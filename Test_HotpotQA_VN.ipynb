# %% [markdown]
# <a href="https://colab.research.google.com/github/chichic21039/Prepare-data-HotpotQA-VN/blob/main/Test_HotpotQA_VN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q --upgrade --force-reinstall \
    "pyarrow>=21.0.0" \
    "datasets" \
    "pandas"
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.3, but you have pandas 3.0.5 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2026.6.0 which is incompatible.
# numba 0.61.2 requires numpy<2.3,>=1.24, but you have numpy 2.5.2 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.5 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.5 which is incompatible.

# %%
# !pip -q install -U datasets

# %%
from datasets import (
    load_dataset,
    get_dataset_config_names,
    get_dataset_split_names
)

VN_REPO = "GreenNode/hotpotqa-vn"
EN_REPO = "hotpotqa/hotpot_qa"

# %%
configs = get_dataset_config_names(VN_REPO)

print("Available configs:")
for config in configs:
    print("-", config)
# Out:
# README.md:   0%|          | 0.00/8.52k [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Available configs:
# - corpus
# - default
# - qrels
# - queries

# %%
query_config = None

for config in configs:
    try:
        splits = get_dataset_split_names(VN_REPO, config)

        print("=" * 60)
        print("Config:", config)
        print("Splits:", splits)

        split_name = "test" if "test" in splits else splits[0]

        sample = load_dataset(
            VN_REPO,
            config,
            split=f"{split_name}[:3]"
        )

        print("Columns:", sample.column_names)
        print("First sample:")
        print(sample[0])

        # Nếu config tên queries thì lấy luôn
        if config.lower() == "queries":
            query_config = config

    except Exception as e:
        print("Error:", e)

print("\nDetected query config:", query_config)
# Out:
# ============================================================
# Config: corpus
# Splits: ['test']
# corpus/test-00000-of-00008.parquet: reconstructing file:   0%|          |  0.00B /  300MB
# corpus/test-00000-of-00008.parquet: downloading bytes:           |  0.00B
# corpus/test-00001-of-00008.parquet: reconstructing file:   0%|          |  0.00B /  249MB
# corpus/test-00001-of-00008.parquet: downloading bytes:           |  0.00B
# corpus/test-00002-of-00008.parquet: reconstructing file:   0%|          |  0.00B /  244MB
# corpus/test-00002-of-00008.parquet: downloading bytes:           |  0.00B
# corpus/test-00003-of-00008.parquet: reconstructing file:   0%|          |  0.00B /  240MB
# corpus/test-00003-of-00008.parquet: downloading bytes:           |  0.00B
# corpus/test-00004-of-00008.parquet: reconstructing file:   0%|          |  0.00B /  271MB
# corpus/test-00004-of-00008.parquet: downloading bytes:           |  0.00B
# corpus/test-00005-of-00008.parquet: reconstructing file:   0%|          |  0.00B /  273MB
# corpus/test-00005-of-00008.parquet: downloading bytes:           |  0.00B
# corpus/test-00006-of-00008.parquet: reconstructing file:   0%|          |  0.00B /  267MB
# corpus/test-00006-of-00008.parquet: downloading bytes:           |  0.00B
# corpus/test-00007-of-00008.parquet: reconstructing file:   0%|          |  0.00B /  241MB
# corpus/test-00007-of-00008.parquet: downloading bytes:           |  0.00B
# Generating test split:   0%|          | 0/5233329 [00:00<?, ? examples/s]
# Columns: ['id', 'title', 'text', 'og_title', 'og_text']
# First sample:
# {'id': '12', 'title': 'Chủ nghĩa vô chính phủ', 'text': 'Chủ nghĩa vô chính phủ là một triết lý chính trị ủng hộ các xã hội tự quản lý dựa trên các tổ chức tình nguyện. Những xã hội này thường được mô tả như những xã hội không có nhà nước, mặc dù nhiều tác giả đã định nghĩa cụ thể hơn rằng chúng là các tổ chức dựa trên liên hiệp tự do phi phân cấp. Chủ nghĩa vô chính phủ cho rằng nhà nước là điều không mong muốn, không cần thiết và gây hại.', 'og_title': 'Anarchism', 'og_text': 'Anarchism is a political philosophy that advocates self-governed societies based on voluntary institutions. These are often described as stateless societies, although several authors have defined them more specifically as institutions based on non-hierarchical free associations. Anarchism holds the state to be undesirable, unnecessary and harmful.'}
# ============================================================
# Config: default
# Splits: ['dev', 'test']
# data/dev-00000-of-00001.parquet: reconstructing file:   0%|          |  0.00B /  186kB
# data/dev-00000-of-00001.parquet: downloading bytes:           |  0.00B
# data/test-00000-of-00001.parquet: reconstructing file:   0%|          |  0.00B /  251kB
# data/test-00000-of-00001.parquet: downloading bytes:           |  0.00B
# Generating dev split:   0%|          | 0/9314 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/12642 [00:00<?, ? examples/s]
# Columns: ['query-id', 'corpus-id', 'score']
# First sample:
# {'query-id': '5a8c7595554299585d9e36b6', 'corpus-id': '33022480', 'score': 1.0}
# ============================================================
# Config: qrels
# Splits: ['test']
# qrels/test-00000-of-00001.parquet: reconstructing file:   0%|          |  0.00B /  225kB
# qrels/test-00000-of-00001.parquet: downloading bytes:           |  0.00B
# Generating test split:   0%|          | 0/12642 [00:00<?, ? examples/s]
# Columns: ['query-id', 'corpus-id', 'score']
# First sample:
# {'query-id': '5ade157e55429939a52fe802', 'corpus-id': '19212398', 'score': 1}
# ============================================================
# Config: queries
# Splits: ['test']
# queries/test-00000-of-00001.parquet: reconstructing file:   0%|          |  0.00B /  970kB
# queries/test-00000-of-00001.parquet: downloading bytes:           |  0.00B
# Generating test split:   0%|          | 0/6321 [00:00<?, ? examples/s]
# Columns: ['id', 'text', 'og_text']
# First sample:
# {'id': '5a8c7595554299585d9e36b6', 'text': 'Vị trí chính phủ nào được nắm giữ bởi người phụ nữ thể hiện Corliss Archer trong phim Kiss and Tell?', 'og_text': 'What government position was held by the woman who portrayed Corliss Archer in the film Kiss and Tell?'}
#
# Detected query config: queries

# %%
query_splits = get_dataset_split_names(VN_REPO, query_config)

print("Query splits:", query_splits)

if "test" in query_splits:
    vn_split = "test"
elif "validation" in query_splits:
    vn_split = "validation"
else:
    vn_split = query_splits[0]

vn_queries = load_dataset(
    VN_REPO,
    query_config,
    split=vn_split
)

print("Number of VN queries:", len(vn_queries))
print("Columns:", vn_queries.column_names)
print()

print(vn_queries[0])
# Out:
# Query splits: ['test']
# Number of VN queries: 6321
# Columns: ['id', 'text', 'og_text']
#
# {'id': '5a8c7595554299585d9e36b6', 'text': 'Vị trí chính phủ nào được nắm giữ bởi người phụ nữ thể hiện Corliss Archer trong phim Kiss and Tell?', 'og_text': 'What government position was held by the woman who portrayed Corliss Archer in the film Kiss and Tell?'}

# %%
def find_column(columns, candidates):
    lower_map = {c.lower(): c for c in columns}

    for candidate in candidates:
        if candidate.lower() in lower_map:
            return lower_map[candidate.lower()]

    return None


vn_id_col = find_column(
    vn_queries.column_names,
    ["id", "query-id", "query_id", "_id"]
)

vn_text_col = find_column(
    vn_queries.column_names,
    ["text", "query", "question"]
)

print("ID column:", vn_id_col)
print("Text column:", vn_text_col)
# Out:
# ID column: id
# Text column: text

# %%
for i in range(5):
    print("=" * 70)
    print("ID:", vn_queries[i][vn_id_col])
    print("Question:", vn_queries[i][vn_text_col])
# Out:
# ======================================================================
# ID: 5a8c7595554299585d9e36b6
# Question: Vị trí chính phủ nào được nắm giữ bởi người phụ nữ thể hiện Corliss Archer trong phim Kiss and Tell?
# ======================================================================
# ID: 5adbf0a255429947ff17385a
# Question: Laleli Mosque và Esma Sultan Mansion có nằm trong cùng một khu phố không?
# ======================================================================
# ID: 5a8e3ea95542995a26add48d
# Question: Đạo diễn của bộ phim hài lãng mạn "Big Stone Gap" đến từ thành phố nào ở New York?
# ======================================================================
# ID: 5abd94525542992ac4f382d2
# Question: 2014 S/S là album đầu tay của một nhóm nhạc nam Hàn Quốc được thành lập bởi ai?
# ======================================================================
# ID: 5a85b2d95542997b5ce40028
# Question: Ai được biết đến với cái tên sân khấu Aladin và đã giúp các tổ chức cải thiện hiệu suất hoạt động của họ dưới tư cách là một cố vấn?

# %%
hotpot_en = load_dataset(
    EN_REPO,
    "distractor",
    split="validation"
)

print("Number of original HotpotQA validation samples:", len(hotpot_en))
print("Columns:", hotpot_en.column_names)

print()
print(hotpot_en[0])
# Out:
# README.md:   0%|          | 0.00/9.52k [00:00<?, ?B/s]
# distractor/train-00000-of-00002.parquet: reconstructing file:   0%|          |  0.00B /  166MB
# distractor/train-00000-of-00002.parquet: downloading bytes:           |  0.00B
# distractor/train-00001-of-00002.parquet: reconstructing file:   0%|          |  0.00B /  166MB
# distractor/train-00001-of-00002.parquet: downloading bytes:           |  0.00B
# distractor/validation-00000-of-00001.par(…): reconstructing file:   0%|          |  0.00B / 27.5MB
# distractor/validation-00000-of-00001.par(…): downloading bytes:           |  0.00B
# Generating train split:   0%|          | 0/90447 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/7405 [00:00<?, ? examples/s]
# Number of original HotpotQA validation samples: 7405
# Columns: ['id', 'question', 'answer', 'type', 'level', 'supporting_facts', 'context']
#
# {'id': '5a8b57f25542995d1e6f1371', 'question': 'Were Scott Derrickson and Ed Wood of the same nationality?', 'answer': 'yes', 'type': 'comparison', 'level': 'hard', 'supporting_facts': {'title': ['Scott Derrickson', 'Ed Wood'], 'sent_id': [0, 0]}, 'context': {'title': ['Ed Wood (film)', 'Scott Derrickson', 'Woodson, Arkansas', 'Tyler Bates', 'Ed Wood', 'Deliver Us from Evil (2014 film)', 'Adam Collis', 'Sinister (film)', 'Conrad Brooks', 'Doctor Strange (2016 film)'], 'sentences': [['Ed Wood is a 1994 American biographical period comedy-drama film directed and produced by Tim Burton, and starring Johnny Depp as cult filmmaker Ed Wood.', " The film concerns the period in Wood's life when he made his best-known films as well as his relationship with actor Bela Lugosi, played by Martin Landau.", ' Sarah Jessica Parker, Patricia Arquette, Jeffrey Jones, Lisa Marie, and Bill Murray are among the supporting cast.'], ['Scott Derrickson (born July 16, 1966) is an American director, screenwriter and producer.', ' He lives in Los Angeles, California.', ' He is best known for directing horror films such as "Sinister", "The Exorcism of Emily Rose", and "Deliver Us From Evil", as well as the 2016 Marvel Cinematic Universe installment, "Doctor Strange."'], ['Woodson is a census-designated place (CDP) in Pulaski County, Arkansas, in the United States.', ' Its population was 403 at the 2010 census.', ' It is part of the Little Rock–North Little Rock–Conway Metropolitan Statistical Area.', ' Woodson and its accompanying Woodson Lake and Wood Hollow are the namesake for Ed Wood Sr., a prominent plantation owner, trader, and businessman at the turn of the 20th century.', ' Woodson is adjacent to the Wood Plantation, the largest of the plantations own by Ed Wood Sr.'], ['Tyler Bates (born June 5, 1965) is an American musician, music producer, and composer for films, television, and video games.', ' Much of his work is in the action and horror film genres, with films like "Dawn of the Dead, 300, Sucker Punch," and "John Wick."', ' He has collaborated with directors like Zack Snyder, Rob Zombie, Neil Marshall, William Friedkin, Scott Derrickson, and James Gunn.', ' With Gunn, he has scored every one of the director\'s films; including "Guardians of the Galaxy", which became one of the highest grossing domestic movies of 2014, and its 2017 sequel.', ' In addition, he is also the lead guitarist of the American rock band Marilyn Manson, and produced its albums "The Pale Emperor" and "Heaven Upside Down".'], ['Edward Davis Wood Jr. (October 10, 1924 – December 10, 1978) was an American filmmaker, actor, writer, producer, and director.'], ['Deliver Us from Evil is a 2014 American supernatural horror film directed by Scott Derrickson and produced by Jerry Bruckheimer.', ' The film is officially based on a 2001 non-fiction book entitled "Beware the Night" by Ralph Sarchie and Lisa Collier Cool, and its marketing campaign highlighted that it was "inspired by actual accounts".', ' The film stars Eric Bana, Édgar Ramírez, Sean Harris, Olivia Munn, and Joel McHale in the main roles and was released on July 2, 2014.'], ['Adam Collis is an American filmmaker and actor.', ' He attended the Duke University from 1986 to 1990 and the University of California, Los Angeles from 2007 to 2010.', ' He also studied cinema at the University of Southern California from 1991 to 1997.', ' Collis first work was the assistant director for the Scott Derrickson\'s short "Love in the Ruins" (1995).', ' In 1998, he played "Crankshaft" in Eric Koyanagi\'s "Hundred Percent".'], ['Sinister is a 2012 supernatural horror film directed by Scott Derrickson and written by Derrickson and C. Robert Cargill.', ' It stars Ethan Hawke as fictional true-crime writer Ellison Oswalt who discovers a box of home movies in his attic that puts his family in danger.'], ['Conrad Brooks (born Conrad Biedrzycki on January 3, 1931 in Baltimore, Maryland) is an American actor.', ' He moved to Hollywood, Ca ...

# %%
original_by_id = {
    str(row["id"]): row
    for row in hotpot_en
}

print("Indexed:", len(original_by_id), "HotpotQA samples")
# Out:
# Indexed: 7405 HotpotQA samples

# %%
NUM_SAMPLES = 5

matched = []

for vn_row in vn_queries:

    query_id = str(vn_row[vn_id_col])

    if query_id in original_by_id:

        matched.append({
            "vn": vn_row,
            "en": original_by_id[query_id]
        })

    if len(matched) == NUM_SAMPLES:
        break


print("Found:", len(matched), "matched samples")
# Out:
# Found: 5 matched samples

# %%
for i, item in enumerate(matched, start=1):

    vn = item["vn"]
    en = item["en"]

    print("\n")
    print("#" * 100)
    print("SAMPLE", i)
    print("#" * 100)

    print("\nID:")
    print(en["id"])

    print("\nVIETNAMESE QUESTION:")
    print(vn[vn_text_col])

    print("\nORIGINAL ENGLISH QUESTION:")
    print(en["question"])

    print("\nGOLD ANSWER:")
    print(en["answer"])

    print("\nTYPE:")
    print(en["type"])

    print("\nLEVEL:")
    print(en["level"])

    print("\nSUPPORTING FACTS:")

    sf = en["supporting_facts"]

    for title, sent_id in zip(
        sf["title"],
        sf["sent_id"]
    ):
        print(f"- {title} | sentence {sent_id}")
# Out:
# ####################################################################################################
# SAMPLE 1
# ####################################################################################################
#
# ID:
# 5a8c7595554299585d9e36b6
#
# VIETNAMESE QUESTION:
# Vị trí chính phủ nào được nắm giữ bởi người phụ nữ thể hiện Corliss Archer trong phim Kiss and Tell?
#
# ORIGINAL ENGLISH QUESTION:
# What government position was held by the woman who portrayed Corliss Archer in the film Kiss and Tell?
#
# GOLD ANSWER:
# Chief of Protocol
#
# TYPE:
# bridge
#
# LEVEL:
# hard
#
# SUPPORTING FACTS:
# - Kiss and Tell (1945 film) | sentence 0
# - Shirley Temple | sentence 0
# - Shirley Temple | sentence 1
#
#
# ####################################################################################################
# SAMPLE 2
# ####################################################################################################
#
# ID:
# 5adbf0a255429947ff17385a
#
# VIETNAMESE QUESTION:
# Laleli Mosque và Esma Sultan Mansion có nằm trong cùng một khu phố không?
#
# ORIGINAL ENGLISH QUESTION:
# Are the Laleli Mosque and Esma Sultan Mansion located in the same neighborhood?
#
# GOLD ANSWER:
# no
#
# TYPE:
# comparison
#
# LEVEL:
# hard
#
# SUPPORTING FACTS:
# - Laleli Mosque | sentence 0
# - Esma Sultan Mansion | sentence 0
#
#
# ####################################################################################################
# SAMPLE 3
# ####################################################################################################
#
# ID:
# 5a8e3ea95542995a26add48d
#
# VIETNAMESE QUESTION:
# Đạo diễn của bộ phim hài lãng mạn "Big Stone Gap" đến từ thành phố nào ở New York?
#
# ORIGINAL ENGLISH QUESTION:
# The director of the romantic comedy "Big Stone Gap" is based in what New York city?
#
# GOLD ANSWER:
# Greenwich Village, New York City
#
# TYPE:
# bridge
#
# LEVEL:
# hard
#
# SUPPORTING FACTS:
# - Big Stone Gap (film) | sentence 0
# - Adriana Trigiani | sentence 0
#
#
# ####################################################################################################
# SAMPLE 4
# ####################################################################################################
#
# ID:
# 5abd94525542992ac4f382d2
#
# VIETNAMESE QUESTION:
# 2014 S/S là album đầu tay của một nhóm nhạc nam Hàn Quốc được thành lập bởi ai?
#
# ORIGINAL ENGLISH QUESTION:
# 2014 S/S is the debut album of a South Korean boy group that was formed by who?
#
# GOLD ANSWER:
# YG Entertainment
#
# TYPE:
# bridge
#
# LEVEL:
# hard
#
# SUPPORTING FACTS:
# - 2014 S/S | sentence 0
# - Winner (band) | sentence 0
#
#
# ####################################################################################################
# SAMPLE 5
# ####################################################################################################
#
# ID:
# 5a85b2d95542997b5ce40028
#
# VIETNAMESE QUESTION:
# Ai được biết đến với cái tên sân khấu Aladin và đã giúp các tổ chức cải thiện hiệu suất hoạt động của họ dưới tư cách là một cố vấn?
#
# ORIGINAL ENGLISH QUESTION:
# Who was known by his stage name Aladin and helped organizations improve their performance as a consultant?
#
# GOLD ANSWER:
# Eenasul Fateh
#
# TYPE:
# bridge
#
# LEVEL:
# hard
#
# SUPPORTING FACTS:
# - Eenasul Fateh | sentence 0
# - Management consulting | sentence 0

# %%
for i, item in enumerate(matched, start=1):

    en = item["en"]

    context_map = {
        title: sentences
        for title, sentences
        in zip(
            en["context"]["title"],
            en["context"]["sentences"]
        )
    }

    print("\n")
    print("#" * 100)
    print("SAMPLE", i)
    print("#" * 100)

    print("QUESTION:")
    print(en["question"])

    print("\nANSWER:")
    print(en["answer"])

    print("\nGOLD SUPPORTING SENTENCES:")

    sf = en["supporting_facts"]

    for title, sent_id in zip(
        sf["title"],
        sf["sent_id"]
    ):

        sentences = context_map.get(title)

        if sentences is None:
            print(f"[Missing article] {title}")
            continue

        if sent_id >= len(sentences):
            print(
                f"[Invalid sentence index] "
                f"{title}: {sent_id}"
            )
            continue

        print(
            f"\n[{title} - sentence {sent_id}]"
        )

        print(sentences[sent_id])
# Out:
# ####################################################################################################
# SAMPLE 1
# ####################################################################################################
# QUESTION:
# What government position was held by the woman who portrayed Corliss Archer in the film Kiss and Tell?
#
# ANSWER:
# Chief of Protocol
#
# GOLD SUPPORTING SENTENCES:
#
# [Kiss and Tell (1945 film) - sentence 0]
# Kiss and Tell is a 1945 American comedy film starring then 17-year-old Shirley Temple as Corliss Archer.
#
# [Shirley Temple - sentence 0]
# Shirley Temple Black (April 23, 1928 – February 10, 2014) was an American actress, singer, dancer, businesswoman, and diplomat who was Hollywood's number one box-office draw as a child actress from 1935 to 1938.
#
# [Shirley Temple - sentence 1]
#  As an adult, she was named United States ambassador to Ghana and to Czechoslovakia and also served as Chief of Protocol of the United States.
#
#
# ####################################################################################################
# SAMPLE 2
# ####################################################################################################
# QUESTION:
# Are the Laleli Mosque and Esma Sultan Mansion located in the same neighborhood?
#
# ANSWER:
# no
#
# GOLD SUPPORTING SENTENCES:
#
# [Laleli Mosque - sentence 0]
# The Laleli Mosque (Turkish: "Laleli Camii, or Tulip Mosque" ) is an 18th-century Ottoman imperial mosque located in Laleli, Fatih, Istanbul, Turkey.
#
# [Esma Sultan Mansion - sentence 0]
# The Esma Sultan Mansion (Turkish: "Esma Sultan Yalısı" ), a historical yalı (English: waterside mansion ) located at Bosphorus in Ortaköy neighborhood of Istanbul, Turkey and named after its original owner Esma Sultan, is used today as a cultural center after being redeveloped.
#
#
# ####################################################################################################
# SAMPLE 3
# ####################################################################################################
# QUESTION:
# The director of the romantic comedy "Big Stone Gap" is based in what New York city?
#
# ANSWER:
# Greenwich Village, New York City
#
# GOLD SUPPORTING SENTENCES:
#
# [Big Stone Gap (film) - sentence 0]
# Big Stone Gap is a 2014 American drama romantic comedy film written and directed by Adriana Trigiani and produced by Donna Gigliotti for Altar Identity Studios, a subsidiary of Media Society.
#
# [Adriana Trigiani - sentence 0]
# Adriana Trigiani is an Italian American best-selling author of sixteen books, television writer, film director, and entrepreneur based in Greenwich Village, New York City.
#
#
# ####################################################################################################
# SAMPLE 4
# ####################################################################################################
# QUESTION:
# 2014 S/S is the debut album of a South Korean boy group that was formed by who?
#
# ANSWER:
# YG Entertainment
#
# GOLD SUPPORTING SENTENCES:
#
# [2014 S/S - sentence 0]
# 2014 S/S is the debut album of South Korean group WINNER.
#
# [Winner (band) - sentence 0]
# Winner (Hangul: 위너), often stylized as WINNER, is a South Korean boy group formed in 2013 by YG Entertainment and debuted in 2014.
#
#
# ####################################################################################################
# SAMPLE 5
# ####################################################################################################
# QUESTION:
# Who was known by his stage name Aladin and helped organizations improve their performance as a consultant?
#
# ANSWER:
# Eenasul Fateh
#
# GOLD SUPPORTING SENTENCES:
#
# [Eenasul Fateh - sentence 0]
# Eenasul Fateh (Bengali: ঈনাসুল ফাতেহ ; born 3 April 1959), also known by his stage name Aladin, is a Bangladeshi-British cultural practitioner, magician, live artist and former international management consultant.
#
# [Management consulting - sentence 0]
# Management consulting is the practice of helping organizations to improve their performance, operating primarily through the analysis of existing organizational problems and the development of plans for improvement.

# %%
matched_count = 0
unmatched_ids = []

for row in vn_queries:

    query_id = str(row[vn_id_col])

    if query_id in original_by_id:
        matched_count += 1
    else:
        unmatched_ids.append(query_id)


total = len(vn_queries)

print("=" * 60)
print("FULL MAPPING STATISTICS")
print("=" * 60)

print("Total Vietnamese queries :", total)
print("Matched                  :", matched_count)
print("Not matched              :", len(unmatched_ids))
print(
    "Match rate               :",
    f"{matched_count / total * 100:.2f}%"
)
# Out:
# ============================================================
# FULL MAPPING STATISTICS
# ============================================================
# Total Vietnamese queries : 6321
# Matched                  : 6321
# Not matched              : 0
# Match rate               : 100.00%

# %%
hotpot_train = load_dataset(
    EN_REPO,
    "distractor",
    split="train"
)

hotpot_validation = load_dataset(
    EN_REPO,
    "distractor",
    split="validation"
)

original_by_id_all = {}

for row in hotpot_train:
    original_by_id_all[str(row["id"])] = row

for row in hotpot_validation:
    original_by_id_all[str(row["id"])] = row

print(
    "Total indexed original questions:",
    len(original_by_id_all)
)
# Out:
# Total indexed original questions: 97852

# %%
matched_count = 0
unmatched_ids = []

for row in vn_queries:

    query_id = str(row[vn_id_col])

    if query_id in original_by_id_all:
        matched_count += 1
    else:
        unmatched_ids.append(query_id)


total = len(vn_queries)

print("Total VN :", total)
print("Matched  :", matched_count)
print("Missing  :", len(unmatched_ids))
print(
    "Rate     :",
    f"{matched_count / total * 100:.2f}%"
)
# Out:
# Total VN : 6321
# Matched  : 6321
# Missing  : 0
# Rate     : 100.00%

# %%
from datasets import load_dataset, get_dataset_config_names, get_dataset_split_names

VN_REPO = "GreenNode/hotpotqa-vn"

configs = get_dataset_config_names(VN_REPO)

qrels_config = None
corpus_config = None

for config in configs:
    splits = get_dataset_split_names(VN_REPO, config)

    split_name = "test" if "test" in splits else splits[0]

    # Streaming để không vô tình tải corpus lớn
    ds_stream = load_dataset(
        VN_REPO,
        config,
        split=split_name,
        streaming=True
    )

    first_row = next(iter(ds_stream))
    columns = list(first_row.keys())

    print("=" * 70)
    print("CONFIG:", config)
    print("SPLIT :", split_name)
    print("COLUMNS:", columns)
    print("SAMPLE:", first_row)

    lower_cols = [c.lower() for c in columns]

    # qrels
    if (
        any(c in lower_cols for c in ["query-id", "query_id"])
        and
        any(c in lower_cols for c in ["corpus-id", "corpus_id"])
    ):
        qrels_config = config

    # corpus
    has_id = any(c in lower_cols for c in ["id", "_id", "corpus-id", "corpus_id"])
    has_text = any(c in lower_cols for c in ["text", "document", "content"])

    is_query = any(c in lower_cols for c in ["query-id", "query_id"])

    if has_id and has_text and not is_query:
        corpus_config = config


print("\nDetected qrels config :", qrels_config)
print("Detected corpus config:", corpus_config)
# Out:
# ======================================================================
# CONFIG: corpus
# SPLIT : test
# COLUMNS: ['id', 'title', 'text', 'og_title', 'og_text']
# SAMPLE: {'id': '12', 'title': 'Chủ nghĩa vô chính phủ', 'text': 'Chủ nghĩa vô chính phủ là một triết lý chính trị ủng hộ các xã hội tự quản lý dựa trên các tổ chức tình nguyện. Những xã hội này thường được mô tả như những xã hội không có nhà nước, mặc dù nhiều tác giả đã định nghĩa cụ thể hơn rằng chúng là các tổ chức dựa trên liên hiệp tự do phi phân cấp. Chủ nghĩa vô chính phủ cho rằng nhà nước là điều không mong muốn, không cần thiết và gây hại.', 'og_title': 'Anarchism', 'og_text': 'Anarchism is a political philosophy that advocates self-governed societies based on voluntary institutions. These are often described as stateless societies, although several authors have defined them more specifically as institutions based on non-hierarchical free associations. Anarchism holds the state to be undesirable, unnecessary and harmful.'}
# ======================================================================
# CONFIG: default
# SPLIT : test
# COLUMNS: ['query-id', 'corpus-id', 'score']
# SAMPLE: {'query-id': '5a8c7595554299585d9e36b6', 'corpus-id': '33022480', 'score': 1.0}
# ======================================================================
# CONFIG: qrels
# SPLIT : test
# COLUMNS: ['query-id', 'corpus-id', 'score']
# SAMPLE: {'query-id': '5ade157e55429939a52fe802', 'corpus-id': '19212398', 'score': 1}
# ======================================================================
# CONFIG: queries
# SPLIT : test
# COLUMNS: ['id', 'text', 'og_text']
# SAMPLE: {'id': '5a8c7595554299585d9e36b6', 'text': 'Vị trí chính phủ nào được nắm giữ bởi người phụ nữ thể hiện Corliss Archer trong phim Kiss and Tell?', 'og_text': 'What government position was held by the woman who portrayed Corliss Archer in the film Kiss and Tell?'}
#
# Detected qrels config : qrels
# Detected corpus config: queries

# %%
VN_REPO = "GreenNode/hotpotqa-vn"

QUERY_CONFIG = "queries"
QRELS_CONFIG = "qrels"
CORPUS_CONFIG = "corpus"

print("Query config :", QUERY_CONFIG)
print("Qrels config :", QRELS_CONFIG)
print("Corpus config:", CORPUS_CONFIG)
# Out:
# Query config : queries
# Qrels config : qrels
# Corpus config: corpus

# %%
sample_query_ids = {
    str(item["en"]["id"])
    for item in matched
}

print("Sample query IDs:")
for qid in sample_query_ids:
    print("-", qid)
# Out:
# Sample query IDs:
# - 5abd94525542992ac4f382d2
# - 5adbf0a255429947ff17385a
# - 5a8c7595554299585d9e36b6
# - 5a8e3ea95542995a26add48d
# - 5a85b2d95542997b5ce40028

# %%
qrels = load_dataset(
    VN_REPO,
    QRELS_CONFIG,
    split="test"
)

selected_qrels = []

for row in qrels:
    if str(row["query-id"]) in sample_query_ids:
        selected_qrels.append(row)

print("\nSelected qrels:", len(selected_qrels))

for row in selected_qrels:
    print(row)
# Out:
# Selected qrels: 10
# {'query-id': '5abd94525542992ac4f382d2', 'corpus-id': '43665973', 'score': 1}
# {'query-id': '5abd94525542992ac4f382d2', 'corpus-id': '40901645', 'score': 1}
# {'query-id': '5a8e3ea95542995a26add48d', 'corpus-id': '41146297', 'score': 1}
# {'query-id': '5a8e3ea95542995a26add48d', 'corpus-id': '5382358', 'score': 1}
# {'query-id': '5a85b2d95542997b5ce40028', 'corpus-id': '507437', 'score': 1}
# {'query-id': '5a85b2d95542997b5ce40028', 'corpus-id': '282635', 'score': 1}
# {'query-id': '5a8c7595554299585d9e36b6', 'corpus-id': '33022480', 'score': 1}
# {'query-id': '5a8c7595554299585d9e36b6', 'corpus-id': '804602', 'score': 1}
# {'query-id': '5adbf0a255429947ff17385a', 'corpus-id': '9421721', 'score': 1}
# {'query-id': '5adbf0a255429947ff17385a', 'corpus-id': '20395866', 'score': 1}

# %%
target_corpus_ids = {
    str(row["corpus-id"])
    for row in selected_qrels
}

print("Need to find:", len(target_corpus_ids), "documents")

for cid in target_corpus_ids:
    print("-", cid)
# Out:
# Need to find: 10 documents
# - 33022480
# - 41146297
# - 507437
# - 40901645
# - 43665973
# - 5382358
# - 20395866
# - 282635
# - 804602
# - 9421721

# %%
vn_corpus_stream = load_dataset(
    VN_REPO,
    CORPUS_CONFIG,
    split="test",
    streaming=True
)

print(vn_corpus_stream)
# Out:
# IterableDataset({
#     features: ['id', 'title', 'text', 'og_title', 'og_text'],
#     num_shards: 8
# })

# %%
found_docs = {}

for i, row in enumerate(vn_corpus_stream):

    corpus_id = str(row["id"])

    if corpus_id in target_corpus_ids:
        found_docs[corpus_id] = row

        print(
            f"FOUND {len(found_docs)}/{len(target_corpus_ids)} "
            f"- ID: {corpus_id}"
        )

    # đủ 10 document thì dừng ngay
    if len(found_docs) == len(target_corpus_ids):
        break

    # chỉ để biết chương trình vẫn đang chạy
    if (i + 1) % 100000 == 0:
        print(
            f"Scanned {i + 1:,} documents | "
            f"Found {len(found_docs)}/{len(target_corpus_ids)}"
        )


print("\n" + "=" * 70)
print("FINAL")
print("=" * 70)

print("Expected:", len(target_corpus_ids))
print("Found   :", len(found_docs))

missing = target_corpus_ids - set(found_docs.keys())

print("Missing :", len(missing))

if missing:
    print("\nMissing IDs:")
    for cid in missing:
        print("-", cid)
# Out:
# Scanned 100,000 documents | Found 0/10
# FOUND 1/10 - ID: 282635
# FOUND 2/10 - ID: 507437
# Scanned 200,000 documents | Found 2/10
# FOUND 3/10 - ID: 804602
# Scanned 300,000 documents | Found 3/10
# Scanned 400,000 documents | Found 3/10
# Scanned 500,000 documents | Found 3/10
# Scanned 600,000 documents | Found 3/10
# Scanned 700,000 documents | Found 3/10
# Scanned 800,000 documents | Found 3/10
# Scanned 900,000 documents | Found 3/10
# Scanned 1,000,000 documents | Found 3/10
# Scanned 1,100,000 documents | Found 3/10
# Scanned 1,200,000 documents | Found 3/10
# Scanned 1,300,000 documents | Found 3/10
# Scanned 1,400,000 documents | Found 3/10
# FOUND 4/10 - ID: 33022480
# Scanned 1,500,000 documents | Found 4/10
# Scanned 1,600,000 documents | Found 4/10
# Scanned 1,700,000 documents | Found 4/10
# Scanned 1,800,000 documents | Found 4/10
# Scanned 1,900,000 documents | Found 4/10
# Scanned 2,000,000 documents | Found 4/10
# Scanned 2,100,000 documents | Found 4/10
# FOUND 5/10 - ID: 40901645
# FOUND 6/10 - ID: 41146297
# Scanned 2,200,000 documents | Found 6/10
# Scanned 2,300,000 documents | Found 6/10
# FOUND 7/10 - ID: 43665973
# Scanned 2,400,000 documents | Found 7/10
# Scanned 2,500,000 documents | Found 7/10
# Scanned 2,600,000 documents | Found 7/10
# Scanned 2,700,000 documents | Found 7/10
# Scanned 2,800,000 documents | Found 7/10
# Scanned 2,900,000 documents | Found 7/10
# Scanned 3,000,000 documents | Found 7/10
# Scanned 3,100,000 documents | Found 7/10
# Scanned 3,200,000 documents | Found 7/10
# Scanned 3,300,000 documents | Found 7/10
# Scanned 3,400,000 documents | Found 7/10
# Scanned 3,500,000 documents | Found 7/10
# Scanned 3,600,000 documents | Found 7/10
# Scanned 3,700,000 documents | Found 7/10
# FOUND 8/10 - ID: 5382358
# Scanned 3,800,000 documents | Found 8/10
# Scanned 3,900,000 documents | Found 8/10
# Scanned 4,000,000 documents | Found 8/10
# Scanned 4,100,000 documents | Found 8/10
# FOUND 9/10 - ID: 9421721
# Scanned 4,200,000 documents | Found 9/10
# Scanned 4,300,000 documents | Found 9/10
# Scanned 4,400,000 documents | Found 9/10
# Scanned 4,500,000 documents | Found 9/10
# Scanned 4,600,000 documents | Found 9/10
# Scanned 4,700,000 documents | Found 9/10
# Scanned 4,800,000 documents | Found 9/10
# Scanned 4,900,000 documents | Found 9/10
# Scanned 5,000,000 documents | Found 9/10
# FOUND 10/10 - ID: 20395866
#
# ======================================================================
# FINAL
# ======================================================================
# Expected: 10
# Found   : 10
# Missing : 0

# %%
for corpus_id, doc in found_docs.items():

    print("\n")
    print("#" * 100)
    print("CORPUS ID:", corpus_id)
    print("#" * 100)

    print("\nVIETNAMESE TITLE:")
    print(doc["title"])

    print("\nORIGINAL TITLE:")
    print(doc["og_title"])

    print("\nVIETNAMESE TEXT:")
    print(doc["text"])

    print("\nORIGINAL ENGLISH TEXT:")
    print(doc["og_text"])
# Out:
# ####################################################################################################
# CORPUS ID: 282635
# ####################################################################################################
#
# VIETNAMESE TITLE:
# Tư vấn quản lý
#
# ORIGINAL TITLE:
# Management consulting
#
# VIETNAMESE TEXT:
# Tư vấn quản lý là thực hành giúp các tổ chức cải thiện hiệu suất hoạt động của họ, chủ yếu thông qua phân tích các vấn đề hiện tại của tổ chức và phát triển kế hoạch cải thiện. Các tổ chức có thể dựa vào dịch vụ tư vấn quản lý cho một số lý do, bao gồm việc tìm kiếm lời khuyên bên ngoài (và giả định khách quan) và tiếp cận chuyên môn chuyên sâu của nhà tư vấn.
#
# ORIGINAL ENGLISH TEXT:
# Management consulting is the practice of helping organizations to improve their performance, operating primarily through the analysis of existing organizational problems and the development of plans for improvement. Organizations may draw upon the services of management consultants for a number of reasons, including gaining external (and presumably objective) advice and access to the consultants' specialized expertise.
#
#
# ####################################################################################################
# CORPUS ID: 507437
# ####################################################################################################
#
# VIETNAMESE TITLE:
# Ên-a-xul Phê-tắc
#
# ORIGINAL TITLE:
# Eenasul Fateh
#
# VIETNAMESE TEXT:
# Eenasul Fateh (tiếng Bengali: ঈনাসুল ফাতেহ ; sinh ngày 3 tháng 4 năm 1959), còn được biết đến với tên sân khấu Aladin, là một người thực hành văn hóa Bangladesh-Anh, ảo thuật gia, nghệ sĩ biểu diễn trực tiếp và cựu cố vấn quản lý quốc tế.
#
# ORIGINAL ENGLISH TEXT:
# Eenasul Fateh (Bengali: ঈনাসুল ফাতেহ ; born 3 April 1959), also known by his stage name Aladin, is a Bangladeshi-British cultural practitioner, magician, live artist and former international management consultant.
#
#
# ####################################################################################################
# CORPUS ID: 804602
# ####################################################################################################
#
# VIETNAMESE TITLE:
# Shirley Temple
#
# ORIGINAL TITLE:
# Shirley Temple
#
# VIETNAMESE TEXT:
# Shirley Temple Black (23 tháng 4 năm 1928 – 10 tháng 2 năm 2014) là một nữ diễn viên, ca sĩ, vũ công, doanh nhân và nhà ngoại giao người Mỹ. Bà từng là diễn viên nhí được trả lương cao nhất tại Hollywood từ năm 1935 đến năm 1938. Khi trưởng thành bà trở thành Đại sứ Hoa Kỳ tại Ghana và Cộng hòa Séc cũng như giữ chức vụ Trưởng phòng Lễ tân của Nhà Trắng.
#
# ORIGINAL ENGLISH TEXT:
# Shirley Temple Black (April 23, 1928 – February 10, 2014) was an American actress, singer, dancer, businesswoman, and diplomat who was Hollywood's number one box-office draw as a child actress from 1935 to 1938. As an adult, she was named United States ambassador to Ghana and to Czechoslovakia and also served as Chief of Protocol of the United States.
#
#
# ####################################################################################################
# CORPUS ID: 33022480
# ####################################################################################################
#
# VIETNAMESE TITLE:
# Kiss and Tell (phim 1945)
#
# ORIGINAL TITLE:
# Kiss and Tell (1945 film)
#
# VIETNAMESE TEXT:
# Kiss and Tell là một bộ phim hài hước Mỹ năm 1945 với sự tham gia của Shirley Temple (lúc đó mới 17 tuổi) trong vai Corliss Archer. Trong phim, hai cô gái thiếu niên khiến cha mẹ họ lo lắng khi bắt đầu quan tâm đến các chàng trai. Sự tranh cãi giữa cha mẹ về việc ai có ảnh hưởng xấu hơn lại gây ra nhiều vấn đề hơn là giải quyết được chúng.
#
# ORIGINAL ENGLISH TEXT:
# Kiss and Tell is a 1945 American comedy film starring then 17-year-old Shirley Temple as Corliss Archer. In the film, two teenage girls cause their respective parents much concern when they start to become interested in boys. The parents' bickering about which girl is the worse influence causes more problems than it solves.
#
#
# ####################################################################################################
# CORPUS ID: 40901645
# ####################################################################################################
#
# VIETNAMESE TITLE:
# Winner
#
# ORIGINAL TITLE:
# Winner (band)
#
# VIETNAMESE TEXT:
# Winner (Hangeul: 위너), thường được viết là WINNER, là một nhóm nhạc nam Hàn Quốc thành lập vào năm 2013 bởi YG Entertainment và ra mắt vào năm 2014. Hiện tại bao gồm bốn thành viên Jinwoo, Seunghoon, Mino và Seungyoon. Ban đầu là nhóm có 5 người với Taehyun trước khi anh rời nhóm vào tháng 11/2016.
#
# ORIGINAL ENGLISH TEXT:
# Winner (Hangul: 위너), often stylized as WINNER, is a South Korean boy group formed in 2013 by YG Entertainment and debuted in 2014. It currently consists of four members, Jinwoo, Seunghoon, Mino and Seungyoon. Originally a five-piece group with Taehyun, who later departed from the group in November 2016.
#
#
# ####################################################################################################
# CORPUS ID: 41146297
# ####################################################################################################
#
# VIETNAMESE TITLE:
# Big Stone Gap (phim)
#
# ORIGINAL TITLE:
# Big Stone Gap (film)
#
# VIETNAMESE TEXT:
# Big Stone Gap là một bộ phim hài lãng mạn năm 2014 do Adriana Trigiani viết kịch bản và đạo diễn, được Donna Gigliotti sản xuất cho Altar Identity Studios, một công ty con của Media Society. Dựa trên cuốn tiểu thuyết cùng tên năm 2000 của Trigiani, câu chuyện diễn ra tại thị trấn Big Stone Gap ở Virginia vào những năm 1970. Phim đã có buổi ra mắt thế giới tại Liên hoan phim Virginia vào ngày 6 tháng 11 năm 2014.
#
# ORIGINAL ENGLISH TEXT:
# Big Stone Gap is a 2014 American drama romantic comedy film written and directed by Adriana Trigiani and produced by Donna Gigliotti for Altar Identity Studios, a subsidiary of Media Society. Based on Trigiani's 2000 best-selling novel of the same name, the story is set in the actual Virginia town of Big Stone Gap circa 1970s. The film had its world premiere at the Virginia Film Festival on November 6, 2014.
#
#
# ####################################################################################################
# CORPUS ID: 43665973
# ####################################################################################################
#
# VIETNAMESE TITLE:
# 2014 S/S
#
# ORIGINAL TITLE:
# 2014 S/S
#
# VIETNAMESE TEXT:
# 2014 S/S là album đầu tay của nhóm nhạc nam WINNER. Nó được phát hành vào ngày 12 tháng 8 năm 2014 bởi hãng đĩa YG Entertainment của nhóm. Các thành viên đã viết lời và soạn nhạc cho hầu hết các ca khúc trong album này.
#
# ORIGINAL ENGLISH TEXT:
# 2014 S/S is the debut album of South Korean group WINNER. It was released on August 12, 2014 by the group's record label, YG Entertainment. The members were credited for writing the lyrics and composing the majority of the album's songs.
#
#
# ####################################################################################################
# CORPUS ID: 5382358
# ####################################################################################################
#
# VIETNAMESE TITLE:
# Adriana Trigiani
#
# ORIGINAL TITLE:
# Adriana Trigiani
#
# VIETNAMESE TEXT:
# Adriana Trigiani là một tác giả người Mỹ gốc Ý bán chạy nhất của 16 cuốn sách, biên kịch truyền hình, đạo diễn phim và doanh nhân tại Greenwich Village ở thành phố New York. Kể từ năm 2000, cô đã xuất bản một tiểu thuyết mỗi năm.
#
# ORIGINAL ENGLISH TEXT:
# Adriana Trigiani is an Italian American best-selling author of sixteen books, television writer, film director, and entrepreneur based in Greenwich Village, New York City. Trigiani has published a novel a year since 2000.
#
#
# ####################################################################################################
# CORPUS ID: 9421721
# ####################################################################################################
#
# VIETNAMESE TITLE:
# Chùa Laleli
#
# ORIGINAL TITLE:
# Laleli Mosque
#
# VIETNAMESE TEXT:
# Chùa Laleli (tiếng Thổ Nhĩ Kỳ: "Laleli Camii, hoặc Tulip Mosque" ) là một nhà thờ Hồi giáo hoàng gia Ottoman thế kỷ 18 nằm ở Laleli, Fatih, Istanbul, Thổ Nhĩ Kỳ.
#
# ORIGINAL ENGLISH TEXT:
# The Laleli Mosque (Turkish: "Laleli Camii, or Tulip Mosque" ) is an 18th-century Ottoman imperial mosque located in Laleli, Fatih, Istanbul, Turkey.
#
#
# ####################################################################################################
# CORPUS ID: 20395866
# ####################################################################################################
#
# VIETNAMESE TITLE:
# Esma Sultan Mansion
#
# ORIGINAL TITLE:
# Esma Sultan Mansion
#
# VIETNAMESE TEXT:
# Esma Sultan Mansion (tiếng Thổ Nhĩ Kỳ: Esma Sultan Yalısı ), một biệt thự lịch sử ( tiếng Anh : Waterside mansion ) nằm ở Bosphorus trong khu phố Ortaköy của Istanbul, Thổ Nhĩ Kỳ và được đặt tên theo chủ sở hữu ban đầu Esma Sultan, hiện đang được sử dụng làm trung tâm văn hóa sau khi đã được cải tạo.
#
# ORIGINAL ENGLISH TEXT:
# The Esma Sultan Mansion (Turkish: "Esma Sultan Yalısı" ), a historical yalı (English: waterside mansion ) located at Bosphorus in Ortaköy neighborhood of Istanbul, Turkey and named after its original owner Esma Sultan, is used today as a cultural center after being redeveloped.

# %%
# query_id -> list corpus IDs
qrels_by_query = {}

for row in selected_qrels:

    qid = str(row["query-id"])
    cid = str(row["corpus-id"])

    qrels_by_query.setdefault(qid, []).append(cid)


for item in matched:

    vn = item["vn"]
    en = item["en"]

    qid = str(en["id"])

    print("\n\n")
    print("#" * 100)
    print("QUESTION ID:", qid)
    print("#" * 100)

    print("\nVIETNAMESE QUESTION:")
    print(vn[vn_text_col])

    print("\nORIGINAL ENGLISH QUESTION:")
    print(en["question"])

    print("\nENGLISH GOLD ANSWER:")
    print(en["answer"])

    print("\nORIGINAL SUPPORTING FACTS:")

    sf = en["supporting_facts"]

    for title, sent_id in zip(
        sf["title"],
        sf["sent_id"]
    ):
        print(f"- {title} | sentence {sent_id}")

    print("\n" + "=" * 80)
    print("VIETNAMESE RELEVANT DOCUMENTS")
    print("=" * 80)

    corpus_ids = qrels_by_query.get(qid, [])

    for corpus_id in corpus_ids:

        doc = found_docs.get(corpus_id)

        print("\nCORPUS ID:", corpus_id)

        if doc is None:
            print("[NOT FOUND]")
            continue

        print("\nVI TITLE:")
        print(doc["title"])

        print("\nORIGINAL TITLE:")
        print(doc["og_title"])

        print("\nVI TEXT:")
        print(doc["text"])

        print("\nORIGINAL TEXT:")
        print(doc["og_text"])

        print("\n" + "-" * 80)
# Out:
# ####################################################################################################
# QUESTION ID: 5a8c7595554299585d9e36b6
# ####################################################################################################
#
# VIETNAMESE QUESTION:
# Vị trí chính phủ nào được nắm giữ bởi người phụ nữ thể hiện Corliss Archer trong phim Kiss and Tell?
#
# ORIGINAL ENGLISH QUESTION:
# What government position was held by the woman who portrayed Corliss Archer in the film Kiss and Tell?
#
# ENGLISH GOLD ANSWER:
# Chief of Protocol
#
# ORIGINAL SUPPORTING FACTS:
# - Kiss and Tell (1945 film) | sentence 0
# - Shirley Temple | sentence 0
# - Shirley Temple | sentence 1
#
# ================================================================================
# VIETNAMESE RELEVANT DOCUMENTS
# ================================================================================
#
# CORPUS ID: 33022480
#
# VI TITLE:
# Kiss and Tell (phim 1945)
#
# ORIGINAL TITLE:
# Kiss and Tell (1945 film)
#
# VI TEXT:
# Kiss and Tell là một bộ phim hài hước Mỹ năm 1945 với sự tham gia của Shirley Temple (lúc đó mới 17 tuổi) trong vai Corliss Archer. Trong phim, hai cô gái thiếu niên khiến cha mẹ họ lo lắng khi bắt đầu quan tâm đến các chàng trai. Sự tranh cãi giữa cha mẹ về việc ai có ảnh hưởng xấu hơn lại gây ra nhiều vấn đề hơn là giải quyết được chúng.
#
# ORIGINAL TEXT:
# Kiss and Tell is a 1945 American comedy film starring then 17-year-old Shirley Temple as Corliss Archer. In the film, two teenage girls cause their respective parents much concern when they start to become interested in boys. The parents' bickering about which girl is the worse influence causes more problems than it solves.
#
# --------------------------------------------------------------------------------
#
# CORPUS ID: 804602
#
# VI TITLE:
# Shirley Temple
#
# ORIGINAL TITLE:
# Shirley Temple
#
# VI TEXT:
# Shirley Temple Black (23 tháng 4 năm 1928 – 10 tháng 2 năm 2014) là một nữ diễn viên, ca sĩ, vũ công, doanh nhân và nhà ngoại giao người Mỹ. Bà từng là diễn viên nhí được trả lương cao nhất tại Hollywood từ năm 1935 đến năm 1938. Khi trưởng thành bà trở thành Đại sứ Hoa Kỳ tại Ghana và Cộng hòa Séc cũng như giữ chức vụ Trưởng phòng Lễ tân của Nhà Trắng.
#
# ORIGINAL TEXT:
# Shirley Temple Black (April 23, 1928 – February 10, 2014) was an American actress, singer, dancer, businesswoman, and diplomat who was Hollywood's number one box-office draw as a child actress from 1935 to 1938. As an adult, she was named United States ambassador to Ghana and to Czechoslovakia and also served as Chief of Protocol of the United States.
#
# --------------------------------------------------------------------------------
#
#
#
# ####################################################################################################
# QUESTION ID: 5adbf0a255429947ff17385a
# ####################################################################################################
#
# VIETNAMESE QUESTION:
# Laleli Mosque và Esma Sultan Mansion có nằm trong cùng một khu phố không?
#
# ORIGINAL ENGLISH QUESTION:
# Are the Laleli Mosque and Esma Sultan Mansion located in the same neighborhood?
#
# ENGLISH GOLD ANSWER:
# no
#
# ORIGINAL SUPPORTING FACTS:
# - Laleli Mosque | sentence 0
# - Esma Sultan Mansion | sentence 0
#
# ================================================================================
# VIETNAMESE RELEVANT DOCUMENTS
# ================================================================================
#
# CORPUS ID: 9421721
#
# VI TITLE:
# Chùa Laleli
#
# ORIGINAL TITLE:
# Laleli Mosque
#
# VI TEXT:
# Chùa Laleli (tiếng Thổ Nhĩ Kỳ: "Laleli Camii, hoặc Tulip Mosque" ) là một nhà thờ Hồi giáo hoàng gia Ottoman thế kỷ 18 nằm ở Laleli, Fatih, Istanbul, Thổ Nhĩ Kỳ.
#
# ORIGINAL TEXT:
# The Laleli Mosque (Turkish: "Laleli Camii, or Tulip Mosque" ) is an 18th-century Ottoman imperial mosque located in Laleli, Fatih, Istanbul, Turkey.
#
# --------------------------------------------------------------------------------
#
# CORPUS ID: 20395866
#
# VI TITLE:
# Esma Sultan Mansion
#
# ORIGINAL TITLE:
# Esma Sultan Mansion
#
# VI TEXT:
# Esma Sultan Mansion (tiếng Thổ Nhĩ Kỳ: Esma Sultan Yalısı ), một biệt thự lịch sử ( tiếng Anh : Waterside mansion ) nằm ở Bosphorus trong khu phố Ortaköy của Istanbul, Thổ Nhĩ Kỳ và được đặt tên theo chủ sở hữu ban đầu Esma Sultan, hiện đang được sử dụng làm trung tâm văn hóa sau khi đã được cải tạo.
#
# ORIGINAL TEXT:
# The Esma Sultan Mansion (Turkish: "Esma Sultan Yalısı" ), a historical yalı (English: waterside mansion ) located at Bosphorus in Ortaköy neighborhood of Istanbul, Turkey and named after its original owner Esma Sultan, is used today as a cultural center after being redeveloped.
#
# --------------------------------------------------------------------------------
#
#
#
# ####################################################################################################
# QUESTION ID: 5a8e3ea95542995a26add48d
# ####################################################################################################
#
# VIETNAMESE QUESTION:
# Đạo diễn của bộ phim hài lãng mạn "Big Stone Gap" đến từ thành phố nào ở New York?
#
# ORIGINAL ENGLISH QUESTION:
# The director of the romantic comedy "Big Stone Gap" is based in what New York city?
#
# ENGLISH GOLD ANSWER:
# Greenwich Village, New York City
#
# ORIGINAL SUPPORTING FACTS:
# - Big Stone Gap (film) | sentence 0
# - Adriana Trigiani | sentence 0
#
# ================================================================================
# VIETNAMESE RELEVANT DOCUMENTS
# ================================================================================
#
# CORPUS ID: 41146297
#
# VI TITLE:
# Big Stone Gap (phim)
#
# ORIGINAL TITLE:
# Big Stone Gap (film)
#
# VI TEXT:
# Big Stone Gap là một bộ phim hài lãng mạn năm 2014 do Adriana Trigiani viết kịch bản và đạo diễn, được Donna Gigliotti sản xuất cho Altar Identity Studios, một công ty con của Media Society. Dựa trên cuốn tiểu thuyết cùng tên năm 2000 của Trigiani, câu chuyện diễn ra tại thị trấn Big Stone Gap ở Virginia vào những năm 1970. Phim đã có buổi ra mắt thế giới tại Liên hoan phim Virginia vào ngày 6 tháng 11 năm 2014.
#
# ORIGINAL TEXT:
# Big Stone Gap is a 2014 American drama romantic comedy film written and directed by Adriana Trigiani and produced by Donna Gigliotti for Altar Identity Studios, a subsidiary of Media Society. Based on Trigiani's 2000 best-selling novel of the same name, the story is set in the actual Virginia town of Big Stone Gap circa 1970s. The film had its world premiere at the Virginia Film Festival on November 6, 2014.
#
# --------------------------------------------------------------------------------
#
# CORPUS ID: 5382358
#
# VI TITLE:
# Adriana Trigiani
#
# ORIGINAL TITLE:
# Adriana Trigiani
#
# VI TEXT:
# Adriana Trigiani là một tác giả người Mỹ gốc Ý bán chạy nhất của 16 cuốn sách, biên kịch truyền hình, đạo diễn phim và doanh nhân tại Greenwich Village ở thành phố New York. Kể từ năm 2000, cô đã xuất bản một tiểu thuyết mỗi năm.
#
# ORIGINAL TEXT:
# Adriana Trigiani is an Italian American best-selling author of sixteen books, television writer, film director, and entrepreneur based in Greenwich Village, New York City. Trigiani has published a novel a year since 2000.
#
# --------------------------------------------------------------------------------
#
#
#
# ####################################################################################################
# QUESTION ID: 5abd94525542992ac4f382d2
# ####################################################################################################
#
# VIETNAMESE QUESTION:
# 2014 S/S là album đầu tay của một nhóm nhạc nam Hàn Quốc được thành lập bởi ai?
#
# ORIGINAL ENGLISH QUESTION:
# 2014 S/S is the debut album of a South Korean boy group that was formed by who?
#
# ENGLISH GOLD ANSWER:
# YG Entertainment
#
# ORIGINAL SUPPORTING FACTS:
# - 2014 S/S | sentence 0
# - Winner (band) | sentence 0
#
# ================================================================================
# VIETNAMESE RELEVANT DOCUMENTS
# ================================================================================
#
# CORPUS ID: 43665973
#
# VI TITLE:
# 2014 S/S
#
# ORIGINAL TITLE:
# 2014 S/S
#
# VI TEXT:
# 2014 S/S là album đầu tay của nhóm nhạc nam WINNER. Nó được phát hành vào ngày 12 tháng 8 năm 2014 bởi hãng đĩa YG Entertainment của nhóm. Các thành viên đã viết lời và soạn nhạc cho hầu hết các ca khúc trong album này.
#
# ORIGINAL TEXT:
# 2014 S/S is the debut album of South Korean group WINNER. It was released on August 12, 2014 by the group's record label, YG Entertainment. The members were credited for writing the lyrics and composing the majority of the album's songs.
#
# --------------------------------------------------------------------------------
#
# CORPUS ID: 40901645
#
# VI TITLE:
# Winner
#
# ORIGINAL TITLE:
# Winner (band)
#
# VI TEXT:
# Winner (Hangeul: 위너), thường được viết là WINNER, là một nhóm nhạc nam Hàn Quốc thành lập vào năm 2013 bởi YG Entertainment và ra mắt vào năm 2014. Hiện tại bao gồm bốn thành viên Jinwoo, Seunghoon, Mino và Seungyoon. Ban đầu là nhóm có 5 người với Taehyun trước khi anh rời nhóm vào tháng 11/2016.
#
# ORIGINAL TEXT:
# Winner (Hangul: 위너), often stylized as WINNER, is a South Korean boy group formed in 2013 by YG Entertainment and debuted in 2014. It currently consists of four members, Jinwoo, Seunghoon, Mino and Seungyoon. Originally a five-piece group with Taehyun, who later departed from the group in November 2016.
#
# --------------------------------------------------------------------------------
#
#
#
# ####################################################################################################
# QUESTION ID: 5a85b2d95542997b5ce40028
# ####################################################################################################
#
# VIETNAMESE QUESTION:
# Ai được biết đến với cái tên sân khấu Aladin và đã giúp các tổ chức cải thiện hiệu suất hoạt động của họ dưới tư cách là một cố vấn?
#
# ORIGINAL ENGLISH QUESTION:
# Who was known by his stage name Aladin and helped organizations improve their performance as a consultant?
#
# ENGLISH GOLD ANSWER:
# Eenasul Fateh
#
# ORIGINAL SUPPORTING FACTS:
# - Eenasul Fateh | sentence 0
# - Management consulting | sentence 0
#
# ================================================================================
# VIETNAMESE RELEVANT DOCUMENTS
# ================================================================================
#
# CORPUS ID: 507437
#
# VI TITLE:
# Ên-a-xul Phê-tắc
#
# ORIGINAL TITLE:
# Eenasul Fateh
#
# VI TEXT:
# Eenasul Fateh (tiếng Bengali: ঈনাসুল ফাতেহ ; sinh ngày 3 tháng 4 năm 1959), còn được biết đến với tên sân khấu Aladin, là một người thực hành văn hóa Bangladesh-Anh, ảo thuật gia, nghệ sĩ biểu diễn trực tiếp và cựu cố vấn quản lý quốc tế.
#
# ORIGINAL TEXT:
# Eenasul Fateh (Bengali: ঈনাসুল ফাতেহ ; born 3 April 1959), also known by his stage name Aladin, is a Bangladeshi-British cultural practitioner, magician, live artist and former international management consultant.
#
# --------------------------------------------------------------------------------
#
# CORPUS ID: 282635
#
# VI TITLE:
# Tư vấn quản lý
#
# ORIGINAL TITLE:
# Management consulting
#
# VI TEXT:
# Tư vấn quản lý là thực hành giúp các tổ chức cải thiện hiệu suất hoạt động của họ, chủ yếu thông qua phân tích các vấn đề hiện tại của tổ chức và phát triển kế hoạch cải thiện. Các tổ chức có thể dựa vào dịch vụ tư vấn quản lý cho một số lý do, bao gồm việc tìm kiếm lời khuyên bên ngoài (và giả định khách quan) và tiếp cận chuyên môn chuyên sâu của nhà tư vấn.
#
# ORIGINAL TEXT:
# Management consulting is the practice of helping organizations to improve their performance, operating primarily through the analysis of existing organizational problems and the development of plans for improvement. Organizations may draw upon the services of management consultants for a number of reasons, including gaining external (and presumably objective) advice and access to the consultants' specialized expertise.
#
# --------------------------------------------------------------------------------

# %%
for item in matched:

    en = item["en"]
    qid = str(en["id"])

    # Gold supporting article titles từ HotpotQA
    gold_titles = set(en["supporting_facts"]["title"])

    # English original titles trong các VN relevant docs
    retrieved_titles = set()

    for corpus_id in qrels_by_query.get(qid, []):

        doc = found_docs.get(corpus_id)

        if doc is not None:
            retrieved_titles.add(doc["og_title"])

    print("\n" + "=" * 100)
    print("QUESTION:", en["question"])

    print("\nGold supporting titles:")
    for t in gold_titles:
        print("  GOLD:", t)

    print("\nHotpotQA-VN qrels titles:")
    for t in retrieved_titles:
        print("  VN  :", t)

    print("\nExact title match:")
    print(gold_titles == retrieved_titles)
# Out:
# ====================================================================================================
# QUESTION: What government position was held by the woman who portrayed Corliss Archer in the film Kiss and Tell?
#
# Gold supporting titles:
#   GOLD: Kiss and Tell (1945 film)
#   GOLD: Shirley Temple
#
# HotpotQA-VN qrels titles:
#   VN  : Kiss and Tell (1945 film)
#   VN  : Shirley Temple
#
# Exact title match:
# True
#
# ====================================================================================================
# QUESTION: Are the Laleli Mosque and Esma Sultan Mansion located in the same neighborhood?
#
# Gold supporting titles:
#   GOLD: Laleli Mosque
#   GOLD: Esma Sultan Mansion
#
# HotpotQA-VN qrels titles:
#   VN  : Laleli Mosque
#   VN  : Esma Sultan Mansion
#
# Exact title match:
# True
#
# ====================================================================================================
# QUESTION: The director of the romantic comedy "Big Stone Gap" is based in what New York city?
#
# Gold supporting titles:
#   GOLD: Big Stone Gap (film)
#   GOLD: Adriana Trigiani
#
# HotpotQA-VN qrels titles:
#   VN  : Big Stone Gap (film)
#   VN  : Adriana Trigiani
#
# Exact title match:
# True
#
# ====================================================================================================
# QUESTION: 2014 S/S is the debut album of a South Korean boy group that was formed by who?
#
# Gold supporting titles:
#   GOLD: Winner (band)
#   GOLD: 2014 S/S
#
# HotpotQA-VN qrels titles:
#   VN  : Winner (band)
#   VN  : 2014 S/S
#
# Exact title match:
# True
#
# ====================================================================================================
# QUESTION: Who was known by his stage name Aladin and helped organizations improve their performance as a consultant?
#
# Gold supporting titles:
#   GOLD: Eenasul Fateh
#   GOLD: Management consulting
#
# HotpotQA-VN qrels titles:
#   VN  : Eenasul Fateh
#   VN  : Management consulting
#
# Exact title match:
# True

# %% [markdown]
# # code kiểm tra xem corpus có map được ID qua bản original không, và tương tự với nhánh qrels → corpus → original supporting documents

# %%
# !pip -q install -U datasets tqdm

from datasets import load_dataset
from collections import defaultdict
from tqdm.auto import tqdm
import re
import unicodedata

VN_REPO = "GreenNode/hotpotqa-vn"
EN_REPO = "hotpotqa/hotpot_qa"

# HotpotQA-VN
vn_queries = load_dataset(
    VN_REPO,
    "queries",
    split="test"
)

qrels = load_dataset(
    VN_REPO,
    "qrels",
    split="test"
)

# HotpotQA original
hotpot_train = load_dataset(
    EN_REPO,
    "distractor",
    split="train"
)

hotpot_val = load_dataset(
    EN_REPO,
    "distractor",
    split="validation"
)

print("VN queries:", len(vn_queries))
print("Qrels:", len(qrels))
print("Original train:", len(hotpot_train))
print("Original validation:", len(hotpot_val))
# Out:
# VN queries: 6321
# Qrels: 12642
# Original train: 90447
# Original validation: 7405

# %%
print("Original HotpotQA columns:")
print(hotpot_train.column_names)

print("\nContext structure:")
print(hotpot_train[0]["context"].keys())

print("\nFirst context title:")
print(hotpot_train[0]["context"]["title"][0])

print("\nFirst context sentences:")
print(hotpot_train[0]["context"]["sentences"][0][:3])
# Out:
# Original HotpotQA columns:
# ['id', 'question', 'answer', 'type', 'level', 'supporting_facts', 'context']
#
# Context structure:
# dict_keys(['title', 'sentences'])
#
# First context title:
# Radio City (Indian radio station)
#
# First context sentences:
# ["Radio City is India's first private FM radio station and was started on 3 July 2001.", ' It broadcasts on 91.1 (earlier 91.0 in most cities) megahertz from Mumbai (where it was started in 2004), Bengaluru (started first in 2001), Lucknow and New Delhi (since 2003).', ' It plays Hindi, English and regional songs.']

# %%
original_by_id = {}

for row in hotpot_train:
    original_by_id[str(row["id"])] = row

for row in hotpot_val:
    original_by_id[str(row["id"])] = row

print("Total original questions indexed:", len(original_by_id))
# Out:
# Total original questions indexed: 97852

# %%
matched_query_ids = []
missing_query_ids = []

for row in vn_queries:

    qid = str(row["id"])

    if qid in original_by_id:
        matched_query_ids.append(qid)
    else:
        missing_query_ids.append(qid)


print("Total VN queries :", len(vn_queries))
print("Matched          :", len(matched_query_ids))
print("Missing          :", len(missing_query_ids))

print(
    "Match rate       :",
    f"{len(matched_query_ids)/len(vn_queries)*100:.2f}%"
)
# Out:
# Total VN queries : 6321
# Matched          : 6321
# Missing          : 0
# Match rate       : 100.00%

# %%
target_corpus_ids = {
    str(row["corpus-id"])
    for row in qrels
}

print("Total qrel rows          :", len(qrels))
print("Unique relevant corpus ID:", len(target_corpus_ids))
# Out:
# Total qrel rows          : 12642
# Unique relevant corpus ID: 11874

# %%
vn_corpus_stream = load_dataset(
    VN_REPO,
    "corpus",
    split="test",
    streaming=True
)

found_docs = {}

for i, row in enumerate(vn_corpus_stream, start=1):

    cid = str(row["id"])

    if cid in target_corpus_ids:
        found_docs[cid] = row

    # Tìm đủ thì dừng
    if len(found_docs) == len(target_corpus_ids):
        print("Found all target documents!")
        break

    # progress
    if i % 100000 == 0:
        print(
            f"Scanned {i:,} docs | "
            f"Found {len(found_docs):,}/{len(target_corpus_ids):,}"
        )


missing_corpus_ids = (
    target_corpus_ids - set(found_docs.keys())
)

print("\n" + "=" * 70)
print("CORPUS ID CHECK")
print("=" * 70)

print("Expected:", len(target_corpus_ids))
print("Found   :", len(found_docs))
print("Missing :", len(missing_corpus_ids))
# Out:
# Scanned 100,000 docs | Found 1,584/11,874
# Scanned 200,000 docs | Found 2,737/11,874
# Scanned 300,000 docs | Found 3,538/11,874
# Scanned 400,000 docs | Found 4,129/11,874
# Scanned 500,000 docs | Found 4,621/11,874
# Scanned 600,000 docs | Found 4,729/11,874
# Scanned 700,000 docs | Found 4,846/11,874
# Scanned 800,000 docs | Found 4,980/11,874
# Scanned 900,000 docs | Found 5,108/11,874
# Scanned 1,000,000 docs | Found 5,217/11,874
# Scanned 1,100,000 docs | Found 5,352/11,874
# Scanned 1,200,000 docs | Found 5,474/11,874
# Scanned 1,300,000 docs | Found 5,621/11,874
# Scanned 1,400,000 docs | Found 5,734/11,874
# Scanned 1,500,000 docs | Found 5,843/11,874
# Scanned 1,600,000 docs | Found 5,947/11,874
# Scanned 1,700,000 docs | Found 6,047/11,874
# Scanned 1,800,000 docs | Found 6,150/11,874
# Scanned 1,900,000 docs | Found 6,251/11,874
# Scanned 2,000,000 docs | Found 6,402/11,874
# Scanned 2,100,000 docs | Found 6,512/11,874
# Scanned 2,200,000 docs | Found 6,603/11,874
# Scanned 2,300,000 docs | Found 6,715/11,874
# Scanned 2,400,000 docs | Found 6,848/11,874
# Scanned 2,500,000 docs | Found 6,972/11,874
# Scanned 2,600,000 docs | Found 7,100/11,874
# Scanned 2,700,000 docs | Found 7,228/11,874
# Scanned 2,800,000 docs | Found 7,334/11,874
# Scanned 2,900,000 docs | Found 7,436/11,874
# Scanned 3,000,000 docs | Found 7,530/11,874
# Scanned 3,100,000 docs | Found 8,034/11,874
# Scanned 3,200,000 docs | Found 8,382/11,874
# Scanned 3,300,000 docs | Found 8,575/11,874
# Scanned 3,400,000 docs | Found 8,701/11,874
# Scanned 3,500,000 docs | Found 8,864/11,874
# Scanned 3,600,000 docs | Found 9,135/11,874
# Scanned 3,700,000 docs | Found 9,393/11,874
# Scanned 3,800,000 docs | Found 9,632/11,874
# Scanned 3,900,000 docs | Found 9,840/11,874
# Scanned 4,000,000 docs | Found 10,081/11,874
# Scanned 4,100,000 docs | Found 10,286/11,874
# Scanned 4,200,000 docs | Found 10,483/11,874
# Scanned 4,300,000 docs | Found 10,666/11,874
# Scanned 4,400,000 docs | Found 10,773/11,874
# Scanned 4,500,000 docs | Found 10,921/11,874
# Scanned 4,600,000 docs | Found 11,067/11,874
# Scanned 4,700,000 docs | Found 11,169/11,874
# Scanned 4,800,000 docs | Found 11,293/11,874
# Scanned 4,900,000 docs | Found 11,447/11,874
# Scanned 5,000,000 docs | Found 11,576/11,874
# Scanned 5,100,000 docs | Found 11,704/11,874
# Scanned 5,200,000 docs | Found 11,841/11,874
# Found all target documents!
#
# ======================================================================
# CORPUS ID CHECK
# ======================================================================
# Expected: 11874
# Found   : 11874
# Missing : 0

# %% [markdown]
# Cell 7:

# %%
qrels_by_query = defaultdict(list)

for row in qrels:

    qid = str(row["query-id"])
    cid = str(row["corpus-id"])

    qrels_by_query[qid].append(cid)


print("Queries represented in qrels:", len(qrels_by_query))
# Out:
# Queries represented in qrels: 6321

# %%
from collections import Counter

num_docs_distribution = Counter(
    len(set(cids))
    for cids in qrels_by_query.values()
)

print(num_docs_distribution)
# Out:
# Counter({2: 6321})

# %% [markdown]
# Cell 8

# %%
exact_title_matches = 0
title_mismatches = []

for qid in vn_queries["id"]:

    qid = str(qid)

    original = original_by_id.get(qid)

    if original is None:
        continue

    # Gold supporting document titles từ HotpotQA original
    gold_titles = set(
        original["supporting_facts"]["title"]
    )

    # Documents mà GreenNode qrels trỏ tới
    retrieved_titles = set()

    for cid in qrels_by_query.get(qid, []):

        doc = found_docs.get(cid)

        if doc is not None:
            retrieved_titles.add(
                doc["og_title"]
            )

    if gold_titles == retrieved_titles:
        exact_title_matches += 1

    else:
        title_mismatches.append({
            "query_id": qid,
            "gold_titles": gold_titles,
            "qrels_titles": retrieved_titles
        })


total = len(vn_queries)

print("=" * 70)
print("QRELS → CORPUS → ORIGINAL TITLE CHECK")
print("=" * 70)

print("Total queries :", total)
print("Exact match   :", exact_title_matches)
print("Mismatch      :", len(title_mismatches))

print(
    "Match rate    :",
    f"{exact_title_matches/total*100:.2f}%"
)
# Out:
# ======================================================================
# QRELS → CORPUS → ORIGINAL TITLE CHECK
# ======================================================================
# Total queries : 6321
# Exact match   : 6321
# Mismatch      : 0
# Match rate    : 100.00%

# %% [markdown]
# Cell 9: Nếu có mismatch thì xem thử

# %%
for x in title_mismatches[:20]:

    print("\n" + "=" * 80)

    print("QUERY ID:")
    print(x["query_id"])

    print("\nGOLD:")
    for t in x["gold_titles"]:
        print("-", t)

    print("\nQRELS → CORPUS:")
    for t in x["qrels_titles"]:
        print("-", t)

# %% [markdown]
# cell 10: kiểm tra sâu hơn bằng cả og_text

# %%
def normalize_text(text):

    if text is None:
        return ""

    text = unicodedata.normalize(
        "NFKC",
        str(text)
    )

    text = text.lower()

    # chuẩn hóa khoảng trắng
    text = re.sub(r"\s+", " ", text)

    # bỏ khoảng trắng trước punctuation
    text = re.sub(
        r"\s+([.,!?;:])",
        r"\1",
        text
    )

    return text.strip()

# %% [markdown]
# Cell 11: so content cho toàn bộ qrels

# %%
total_qrel_checked = 0

title_found_in_original_context = 0
exact_text_match = 0
text_containment_match = 0

content_mismatches = []


for qid, corpus_ids in qrels_by_query.items():

    original = original_by_id.get(qid)

    if original is None:
        continue

    # context của chính query đó
    context_map = {}

    for title, sentences in zip(
        original["context"]["title"],
        original["context"]["sentences"]
    ):

        context_text = " ".join(sentences)

        context_map[title] = context_text

    # kiểm tra từng qrel document
    for cid in corpus_ids:

        total_qrel_checked += 1

        doc = found_docs.get(cid)

        if doc is None:
            content_mismatches.append({
                "query_id": qid,
                "corpus_id": cid,
                "reason": "corpus_id_not_found"
            })
            continue

        og_title = doc["og_title"]
        og_text = doc["og_text"]

        # title có trong original query context không?
        if og_title not in context_map:

            content_mismatches.append({
                "query_id": qid,
                "corpus_id": cid,
                "reason": "title_not_in_original_context",
                "title": og_title
            })

            continue

        title_found_in_original_context += 1

        original_text = context_map[og_title]

        a = normalize_text(og_text)
        b = normalize_text(original_text)

        # 1. exact
        if a == b:
            exact_text_match += 1
            continue

        # 2. một bản có thể dài hơn một chút
        if a in b or b in a:
            text_containment_match += 1
            continue

        content_mismatches.append({
            "query_id": qid,
            "corpus_id": cid,
            "reason": "text_difference",
            "title": og_title,
            "green_text": og_text,
            "original_text": original_text
        })


print("=" * 70)
print("FULL CONTENT MAPPING CHECK")
print("=" * 70)

print("Total qrel rows checked :", total_qrel_checked)

print(
    "Title found in original:",
    title_found_in_original_context
)

print(
    "Exact text match        :",
    exact_text_match
)

print(
    "Containment match       :",
    text_containment_match
)

print(
    "Other mismatch          :",
    len(content_mismatches)
)
# Out:
# ======================================================================
# FULL CONTENT MAPPING CHECK
# ======================================================================
# Total qrel rows checked : 12642
# Title found in original: 12642
# Exact text match        : 12467
# Containment match       : 0
# Other mismatch          : 175

# %%
for x in content_mismatches[:10]:

    print("\n")
    print("#" * 100)

    print("Query ID :", x.get("query_id"))
    print("Corpus ID:", x.get("corpus_id"))
    print("Reason   :", x.get("reason"))

    if x.get("title"):
        print("Title    :", x["title"])

    if x.get("green_text"):
        print("\nGREENNODE ORIGINAL TEXT:")
        print(x["green_text"][:1000])

    if x.get("original_text"):
        print("\nHOTPOTQA ORIGINAL CONTEXT:")
        print(x["original_text"][:1000])
# Out:
# ####################################################################################################
# Query ID : 5ae02b6c55429924de1b7044
# Corpus ID: 187479
# Reason   : text_difference
# Title    : Life (magazine)
#
# GREENNODE ORIGINAL TEXT:
# Life was an American magazine that ran weekly from 1883 to 1936 as a humor magazine with limited circulation. "Time" owner Henry Luce bought the magazine in 1936, solely so that he could acquire the rights to its name, and launched a major weekly news magazine with a strong emphasis on photojournalism. "Life" was published weekly until 1972, as an intermittent "special" until 1978, and as a monthly from 1978 to 2000.
#
# HOTPOTQA ORIGINAL CONTEXT:
# Life was an American magazine that ran weekly from 1883 to 1936 as a humor magazine with limited circulation. " Time" owner Henry Luce bought the magazine in 1936, solely so that he could acquire the rights to its name, and launched a major weekly news magazine with a strong emphasis on photojournalism.  "Life" was published weekly until 1972, as an intermittent "special" until 1978, and as a monthly from 1978 to 2000.
#
#
# ####################################################################################################
# Query ID : 5ac23ff0554299636651994d
# Corpus ID: 15549454
# Reason   : text_difference
# Title    : Shut Up, Make Love
#
# GREENNODE ORIGINAL TEXT:
# "Shut Up, Make Love" is a song by American rock band Poison; released in 2000, it was the first single presented to radio stations from their 2000 "Crack a Smile...and More!" album. The song also appears on the second promo single "Be the One" as a B-side. "Crack a Smile" is Poison's fifth studio album, released on March 14, 2000, and charting at #131 on The Billboard 200. The song was the first Poison single with lead guitarist Blues Saraceno.
#
# HOTPOTQA ORIGINAL CONTEXT:
# "Shut Up, Make Love" is a song by American rock band Poison; released in 2000, it was the first single presented to radio stations from their 2000 "Crack a Smile...and More! " album.  The song also appears on the second promo single "Be the One" as a B-side.  "Crack a Smile" is Poison's fifth studio album, released on March 14, 2000, and charting at #131 on The Billboard 200.  The song was the first Poison single with lead guitarist Blues Saraceno.
#
#
# ####################################################################################################
# Query ID : 5ac23ff0554299636651994d
# Corpus ID: 166643
# Reason   : text_difference
# Title    : Poison (American band)
#
# GREENNODE ORIGINAL TEXT:
# Poison is an American rock band that achieved great commercial success in the mid-1980s to the mid-1990s. Poison has sold over 40 million records worldwide and has sold 15 million records in the United States alone. The band has also charted ten singles to the Top 40 of the "Billboard" Hot 100, including six Top 10 singles and the Hot 100 number-one, "Every Rose Has Its Thorn". The band's breakthrough debut album, the multi-platinum "Look What the Cat Dragged In", was released in 1986 and they hit their peak with the second album, "Open Up and Say... Ahh!", which became the band's most successful album, being certified 5x platinum in the US. The popularity continued into the new decade with their third consecutive multi-platinum selling album, "Flesh & Blood".
#
# HOTPOTQA ORIGINAL CONTEXT:
# Poison is an American rock band that achieved great commercial success in the mid-1980s to the mid-1990s.  Poison has sold over 40 million records worldwide and has sold 15 million records in the United States alone.  The band has also charted ten singles to the Top 40 of the "Billboard" Hot 100, including six Top 10 singles and the Hot 100 number-one, "Every Rose Has Its Thorn".  The band's breakthrough debut album, the multi-platinum "Look What the Cat Dragged In", was released in 1986 and they hit their peak with the second album, "Open Up and Say... Ahh! ", which became the band's most successful album, being certified 5x platinum in the US.  The popularity continued into the new decade with their third consecutive multi-platinum selling album, "Flesh & Blood".
#
#
# ####################################################################################################
# Query ID : 5a7c6753554299683c1c62f9
# Corpus ID: 12330092
# Reason   : text_difference
# Title    : Girls' Generation
#
# GREENNODE ORIGINAL TEXT:
# Girls' Generation (), also known as SNSD, is a South Korean girl group formed by S.M. Entertainment. The group is composed of eight members: Taeyeon, Sunny, Tiffany, Hyoyeon, Yuri, Sooyoung, Yoona, and Seohyun. Originally a nine-piece group (with Jessica, who later departed from the group in September 2014), Girls' Generation debuted in 2007 with their Korean eponymous debut album. Though the album gained some attention, it was not until 2009 that the group rose to fame with the single "Gee", which claimed the top spot on KBS's "Music Bank" for a record-breaking nine consecutive weeks and was named the most popular song of the 2000s in South Korea by Melon. Girls' Generation further consolidated their popularity on the South Korean music scene with follow-up singles "Tell Me Your Wish (Genie)", "Oh!", and "Run Devil Run", which were released in mid-2009 and early 2010.
#
# HOTPOTQA ORIGINAL CONTEXT:
# Girls' Generation (), also known as SNSD, is a South Korean girl group formed by S.M. Entertainment.  The group is composed of eight members: Taeyeon, Sunny, Tiffany, Hyoyeon, Yuri, Sooyoung, Yoona, and Seohyun.  Originally a nine-piece group (with Jessica, who later departed from the group in September 2014), Girls' Generation debuted in 2007 with their Korean eponymous debut album.  Though the album gained some attention, it was not until 2009 that the group rose to fame with the single "Gee", which claimed the top spot on KBS's "Music Bank" for a record-breaking nine consecutive weeks and was named the most popular song of the 2000s in South Korea by Melon.  Girls' Generation further consolidated their popularity on the South Korean music scene with follow-up singles "Tell Me Your Wish (Genie)", "Oh! ", and "Run Devil Run", which were released in mid-2009 and early 2010.
#
#
# ####################################################################################################
# Query ID : 5a7698c2554299373536010d
# Corpus ID: 7954695
# Reason   : text_difference
# Title    : Ohio State Route 78
#
# GREENNODE ORIGINAL TEXT:
# State Route 78 (SR 78) is a state highway that runs for 105 miles (169 km) from Nelsonville to Clarington in the U.S. state of Ohio. "Car and Driver" has called it one of the most scenic highways nationwide. The stretch of this highway that runs along the south side of Burr Oak State Park in Morgan County, Ohio, is well known for its extreme curves and views, and is sometimes locally referred to as the "Rim of the World." Much of this highway runs through old coal-producing areas.
#
# HOTPOTQA ORIGINAL CONTEXT:
# State Route 78 (SR 78) is a state highway that runs for 105 miles (169 km) from Nelsonville to Clarington in the U.S. state of Ohio. " Car and Driver" has called it one of the most scenic highways nationwide.  The stretch of this highway that runs along the south side of Burr Oak State Park in Morgan County, Ohio, is well known for its extreme curves and views, and is sometimes locally referred to as the "Rim of the World."  Much of this highway runs through old coal-producing areas.
#
#
# ####################################################################################################
# Query ID : 5a7c6d98554299683c1c6304
# Corpus ID: 7491727
# Reason   : text_difference
# Title    : Dominic Cooper
#
# GREENNODE ORIGINAL TEXT:
# Dominic Edward Cooper (born 2 June 1978) is an English actor. He has worked in television, film, theatre and radio including "Mamma Mia!" and as the young Howard Stark in the Marvel Cinematic Universe including "" and "Agent Carter". He stars as Jesse Custer on the AMC show "Preacher" (2016–present).
#
# HOTPOTQA ORIGINAL CONTEXT:
# Dominic Edward Cooper (born 2 June 1978) is an English actor.  He has worked in television, film, theatre and radio including "Mamma Mia! " and as the young Howard Stark in the Marvel Cinematic Universe including "" and "Agent Carter".  He stars as Jesse Custer on the AMC show "Preacher" (2016–present).
#
#
# ####################################################################################################
# Query ID : 5a8081975542992097ad2fef
# Corpus ID: 17719358
# Reason   : text_difference
# Title    : Leslie Goodwins
#
# GREENNODE ORIGINAL TEXT:
# Leslie Goodwins (17 September 1899 – 8 January 1969) was an English film director and screenwriter. He directed nearly 100 films between 1926 and 1967. His 1936 film "Dummy Ache" was nominated for an Academy Award in 1936 for Best Short Subject (Two-Reel). His 1937 film "Should Wives Work?" was also nominated for an Academy Award in the same category. He was born in London, England and he died in Hollywood, California.
#
# HOTPOTQA ORIGINAL CONTEXT:
# Leslie Goodwins (17 September 1899 – 8 January 1969) was an English film director and screenwriter.  He directed nearly 100 films between 1926 and 1967.  His 1936 film "Dummy Ache" was nominated for an Academy Award in 1936 for Best Short Subject (Two-Reel).  His 1937 film "Should Wives Work? " was also nominated for an Academy Award in the same category.  He was born in London, England and he died in Hollywood, California.
#
#
# ####################################################################################################
# Query ID : 5a7652785542992db9473760
# Corpus ID: 3746481
# Reason   : text_difference
# Title    : Wolfgang Becker
#
# GREENNODE ORIGINAL TEXT:
# Wolfgang Becker (born 22 June 1954) is a German film director and writer. He is best known to the international audience for his work "Good Bye Lenin!" (2003).
#
# HOTPOTQA ORIGINAL CONTEXT:
# Wolfgang Becker (born 22 June 1954) is a German film director and writer.  He is best known to the international audience for his work "Good Bye Lenin! " (2003).
#
#
# ####################################################################################################
# Query ID : 5a8a4b9955429930ff3c0d88
# Corpus ID: 41259403
# Reason   : text_difference
# Title    : Gretel Scarlett
#
# GREENNODE ORIGINAL TEXT:
# Gretel Scarlett (born 9 November 1987) is an Australian actress and performer. Having appeared in theatre productions including "Wicked" and "Mamma Mia!", she is best known for starring as Sandy in the 2013–2015 Australian production of "Grease". In 2016, Scarlett appears as Kathy Selden in the 2016/2017 Australian production of "Singin' in the Rain" which opened at Her Majesty's Theatre, Melbourne.
#
# HOTPOTQA ORIGINAL CONTEXT:
# Gretel Scarlett (born 9 November 1987) is an Australian actress and performer.  Having appeared in theatre productions including "Wicked" and "Mamma Mia! ", she is best known for starring as Sandy in the 2013–2015 Australian production of "Grease".  In 2016, Scarlett appears as Kathy Selden in the 2016/2017 Australian production of "Singin' in the Rain" which opened at Her Majesty's Theatre, Melbourne.
#
#
# ####################################################################################################
# Query ID : 5a8193275542995ce29dcc07
# Corpus ID: 28891330
# Reason   : text_difference
# Title    : Frankenweenie (2012 film)
#
# GREENNODE ORIGINAL TEXT:
# Frankenweenie is a 2012 American 3D stop-motion-animated fantasy horror comedy film directed by Tim Burton and produced by Walt Disney Pictures. It is a remake of Burton's 1984 short film of the same name and is a parody of and a homage to the 1931 film "Frankenstein" based on Mary Shelley's book of the same name. The voice cast includes four actors who worked with Burton on previous films: Winona Ryder ("Beetlejuice" and "Edward Scissorhands"); Catherine O'Hara ("Beetlejuice" and "The Nightmare Before Christmas"); Martin Short ("Mars Attacks!"); and Martin Landau ("Ed Wood" and "Sleepy Hollow").
#
# HOTPOTQA ORIGINAL CONTEXT:
# Frankenweenie is a 2012 American 3D stop-motion-animated fantasy horror comedy film directed by Tim Burton and produced by Walt Disney Pictures.  It is a remake of Burton's 1984 short film of the same name and is a parody of and a homage to the 1931 film "Frankenstein" based on Mary Shelley's book of the same name.  The voice cast includes four actors who worked with Burton on previous films: Winona Ryder ("Beetlejuice" and "Edward Scissorhands"); Catherine O'Hara ("Beetlejuice" and "The Nightmare Before Christmas"); Martin Short ("Mars Attacks! "); and Martin Landau ("Ed Wood" and "Sleepy Hollow").

# %%
def normalize_text_strict(text):
    if text is None:
        return ""

    text = unicodedata.normalize("NFKC", str(text))

    # Một số loại whitespace đặc biệt
    text = text.replace("\xa0", " ")

    # lowercase
    text = text.lower()

    # gom whitespace
    text = re.sub(r"\s+", " ", text)

    # bỏ space ngay sau dấu quote
    text = re.sub(r'"\s+', '"', text)

    # bỏ space ngay trước dấu quote
    text = re.sub(r'\s+"', '"', text)

    # bỏ space trước punctuation
    text = re.sub(r"\s+([.,!?;:])", r"\1", text)

    return text.strip()


strict_exact = 0
strict_mismatch = []

for x in content_mismatches:

    if x["reason"] != "text_difference":
        strict_mismatch.append(x)
        continue

    green = normalize_text_strict(x["green_text"])
    original = normalize_text_strict(x["original_text"])

    if green == original:
        strict_exact += 1
    else:
        strict_mismatch.append(x)


print("=" * 70)
print("STRICT NORMALIZATION CHECK")
print("=" * 70)

print("Original text differences :", len(content_mismatches))
print("Resolved by normalization :", strict_exact)
print("Still genuinely different :", len(strict_mismatch))
# Out:
# ======================================================================
# STRICT NORMALIZATION CHECK
# ======================================================================
# Original text differences : 175
# Resolved by normalization : 146
# Still genuinely different : 29

# %%
from difflib import SequenceMatcher

print("Remaining mismatches:", len(strict_mismatch))

for i, x in enumerate(strict_mismatch[:29], start=1):

    green = normalize_text_strict(x["green_text"])
    original = normalize_text_strict(x["original_text"])

    similarity = SequenceMatcher(
        None,
        green,
        original
    ).ratio()

    print("\n" + "#" * 100)
    print("CASE", i)
    print("Query ID :", x["query_id"])
    print("Corpus ID:", x["corpus_id"])
    print("Title    :", x.get("title"))
    print(f"Similarity: {similarity:.4f}")

    print("\nGREENNODE:")
    print(x["green_text"])

    print("\nORIGINAL:")
    print(x["original_text"])
# Out:
# Remaining mismatches: 29
#
# ####################################################################################################
# CASE 1
# Query ID : 5ae78d155542994a481bbd99
# Corpus ID: 1408167
# Title    : Linux Format
# Similarity: 0.9988
#
# GREENNODE:
# Linux Format was the UK's first Linux-specific magazine, and as of 2013 was the best-selling Linux title in the UK. It is also exported to many countries worldwide. It is published by Future plc (which produces "PC Plus", ".net" and many other computer magazines). Linux Format is commonly abbreviated to LXF, and issues are referred to with LXF as a prefix followed by the issue number (for example LXF102 refers to the 102nd issue).
#
# ORIGINAL:
# Linux Format was the UK's first Linux-specific magazine, and as of 2013 was the best-selling Linux title in the UK.  It is also exported to many countries worldwide.  It is published by Future plc (which produces "PC Plus", ". net" and many other computer magazines).  Linux Format is commonly abbreviated to LXF, and issues are referred to with LXF as a prefix followed by the issue number (for example LXF102 refers to the 102nd issue).
#
# ####################################################################################################
# CASE 2
# Query ID : 5ab6390f5542995eadeeff7a
# Corpus ID: 3317022
# Title    : Cougar Bourbon
# Similarity: 0.9984
#
# GREENNODE:
# Cougar bourbon whiskey, formerly called Sam Cougar's, is a brand of bourbon whiskey produced in Lawrenceburg, Indiana. It is an export-only brand owned by Foster's Group (a division of SABMiller) that is bottled and sold in Australia and New Zealand, where it is a popular bourbon whiskey. It is sold at 37% alc./vol.
#
# ORIGINAL:
# Cougar bourbon whiskey, formerly called Sam Cougar's, is a brand of bourbon whiskey produced in Lawrenceburg, Indiana.  It is an export-only brand owned by Foster's Group (a division of SABMiller) that is bottled and sold in Australia and New Zealand, where it is a popular bourbon whiskey.  It is sold at 37% alc. /vol.
#
# ####################################################################################################
# CASE 3
# Query ID : 5ae0d52e554299603e418469
# Corpus ID: 54771039
# Title    : Dead at 17
# Similarity: 0.9957
#
# GREENNODE:
# Dead at 17 is a 2008 Canadian drama film directed by Douglas Jackson.This film has been music composed by Richard Bowers.The film stars Barbara Niven, John Bregar, Justin Bradley, Matthew Raudsepp and Kyle Switzer in the lead roles.
#
# ORIGINAL:
# Dead at 17 is a 2008 Canadian drama film directed by Douglas Jackson. This film has been music composed by Richard Bowers. The film stars Barbara Niven, John Bregar, Justin Bradley, Matthew Raudsepp and Kyle Switzer in the lead roles.
#
# ####################################################################################################
# CASE 4
# Query ID : 5ab83f9f5542990e739ec891
# Corpus ID: 39617527
# Title    : Waputik Mountains
# Similarity: 0.9987
#
# GREENNODE:
# The Waputik Mountains are a mountain range of the Canadian Rockies, located on the Continental Divide between Banff and Yoho National Park. Covering an area of 1069 sqkm , the range is located west of the Howse, Blaeberry and Amiskwi Rivers and east of the Bow and Mistaya Rivers and south to Kicking Horse Pass.Named in 1884 by George M. Dawson, "waputik" is the Stoney Indian word for white goat.
#
# ORIGINAL:
# The Waputik Mountains are a mountain range of the Canadian Rockies, located on the Continental Divide between Banff and Yoho National Park.  Covering an area of 1069 sqkm , the range is located west of the Howse, Blaeberry and Amiskwi Rivers and east of the Bow and Mistaya Rivers and south to Kicking Horse Pass. Named in 1884 by George M. Dawson, "waputik" is the Stoney Indian word for white goat.
#
# ####################################################################################################
# CASE 5
# Query ID : 5ae791245542997b22f6a7a3
# Corpus ID: 10615328
# Title    : Nikhil Nanda
# Similarity: 0.9993
#
# GREENNODE:
# Nikhil Nanda (born 18 March 1974) is an Indian businessman. Part of the Kapoor family, he is the son of insurance agent Ritu Nanda and industrialist Rajan Nanda, and the grandson of actorfilmmaker Raj Kapoor. He is the managing director of Escorts Limited, an engineering company that manufacture agricultural machinery, machine construction and material handling equipment and railway equipment. Escorts Limited was founded in 1948 by his paternal grandfather, Har Prasad Nanda (known as H.P. Nanda).The company’s corporate headquarters is in Faridabad, Haryana, India. He is married to Shweta Bachchan, the daughter of veteran actors Amitabh Bachchan and Jaya Bhaduriand has two children with her.
#
# ORIGINAL:
# Nikhil Nanda (born 18 March 1974) is an Indian businessman.  Part of the Kapoor family, he is the son of insurance agent Ritu Nanda and industrialist Rajan Nanda, and the grandson of actorfilmmaker Raj Kapoor.  He is the managing director of Escorts Limited, an engineering company that manufacture agricultural machinery, machine construction and material handling equipment and railway equipment.  Escorts Limited was founded in 1948 by his paternal grandfather, Har Prasad Nanda (known as H.P. Nanda). The company’s corporate headquarters is in Faridabad, Haryana, India.  He is married to Shweta Bachchan, the daughter of veteran actors Amitabh Bachchan and Jaya Bhaduriand has two children with her.
#
# ####################################################################################################
# CASE 6
# Query ID : 5ae3a0be5542991a06ce9a05
# Corpus ID: 48727953
# Title    : Karachi Kings
# Similarity: 0.9981
#
# GREENNODE:
# Karachi Kings (Urdu: ‎ ; Sindhi: ڪراچي ڪنگز‎ ) is a Pakistani professional Twenty20 cricket team that competes in the Pakistan Super League. The team is based in Karachi, the provincial capital of Sindh, Pakistan. The team was formed in 2015, as a result of the formation of the Pakistan Super League by Pakistan Cricket Board (PCB).Team's home ground is National Stadium.The team is currently captained by Kumar Sangakkara and coached by Mickey Arthur a former South African cricketer. It is owned by Salman Iqbal, the CEO of ARY Group.
#
# ORIGINAL:
# Karachi Kings (Urdu: ‎ ; Sindhi: ڪراچي ڪنگز‎ ) is a Pakistani professional Twenty20 cricket team that competes in the Pakistan Super League.  The team is based in Karachi, the provincial capital of Sindh, Pakistan.  The team was formed in 2015, as a result of the formation of the Pakistan Super League by Pakistan Cricket Board (PCB). Team's home ground is National Stadium. The team is currently captained by Kumar Sangakkara and coached by Mickey Arthur a former South African cricketer.  It is owned by Salman Iqbal, the CEO of ARY Group.
#
# ####################################################################################################
# CASE 7
# Query ID : 5a845b2d5542996488c2e520
# Corpus ID: 2143180
# Title    : Boyz n da Hood
# Similarity: 0.9984
#
# GREENNODE:
# Boyz N Da Hood is an American Southern gangsta rap group from Atlanta, Georgia. They were formerly signed to Sean Combs' Bad Boy Records and consisted of Young Jeezy, Jody Breeze, Gorilla Zoe, Big Gee, .Big Duke They have collaborated several times with fellow Atlanta, Georgia artist and Block Ent labelmate Yung Joc.
#
# ORIGINAL:
# Boyz N Da Hood is an American Southern gangsta rap group from Atlanta, Georgia.  They were formerly signed to Sean Combs' Bad Boy Records and consisted of Young Jeezy, Jody Breeze, Gorilla Zoe, Big Gee, . Big Duke They have collaborated several times with fellow Atlanta, Georgia artist and Block Ent labelmate Yung Joc.
#
# ####################################################################################################
# CASE 8
# Query ID : 5a865e8a55429960ec39b67a
# Corpus ID: 17514247
# Title    : 3OH!3
# Similarity: 0.9992
#
# GREENNODE:
# 3OH!3 (pronounced "three oh three") is an American electronic music duo from Boulder, Colorado, made up of Sean Foreman and Nathaniel Motte. They are best known for their single "Don't Trust Me" from their album "Want", which reached number seven on the "Billboard" Hot 100. Their second single, a remix of "Starstrukk" featuring Katy Perry from "Want", was a top ten hit in the United Kingdom, Ireland, Finland, Poland, and Australia. They gained further recognition by featuring Kesha on the song "My First Kiss", which was made the lead single from their album "Streets of Gold". The album later peaked at number seven on the "Billboard" 200.
#
# ORIGINAL:
# 3OH! 3 (pronounced "three oh three") is an American electronic music duo from Boulder, Colorado, made up of Sean Foreman and Nathaniel Motte.  They are best known for their single "Don't Trust Me" from their album "Want", which reached number seven on the "Billboard" Hot 100.  Their second single, a remix of "Starstrukk" featuring Katy Perry from "Want", was a top ten hit in the United Kingdom, Ireland, Finland, Poland, and Australia.  They gained further recognition by featuring Kesha on the song "My First Kiss", which was made the lead single from their album "Streets of Gold".  The album later peaked at number seven on the "Billboard" 200.
#
# ####################################################################################################
# CASE 9
# Query ID : 5a7c6ed3554299683c1c6306
# Corpus ID: 3692350
# Title    : Catuaba
# Similarity: 0.9990
#
# GREENNODE:
# The name catuaba (pronounced [ka.two.'aba], a Guarani word that means "what gives strength to the Indian") is used for the infusions of the bark of a number of trees native to Brazil. The most widely used barks are derived from the trees "Trichilia catigua" and "Erythroxylum vaccinifolium". Other catuaba preparations use the bark of trees from the following genera or families: "Anemopaegma", "Ilex", "Micropholis", "Phyllanthus", "Secondatia", "Tetragastris" and species from the Myrtaceae.
#
# ORIGINAL:
# The name catuaba (pronounced [ka.two. 'aba], a Guarani word that means "what gives strength to the Indian") is used for the infusions of the bark of a number of trees native to Brazil.  The most widely used barks are derived from the trees "Trichilia catigua" and "Erythroxylum vaccinifolium".  Other catuaba preparations use the bark of trees from the following genera or families: "Anemopaegma", "Ilex", "Micropholis", "Phyllanthus", "Secondatia", "Tetragastris" and species from the Myrtaceae.
#
# ####################################################################################################
# CASE 10
# Query ID : 5a8732505542991e77181713
# Corpus ID: 72297
# Title    : Lebensraum
# Similarity: 0.9991
#
# GREENNODE:
# The German concept of Lebensraum (] , English: "living space" ) refers to policies and practices of settler colonialism which proliferated in Germany from the 1890s to the 1940s. First popularized around 1901, "Lebensraum" became a geopolitical goal of Imperial Germany in World War I (1914–1918) originally, as the core element of the "Septemberprogramm" of territorial expansion.<ref name="E/N301"> </ref> The most extreme form of this ideology was supported by the Nazi Party (NSDAP) and Nazi Germany until the end of World War II.
#
# ORIGINAL:
# The German concept of Lebensraum (] , English: "living space" ) refers to policies and practices of settler colonialism which proliferated in Germany from the 1890s to the 1940s.  First popularized around 1901, "Lebensraum" became a geopolitical goal of Imperial Germany in World War I (1914–1918) originally, as the core element of the "Septemberprogramm" of territorial expansion. <ref name="E/N301"> </ref> The most extreme form of this ideology was supported by the Nazi Party (NSDAP) and Nazi Germany until the end of World War II.
#
# ####################################################################################################
# CASE 11
# Query ID : 5a8f92fb55429918e830d271
# Corpus ID: 17659968
# Title    : Sara Symington
# Similarity: 0.9996
#
# GREENNODE:
# Sara Symington (born 25 September 1969) is an English former professional cyclist. She was the first British female rider to take a medal in a World Cup race, which she achieved in Australia in 1999. She had competed as a javelin thrower as a junior, and she was a member of the national triathlon team prior to becoming a full-time cyclist. Symington started her elite triathlon career whilst combining studying for a master's degree with a spell serving in the police, having previously graduated from Loughborough University with a degree in sports science. She represented Great Britain at the 2000 and 2004 Summer Olympics and England at the 1998 & 2002.Commonwealth Games She also rode at the 1998, 1999, and 2000 UCI Road World Championships and on the track at the 2001 and 2002 UCI Track Cycling World Championships. Symington retired from competition after the 2004 Olympics: following this she worked in business for two years, before returning to the sports world through working as a performance advisor for UK Sport. She was subsequently appointed performance director of Archery GB in February 2009. In February 2015 England Netball announced that she would join them as their performance director the following month.
#
# ORIGINAL:
# Sara Symington (born 25 September 1969) is an English former professional cyclist.  She was the first British female rider to take a medal in a World Cup race, which she achieved in Australia in 1999.  She had competed as a javelin thrower as a junior, and she was a member of the national triathlon team prior to becoming a full-time cyclist.  Symington started her elite triathlon career whilst combining studying for a master's degree with a spell serving in the police, having previously graduated from Loughborough University with a degree in sports science.  She represented Great Britain at the 2000 and 2004 Summer Olympics and England at the 1998 & 2002. Commonwealth Games She also rode at the 1998, 1999, and 2000 UCI Road World Championships and on the track at the 2001 and 2002 UCI Track Cycling World Championships.  Symington retired from competition after the 2004 Olympics: following this she worked in business for two years, before returning to the sports world through working as a performance advisor for UK Sport.  She was subsequently appointed performance director of Archery GB in February 2009.  In February 2015 England Netball announced that she would join them as their performance director the following month.
#
# ####################################################################################################
# CASE 12
# Query ID : 5ab514c05542991779162d72
# Corpus ID: 9609299
# Title    : Wilmslow High School
# Similarity: 0.9987
#
# GREENNODE:
# Wilmslow High School is a mixed-sex 11–18 comprehensive secondary school in Wilmslow, Cheshire, and a designated Centre of Excellence. The school began in 1960 as a grammar school and gradually became a comprehensive school, becoming Wilmslow High School in 1991. Dr. James Pullé is the head teacher. The school is designated "good" by Ofsted.<ref name="11/13 Ofsted Report">Ofsted report</ref>
#
# ORIGINAL:
# Wilmslow High School is a mixed-sex 11–18 comprehensive secondary school in Wilmslow, Cheshire, and a designated Centre of Excellence.  The school began in 1960 as a grammar school and gradually became a comprehensive school, becoming Wilmslow High School in 1991.  Dr. James Pullé is the head teacher.  The school is designated "good" by Ofsted. <ref name="11/13 Ofsted Report">Ofsted report</ref>
#
# ####################################################################################################
# CASE 13
# Query ID : 5ab2d65e554299545a2cfabe
# Corpus ID: 223789
# Title    : Svalbard and Jan Mayen
# Similarity: 0.9992
#
# GREENNODE:
# Svalbard and Jan Mayen (Norwegian: "Svalbard og Jan Mayen" , ISO 3166-1 alpha-2: SJ, ISO 3166-1 alpha-3: SJM, ISO 3166-1 numeric: 744) is a statistical designation defined by ISO 3166-1 of two parts of Norway under separate jurisdictions—Svalbard and Jan Mayen. While the two are combined for the purposes of the International Organization for Standardization (ISO) category, they are not administratively related. This has further resulted in the country code top-level domain .sj being issued for Svalbard and Jan Mayen, and . The United Nations Statistics Division also uses this code, but has named it Svalbard and Jan Mayen Islands.
#
# ORIGINAL:
# Svalbard and Jan Mayen (Norwegian: "Svalbard og Jan Mayen" , ISO 3166-1 alpha-2: SJ, ISO 3166-1 alpha-3: SJM, ISO 3166-1 numeric: 744) is a statistical designation defined by ISO 3166-1 of two parts of Norway under separate jurisdictions—Svalbard and Jan Mayen.  While the two are combined for the purposes of the International Organization for Standardization (ISO) category, they are not administratively related.  This has further resulted in the country code top-level domain . sj being issued for Svalbard and Jan Mayen, and .  The United Nations Statistics Division also uses this code, but has named it Svalbard and Jan Mayen Islands.
#
# ####################################################################################################
# CASE 14
# Query ID : 5ae1d1995542997283cd226c
# Corpus ID: 50695685
# Title    : Ishqbaaaz
# Similarity: 0.9992
#
# GREENNODE:
# Ishqbaaaz (English: "Lovers") is an Indian drama television series which is broadcast on Star Plus. It premiered on 27 June 2016 and airs Mon-Fri 10-11pm IST.Nakuul Mehta, Kunal Jaisingh and Leenesh Mattoo respectively portray Shivaay, Omkara and Rudra, the three heirs of the Oberoi family. The show initially focused on the tale of three brothers, later become centered on the love story of Shivaay and Annika (Surbhi Chandna); with the story of Omkara and Rudra being shifted to the spinoff series "Dil Boley Oberoi". In July 2017 "Dil Boley Oberoi" ended and the storylines were merged back into "Ishqbaaaz" which doubled its runtime.
#
# ORIGINAL:
# Ishqbaaaz (English: "Lovers") is an Indian drama television series which is broadcast on Star Plus.  It premiered on 27 June 2016 and airs Mon-Fri 10-11pm IST. Nakuul Mehta, Kunal Jaisingh and Leenesh Mattoo respectively portray Shivaay, Omkara and Rudra, the three heirs of the Oberoi family.  The show initially focused on the tale of three brothers, later become centered on the love story of Shivaay and Annika (Surbhi Chandna); with the story of Omkara and Rudra being shifted to the spinoff series "Dil Boley Oberoi".  In July 2017 "Dil Boley Oberoi" ended and the storylines were merged back into "Ishqbaaaz" which doubled its runtime.
#
# ####################################################################################################
# CASE 15
# Query ID : 5a7cf4e355429907fabef062
# Corpus ID: 53445585
# Title    : Eldridge Industries
# Similarity: 0.9983
#
# GREENNODE:
# Eldridge Industries, LLC is a Private equity investment holdings firm owned by Todd Boehly, the former president of Guggenheim Partners.The company was formed via the corporate spin-off of the media properties of Guggenheim subsidiary Prometheus Global Media announced on December 17, 2015.
#
# ORIGINAL:
# Eldridge Industries, LLC is a Private equity investment holdings firm owned by Todd Boehly, the former president of Guggenheim Partners. The company was formed via the corporate spin-off of the media properties of Guggenheim subsidiary Prometheus Global Media announced on December 17, 2015.
#
# ####################################################################################################
# CASE 16
# Query ID : 5ae32fc655429928c423965d
# Corpus ID: 24091955
# Title    : Siegi Sessler
# Similarity: 0.9996
#
# GREENNODE:
# Siegi Sessler (9 September 1910 - 1 April 1969) was a prominent London restaurateur and club owner in the mid-20th century.He started club life after the Second World War, and opened Siegi's Club in 1950 at 46 Charles Street in London's Mayfair area. Siegi's became the first of the Mayfair establishments, later among Claremont Club, Annabel's, Tramp, Harry's Bar and The Colony Club. It was well known to be the 'home away from home' for Hollywood stars, such as Frank Sinatra, Humphrey Bogart, Bob Hope, Crosby, Niven, Brando, Monroe, John Wayne, Cary Grant, Bette Davis, Clark Gable, Doris Day, Joan Crawford, Ingrid Bergman and Elizabeth Taylor. It was described as "a sort of Madame Tussauds for live people... a safe haven for the friendless and a place impossible to leave, without a pocketful of introductions, for all four corners of the globe. You may not have wanted to lunch with Brando in LA, or safari with William Holden, at his Mt. Kenya Safari Club, however once out of the door, you were committed and often compelled to be their house guests, although a stranger...and you may have only popped in for a night cap before bed!" by columnist Marjorie Proops.
#
# ORIGINAL:
# Siegi Sessler (9 September 1910 - 1 April 1969) was a prominent London restaurateur and club owner in the mid-20th century. He started club life after the Second World War, and opened Siegi's Club in 1950 at 46 Charles Street in London's Mayfair area.  Siegi's became the first of the Mayfair establishments, later among Claremont Club, Annabel's, Tramp, Harry's Bar and The Colony Club.  It was well known to be the 'home away from home' for Hollywood stars, such as Frank Sinatra, Humphrey Bogart, Bob Hope, Crosby, Niven, Brando, Monroe, John Wayne, Cary Grant, Bette Davis, Clark Gable, Doris Day, Joan Crawford, Ingrid Bergman and Elizabeth Taylor.  It was described as "a sort of Madame Tussauds for live people... a safe haven for the friendless and a place impossible to leave, without a pocketful of introductions, for all four corners of the globe.  You may not have wanted to lunch with Brando in LA, or safari with William Holden, at his Mt. Kenya Safari Club, however once out of the door, you were committed and often compelled to be their house guests, although a stranger...and you may have only popped in for a night cap before bed!"  by columnist Marjorie Proops.
#
# ####################################################################################################
# CASE 17
# Query ID : 5abe84a95542991f6610619b
# Corpus ID: 7827567
# Title    : The Great American Dream Machine
# Similarity: 0.9991
#
# GREENNODE:
# The Great American Dream Machine was a weekly satirical variety television series, produced in New York City by WNET and broadcast on PBS from 1971 to 1972.The program was hosted by humorist and commentator Marshall Efron. Other notable cast members included Chevy Chase and contributors included Albert Brooks, Paul Jacobs, and Andy Rooney. The show centered on skits and satirical political commentary. The hour and a half long show usually contained at least seven different current event topics. In the second season, the show was trimmed down to an hour.
#
# ORIGINAL:
# The Great American Dream Machine was a weekly satirical variety television series, produced in New York City by WNET and broadcast on PBS from 1971 to 1972. The program was hosted by humorist and commentator Marshall Efron.  Other notable cast members included Chevy Chase and contributors included Albert Brooks, Paul Jacobs, and Andy Rooney.  The show centered on skits and satirical political commentary.  The hour and a half long show usually contained at least seven different current event topics.  In the second season, the show was trimmed down to an hour.
#
# ####################################################################################################
# CASE 18
# Query ID : 5addfdf65542992200553bd2
# Corpus ID: 54925712
# Title    : The Last Run (2004 film)
# Similarity: 0.9963
#
# GREENNODE:
# The Last Run is a 2004 American drama and comedy film directed by Jonathan Segal.The film has been music composed by Laura Karpman.This film starring Fred Savage, Amy Adams, Steven Pasquale, Andrea Bogart, Erinn Bartlett, Vyto Ruginis and Robert Romanus in the lead roles.
#
# ORIGINAL:
# The Last Run is a 2004 American drama and comedy film directed by Jonathan Segal. The film has been music composed by Laura Karpman. This film starring Fred Savage, Amy Adams, Steven Pasquale, Andrea Bogart, Erinn Bartlett, Vyto Ruginis and Robert Romanus in the lead roles.
#
# ####################################################################################################
# CASE 19
# Query ID : 5ab82fe155429919ba4e225a
# Corpus ID: 52260473
# Title    : PPA, Pattugliatori Polivalenti d'Altura
# Similarity: 0.9960
#
# GREENNODE:
# PPA, Pattugliatore Polivalente d'Altura (Offshore Multipurpose Patrol Ship) is a new Frigate class of the Italian Navy.<br>
#
# ORIGINAL:
# PPA, Pattugliatore Polivalente d'Altura (Offshore Multipurpose Patrol Ship) is a new Frigate class of the Italian Navy. <br>
#
# ####################################################################################################
# CASE 20
# Query ID : 5ade69e455429975fa854ec5
# Corpus ID: 18850187
# Title    : 1920 (film)
# Similarity: 0.9992
#
# GREENNODE:
# 1920 is a 2008 Indian horror film written and directed by Vikram Bhatt. Filmed in Hindi, the film revolves around the events surrounding a married couple living in a haunted house in the year 1920. The film stars debutant actors Rajneesh Duggal and Adah Sharma as the married couple and Indraneil Sengupta in a special role. The film is the first installment of the 1920 (film series), which was a critical and commercial success. The film was also dubbed into Telugu as "1920 Gayathri". A sequel, "", was also released to mixed reviews and commercial success in 2012.The film is loosely inspired from the 1973 horror cult classic The Exorcist.
#
# ORIGINAL:
# 1920 is a 2008 Indian horror film written and directed by Vikram Bhatt.  Filmed in Hindi, the film revolves around the events surrounding a married couple living in a haunted house in the year 1920.  The film stars debutant actors Rajneesh Duggal and Adah Sharma as the married couple and Indraneil Sengupta in a special role.  The film is the first installment of the 1920 (film series), which was a critical and commercial success.  The film was also dubbed into Telugu as "1920 Gayathri".  A sequel, "", was also released to mixed reviews and commercial success in 2012. The film is loosely inspired from the 1973 horror cult classic The Exorcist.
#
# ####################################################################################################
# CASE 21
# Query ID : 5a7264ed5542990c210a411a
# Corpus ID: 72297
# Title    : Lebensraum
# Similarity: 0.9991
#
# GREENNODE:
# The German concept of Lebensraum (] , English: "living space" ) refers to policies and practices of settler colonialism which proliferated in Germany from the 1890s to the 1940s. First popularized around 1901, "Lebensraum" became a geopolitical goal of Imperial Germany in World War I (1914–1918) originally, as the core element of the "Septemberprogramm" of territorial expansion.<ref name="E/N301"> </ref> The most extreme form of this ideology was supported by the Nazi Party (NSDAP) and Nazi Germany until the end of World War II.
#
# ORIGINAL:
# The German concept of Lebensraum (] , English: "living space" ) refers to policies and practices of settler colonialism which proliferated in Germany from the 1890s to the 1940s.  First popularized around 1901, "Lebensraum" became a geopolitical goal of Imperial Germany in World War I (1914–1918) originally, as the core element of the "Septemberprogramm" of territorial expansion. <ref name="E/N301"> </ref> The most extreme form of this ideology was supported by the Nazi Party (NSDAP) and Nazi Germany until the end of World War II.
#
# ####################################################################################################
# CASE 22
# Query ID : 5abda6e955429965af743d9b
# Corpus ID: 50972525
# Title    : Ogwini Comprehensive Technical High School
# Similarity: 0.9976
#
# GREENNODE:
# Ogwini Comprehensive Technical High School is located at Umlazi, KwaZulu-Natal, South Africa, located south-west of Durban. It had 3149 registered students in 2014.it is known for its good performance s in exams.
#
# ORIGINAL:
# Ogwini Comprehensive Technical High School is located at Umlazi, KwaZulu-Natal, South Africa, located south-west of Durban.  It had 3149 registered students in 2014. it is known for its good performance s in exams.
#
# ####################################################################################################
# CASE 23
# Query ID : 5adcd28c5542994d58a2f6ea
# Corpus ID: 36955268
# Title    : Paul Cheesbrough
# Similarity: 0.9985
#
# GREENNODE:
# Paul Cheesbrough is a British Media Executive and is Chief Technology Officer of Rupert Murdoch's News Corp. He has responsibility for all the Technology in the company and also focussed on the separation of News Corporation into two separate businesses in 2013 and works for Robert Thomson after initially working directly for Murdoch.[1]
#
# ORIGINAL:
# Paul Cheesbrough is a British Media Executive and is Chief Technology Officer of Rupert Murdoch's News Corp.  He has responsibility for all the Technology in the company and also focussed on the separation of News Corporation into two separate businesses in 2013 and works for Robert Thomson after initially working directly for Murdoch. [1]
#
# ####################################################################################################
# CASE 24
# Query ID : 5ab3357d554299166977419d
# Corpus ID: 15060491
# Title    : Sterlite Industries
# Similarity: 0.9981
#
# GREENNODE:
# Sterlite Industries (India) Ltd. is a subsidiary of Vedanta Resources plc, a diversified and integrated metals and mining group. The company is based in Mumbai, India. On 31 March 2013, the company's market capitalisation was INR 31,490 crores (US$ 5.79 billion).<br>
#
# ORIGINAL:
# Sterlite Industries (India) Ltd. is a subsidiary of Vedanta Resources plc, a diversified and integrated metals and mining group.  The company is based in Mumbai, India.  On 31 March 2013, the company's market capitalisation was INR 31,490 crores (US$ 5.79 billion). <br>
#
# ####################################################################################################
# CASE 25
# Query ID : 5a73cbe4554299623ed4ac5f
# Corpus ID: 4712384
# Title    : Tom Mandrake
# Similarity: 0.9986
#
# GREENNODE:
# Tom Mandrake (born May 26, 1956) is an American comics artist, perhaps best known for his collaborations with writer John Ostrander on several series, including "Grimjack" (from First Comics) and "Firestorm", "The Spectre", and "Martian Manhunter" from DC Comics.<ref name="John/Tom">John Ostrander and Tom Mandrake collaborations at the Grand Comics Database</ref>
#
# ORIGINAL:
# Tom Mandrake (born May 26, 1956) is an American comics artist, perhaps best known for his collaborations with writer John Ostrander on several series, including "Grimjack" (from First Comics) and "Firestorm", "The Spectre", and "Martian Manhunter" from DC Comics. <ref name="John/Tom">John Ostrander and Tom Mandrake collaborations at the Grand Comics Database</ref>
#
# ####################################################################################################
# CASE 26
# Query ID : 5a8eb63455429917b4a5bdb7
# Corpus ID: 48462055
# Title    : Jonny Browning
# Similarity: 0.9994
#
# GREENNODE:
# Jonny Browning is an American instrumental surf musician, primarily known as touring guitarist Victor Vector for the band Man or Astro-Man? Prior to his performing in the band, he also played the part of Chromo-Crunch in Man or Astro-Man?: Clone Project Alpha in 1997-1998. He has played guitar and written songs for Sound of Humans (also featuring Birdstuff of Man or Astro-Man?), Jonny and the Shamen, and The Man Made Brain. He currently plays guitar and writes for Canadian instrumental surf band The Other Timelines. Jonny has played in bands or recorded with members of many other bands, including: St. Vincent, The Polyphonic Spree, Drive-By Truckers, And You Will Know Us By The Trail Of Dead, Verbena, and Servotron. He was born and raised in Alabama and has resided in Vancouver, BC since 2009.
#
# ORIGINAL:
# Jonny Browning is an American instrumental surf musician, primarily known as touring guitarist Victor Vector for the band Man or Astro-Man?  Prior to his performing in the band, he also played the part of Chromo-Crunch in Man or Astro-Man? : Clone Project Alpha in 1997-1998.  He has played guitar and written songs for Sound of Humans (also featuring Birdstuff of Man or Astro-Man? ), Jonny and the Shamen, and The Man Made Brain.  He currently plays guitar and writes for Canadian instrumental surf band The Other Timelines.  Jonny has played in bands or recorded with members of many other bands, including: St. Vincent, The Polyphonic Spree, Drive-By Truckers, And You Will Know Us By The Trail Of Dead, Verbena, and Servotron.  He was born and raised in Alabama and has resided in Vancouver, BC since 2009.
#
# ####################################################################################################
# CASE 27
# Query ID : 5abd0814554299700f9d797a
# Corpus ID: 1343137
# Title    : Ballymena United F.C.
# Similarity: 0.9983
#
# GREENNODE:
# Ballymena United Football Club is a semi-professional football club from Northern Ireland. Based in Ballymena, County Antrim, the team competes in the NIFL Premiership and plays home matches at the Ballymena Showgrounds.The club is managed by iconic Irish League player/manager David Jeffrey.
#
# ORIGINAL:
# Ballymena United Football Club is a semi-professional football club from Northern Ireland.  Based in Ballymena, County Antrim, the team competes in the NIFL Premiership and plays home matches at the Ballymena Showgrounds. The club is managed by iconic Irish League player/manager David Jeffrey.
#
# ####################################################################################################
# CASE 28
# Query ID : 5a89810655429946c8d6e929
# Corpus ID: 18560256
# Title    : Atherton Bridge
# Similarity: 0.9991
#
# GREENNODE:
# The Atherton Bridge is a historic iron truss bridge in Lancaster, Massachusetts, spanning the South Branch of the Nashua River. It is a rare example of a hybrid pony truss that is similar to the 19th century truss design of Simeon S. Post. It was built by J.H. Cofrode & Co. of Philadelphia in 1870. It was the first iron bridge to be constructed in the town.<ref name="memory.loc.gov/cgi-bin/query/D?hh:1:./temp/~ammem_Pr5I::">Historic American Engineering Record</ref> The bridge was added to the National Register of Historic Places in 1979.
#
# ORIGINAL:
# The Atherton Bridge is a historic iron truss bridge in Lancaster, Massachusetts, spanning the South Branch of the Nashua River.  It is a rare example of a hybrid pony truss that is similar to the 19th century truss design of Simeon S. Post.  It was built by J.H. Cofrode & Co. of Philadelphia in 1870.  It was the first iron bridge to be constructed in the town. <ref name="memory.loc.gov/cgi-bin/query/D?hh:1:./temp/~ammem_Pr5I::">Historic American Engineering Record</ref> The bridge was added to the National Register of Historic Places in 1979.
#
# ####################################################################################################
# CASE 29
# Query ID : 5ac2efd65542990b17b154c7
# Corpus ID: 47847345
# Title    : Bigg Boss 10
# Similarity: 0.9988
#
# GREENNODE:
# Bigg Boss 10 is the tenth season of the Indian reality TV series "Bigg Boss". It began airing on 16 October 2016 on Colors. The show is also available after the original telecast on Viacom 18's digital platform – Voot. A new element called ‘Unseen-Undekha’ was introduced by way of unseen footage uploaded on Voot.This footage showed parts of the day that weren’t included in the episode, from ‘wake-up call’ to ‘lights out’.
#
# ORIGINAL:
# Bigg Boss 10 is the tenth season of the Indian reality TV series "Bigg Boss".  It began airing on 16 October 2016 on Colors.  The show is also available after the original telecast on Viacom 18's digital platform – Voot.  A new element called ‘Unseen-Undekha’ was introduced by way of unseen footage uploaded on Voot. This footage showed parts of the day that weren’t included in the episode, from ‘wake-up call’ to ‘lights out’.

# %%
from datasets import load_dataset

VN_REPO = "GreenNode/hotpotqa-vn"

vn_corpus_stream = load_dataset(
    VN_REPO,
    "corpus",
    split="test",
    streaming=True
)

count = 0
unique_ids = set()

for row in vn_corpus_stream:
    count += 1
    unique_ids.add(str(row["id"]))

print("Total corpus rows :", count)
print("Unique corpus IDs :", len(unique_ids))
print("Duplicate IDs     :", count - len(unique_ids))
# Out:
# Total corpus rows : 5233329
# Unique corpus IDs : 5233329
# Duplicate IDs     : 0

# %% [markdown]
# # A. Tạo corpus cho 1000 query

# %% [markdown]
# ## Cell A1.

# %%
import random
import re
import json
import unicodedata
from collections import Counter, defaultdict
from datasets import load_dataset

VN_REPO = "GreenNode/hotpotqa-vn"
EN_REPO = "hotpotqa/hotpot_qa"

SEED = 42
N_QUERIES = 1000

# Vietnamese
vn_queries = load_dataset(
    VN_REPO, "queries", split="test"
)

qrels = load_dataset(
    VN_REPO, "qrels", split="test"
)

# Original
hotpot_train = load_dataset(
    EN_REPO, "distractor", split="train"
)

hotpot_val = load_dataset(
    EN_REPO, "distractor", split="validation"
)

original_by_id = {}

for row in hotpot_train:
    original_by_id[str(row["id"])] = row

for row in hotpot_val:
    original_by_id[str(row["id"])] = row

vn_by_id = {
    str(row["id"]): row
    for row in vn_queries
}

# random cố định
all_ids = [str(x) for x in vn_queries["id"]]

rng = random.Random(SEED)
selected_ids = rng.sample(all_ids, N_QUERIES)

selected_id_set = set(selected_ids)

print("Selected queries:", len(selected_ids))
print("Seed:", SEED)
# Out:
# Selected queries: 1000
# Seed: 42

# %% [markdown]
# ## Cell A2. lấy toàn bộ context của 1000 query

# %%
def canonical(text):
    """
    Normalize mạnh để match GreenNode og_text
    với HotpotQA original dù khác whitespace.
    """
    if text is None:
        return ""

    text = unicodedata.normalize("NFKC", str(text))
    text = text.casefold()

    # loại toàn bộ whitespace
    text = re.sub(r"\s+", "", text)

    return text


target_contexts = {}
context_keys_by_query = defaultdict(list)

context_counts = []

for qid in selected_ids:

    row = original_by_id[qid]

    titles = row["context"]["title"]
    sentence_lists = row["context"]["sentences"]

    context_counts.append(len(titles))

    for title, sentences in zip(titles, sentence_lists):

        text = " ".join(sentences).strip()

        key = (
            canonical(title),
            canonical(text)
        )

        context_keys_by_query[qid].append(key)

        if key not in target_contexts:
            target_contexts[key] = {
                "title_en": title,
                "text_en": text
            }


print("Questions:", len(selected_ids))
print("Context occurrences:", sum(context_counts))
print("Unique contexts after dedup:", len(target_contexts))

print("\nContexts/query distribution:")
print(Counter(context_counts))
# Out:
# Questions: 1000
# Context occurrences: 9967
# Unique contexts after dedup: 9822
#
# Contexts/query distribution:
# Counter({10: 995, 2: 3, 6: 1, 5: 1})

# %% [markdown]
# ## Cell A3. Map các context sang tiếng Việt

# %%
vn_corpus_stream = load_dataset(
    VN_REPO,
    "corpus",
    split="test",
    streaming=True
)

mapped_contexts = {}

target_keys = set(target_contexts.keys())

for i, row in enumerate(vn_corpus_stream, start=1):

    key = (
        canonical(row["og_title"]),
        canonical(row["og_text"])
    )

    if key in target_keys and key not in mapped_contexts:

        mapped_contexts[key] = {
            "id": str(row["id"]),
            "title": row["title"],
            "text": row["text"],
            "og_title": row["og_title"],
            "og_text": row["og_text"]
        }

    if len(mapped_contexts) == len(target_keys):
        print("Found all contexts!")
        break

    if i % 100000 == 0:
        print(
            f"Scanned {i:,} | "
            f"Found {len(mapped_contexts):,}/{len(target_keys):,}"
        )


print("\n" + "=" * 70)
print("CONTEXT MAPPING")
print("=" * 70)

print("Expected:", len(target_keys))
print("Found   :", len(mapped_contexts))
print("Missing :", len(target_keys) - len(mapped_contexts))

print(
    "Rate    :",
    f"{len(mapped_contexts)/len(target_keys)*100:.2f}%"
)
# Out:
# Scanned 100,000 | Found 543/9,822
# Scanned 200,000 | Found 1,048/9,822
# Scanned 300,000 | Found 1,451/9,822
# Scanned 400,000 | Found 1,754/9,822
# Scanned 500,000 | Found 2,098/9,822
# Scanned 600,000 | Found 2,234/9,822
# Scanned 700,000 | Found 2,386/9,822
# Scanned 800,000 | Found 2,552/9,822
# Scanned 900,000 | Found 2,712/9,822
# Scanned 1,000,000 | Found 2,863/9,822
# Scanned 1,100,000 | Found 3,027/9,822
# Scanned 1,200,000 | Found 3,174/9,822
# Scanned 1,300,000 | Found 3,326/9,822
# Scanned 1,400,000 | Found 3,494/9,822
# Scanned 1,500,000 | Found 3,632/9,822
# Scanned 1,600,000 | Found 3,789/9,822
# Scanned 1,700,000 | Found 3,913/9,822
# Scanned 1,800,000 | Found 4,041/9,822
# Scanned 1,900,000 | Found 4,191/9,822
# Scanned 2,000,000 | Found 4,317/9,822
# Scanned 2,100,000 | Found 4,438/9,822
# Scanned 2,200,000 | Found 4,577/9,822
# Scanned 2,300,000 | Found 4,730/9,822
# Scanned 2,400,000 | Found 4,874/9,822
# Scanned 2,500,000 | Found 5,028/9,822
# Scanned 2,600,000 | Found 5,172/9,822
# Scanned 2,700,000 | Found 5,315/9,822
# Scanned 2,800,000 | Found 5,472/9,822
# Scanned 2,900,000 | Found 5,624/9,822
# Scanned 3,000,000 | Found 5,757/9,822
# Scanned 3,100,000 | Found 6,080/9,822
# Scanned 3,200,000 | Found 6,346/9,822
# Scanned 3,300,000 | Found 6,572/9,822
# Scanned 3,400,000 | Found 6,728/9,822
# Scanned 3,500,000 | Found 6,887/9,822
# Scanned 3,600,000 | Found 7,115/9,822
# Scanned 3,700,000 | Found 7,339/9,822
# Scanned 3,800,000 | Found 7,551/9,822
# Scanned 3,900,000 | Found 7,744/9,822
# Scanned 4,000,000 | Found 7,935/9,822
# Scanned 4,100,000 | Found 8,125/9,822
# Scanned 4,200,000 | Found 8,298/9,822
# Scanned 4,300,000 | Found 8,502/9,822
# Scanned 4,400,000 | Found 8,644/9,822
# Scanned 4,500,000 | Found 8,782/9,822
# Scanned 4,600,000 | Found 8,935/9,822
# Scanned 4,700,000 | Found 9,058/9,822
# Scanned 4,800,000 | Found 9,192/9,822
# Scanned 4,900,000 | Found 9,376/9,822
# Scanned 5,000,000 | Found 9,488/9,822
# Scanned 5,100,000 | Found 9,636/9,822
# Scanned 5,200,000 | Found 9,775/9,822
# Found all contexts!
#
# ======================================================================
# CONTEXT MAPPING
# ======================================================================
# Expected: 9822
# Found   : 9822
# Missing : 0
# Rate    : 100.00%

# %% [markdown]
# ## Cell A4. Tạo shared Vietnamese corpus

# %%
final_corpus = {}

for key, doc in mapped_contexts.items():
    final_corpus[doc["id"]] = doc

print("Final unique Vietnamese corpus docs:", len(final_corpus))
# Out:
# Final unique Vietnamese corpus docs: 9822

# %% [markdown]
# ## Cell A5. Map từng query sang 10 context IDs

# %%
context_doc_ids_by_query = defaultdict(list)

missing_context_links = []

for qid in selected_ids:

    for key in context_keys_by_query[qid]:

        doc = mapped_contexts.get(key)

        if doc is None:
            missing_context_links.append((qid, key))
        else:
            context_doc_ids_by_query[qid].append(
                doc["id"]
            )


print("Missing query-context mappings:",
      len(missing_context_links))

print("\nExample:")
qid = selected_ids[0]

print("Query:", vn_by_id[qid]["text"])
print("Number of contexts:",
      len(context_doc_ids_by_query[qid]))
print("IDs:", context_doc_ids_by_query[qid])
# Out:
# Missing query-context mappings: 0
#
# Example:
# Query: Tội phạm nào sẽ bị trừng phạt bằng hình thức án tù mà bà Le Corbeau đã nhận được ở Canada?
# Number of contexts: 10
# IDs: ['2678295', '2850017', '41848237', '26788313', '46565227', '54305013', '5902', '42694255', '27634465', '3653768']

# %% [markdown]
# ## Cell A6.

# %%
selected_qrels = []

qrels_by_query = defaultdict(list)

for row in qrels:

    qid = str(row["query-id"])

    if qid in selected_id_set:

        cid = str(row["corpus-id"])

        selected_qrels.append({
            "query_id": qid,
            "corpus_id": cid,
            "score": int(row["score"])
        })

        qrels_by_query[qid].append(cid)


print("Selected qrels:", len(selected_qrels))

print(
    "Relevant docs/query:",
    Counter(
        len(x)
        for x in qrels_by_query.values()
    )
)
# Out:
# Selected qrels: 2000
# Relevant docs/query: Counter({2: 1000})

# %% [markdown]
# ## Cell A7. Kiểm tra 2 gold docs có nằm trong final corpus không

# %%
missing_gold = []

for row in selected_qrels:

    if row["corpus_id"] not in final_corpus:
        missing_gold.append(row)


print("Missing gold documents:", len(missing_gold))
# Out:
# Missing gold documents: 0

# %% [markdown]
# # B. Bổ sung metadata từ HotpotQA gốc

# %% [markdown]
# ## Cell B1. Tạo records cho 1.000 queries

# %%
query_records = []

for qid in selected_ids:

    en = original_by_id[qid]
    vi = vn_by_id[qid]

    supporting_facts = []

    for title, sent_id in zip(
        en["supporting_facts"]["title"],
        en["supporting_facts"]["sent_id"]
    ):
        supporting_facts.append({
            "title": title,
            "sent_id": int(sent_id)
        })

    query_records.append({
        "id": qid,

        "question_vi": vi["text"],
        "question_en": en["question"],

        "answer_en": en["answer"],

        "type": en["type"],
        "level": en["level"],

        "gold_doc_ids": qrels_by_query[qid],

        "context_doc_ids":
            context_doc_ids_by_query[qid],

        "supporting_facts":
            supporting_facts
    })


print("Query records:", len(query_records))
print(query_records[0])
# Out:
# Query records: 1000
# {'id': '5a73d33e5542992d56e7e3a9', 'question_vi': 'Tội phạm nào sẽ bị trừng phạt bằng hình thức án tù mà bà Le Corbeau đã nhận được ở Canada?', 'question_en': 'What is a crime that is punishable by the type of sentence that Madame Le Corbeau received in Canada?', 'answer_en': 'capital crimes or capital offences', 'type': 'bridge', 'level': 'hard', 'gold_doc_ids': ['27634465', '5902'], 'context_doc_ids': ['2678295', '2850017', '41848237', '26788313', '46565227', '54305013', '5902', '42694255', '27634465', '3653768'], 'supporting_facts': [{'title': 'Madame le Corbeau', 'sent_id': 1}, {'title': 'Capital punishment', 'sent_id': 2}]}

# %% [markdown]
# # C. Flow tạo answer_vi

# %% [markdown]
# ## Cell C1 — Tạo text của 2 gold docs cho mỗi query

# %%
gold_text_vi_by_query = {}

for qid in selected_ids:

    texts = []

    for cid in qrels_by_query[qid]:

        doc = final_corpus[cid]

        texts.append(
            f"{doc['title']}\n{doc['text']}"
        )

    gold_text_vi_by_query[qid] = "\n".join(texts)

# %% [markdown]
# ## Cell C2 — Rule xử lý answer đơn giản trước

# %%
def normalize_match(text):
    if text is None:
        return ""

    text = unicodedata.normalize(
        "NFKC",
        str(text)
    )

    text = text.casefold()
    text = re.sub(r"\s+", " ", text)

    return text.strip()


answer_results = {}
need_translation = []


for record in query_records:

    qid = record["id"]
    answer_en = record["answer_en"].strip()

    a = normalize_match(answer_en)

    gold_vi = normalize_match(
        gold_text_vi_by_query[qid]
    )

    # YES / NO
    if a == "yes":

        answer_results[qid] = {
            "answer_vi": "có",
            "method": "rule_yes_no",
            "confidence": "high",
            "needs_review": False
        }

    elif a == "no":

        answer_results[qid] = {
            "answer_vi": "không",
            "method": "rule_yes_no",
            "confidence": "high",
            "needs_review": False
        }

    # Nếu answer tiếng Anh vẫn xuất hiện nguyên văn
    # trong Vietnamese passage -> thường proper noun/number
    elif len(a) >= 3 and a in gold_vi:

        answer_results[qid] = {
            "answer_vi": answer_en,
            "method": "exact_span_existing",
            "confidence": "high",
            "needs_review": False
        }

    else:
        need_translation.append(record)


print("Solved automatically:",
      len(answer_results))

print("Need translation:",
      len(need_translation))
# Out:
# Solved automatically: 597
# Need translation: 403

# %% [markdown]
# ## C3 — Dịch các answer còn lại bằng NLLB

# %%
# !pip -q install transformers sentencepiece accelerate

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

MODEL_NAME = "facebook/nllb-200-distilled-600M"

device = (
    "cuda"
    if torch.cuda.is_available()
    else "cpu"
)

print("Device:", device)

tokenizer = AutoTokenizer.from_pretrained(
    MODEL_NAME
)

model = AutoModelForSeq2SeqLM.from_pretrained(
    MODEL_NAME
).to(device)

tokenizer.src_lang = "eng_Latn"

VI_TOKEN = tokenizer.convert_tokens_to_ids(
    "vie_Latn"
)
# Out:
# Device: cuda
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model: reconstructing file:   0%|          |  0.00B / 4.85MB
# sentencepiece.bpe.model: downloading bytes:           |  0.00B
# tokenizer.json: reconstructing file:   0%|          |  0.00B / 17.3MB
# tokenizer.json: downloading bytes:           |  0.00B
# special_tokens_map.json:   0%|          | 0.00/3.55k [00:00<?, ?B/s]
# pytorch_model.bin: reconstructing file:   0%|          |  0.00B / 2.46GB
# pytorch_model.bin: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/512 [00:00<?, ?it/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 2.46GB
# model.safetensors: downloading bytes:           |  0.00B
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]

# %% [markdown]
# ## Cell C4. Batch translation

# %%
def translate_batch(texts, batch_size=32):

    outputs = []

    for start in range(
        0,
        len(texts),
        batch_size
    ):

        batch = texts[
            start:start + batch_size
        ]

        inputs = tokenizer(
            batch,
            return_tensors="pt",
            padding=True,
            truncation=True,
            max_length=64
        ).to(device)

        with torch.no_grad():

            generated = model.generate(
                **inputs,
                forced_bos_token_id=VI_TOKEN,
                max_new_tokens=32
            )

        translated = tokenizer.batch_decode(
            generated,
            skip_special_tokens=True
        )

        outputs.extend(translated)

    return outputs

# %%
answers_to_translate = [
    r["answer_en"]
    for r in need_translation
]

translated_answers = translate_batch(
    answers_to_translate
)

print(
    "Translated:",
    len(translated_answers)
)
# Out:
# [transformers] Both `max_new_tokens` (=32) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=32) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=32) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=32) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=32) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=32) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=32) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=32) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=32) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=32) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=32) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=32) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Both `max_new_tokens` (=32) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Translated: 403

# %% [markdown]
# ## Cell C5. Kiểm tra candidate có nằm trong gold Vietnamese evidence không

# %%
for record, candidate in zip(
    need_translation,
    translated_answers
):

    qid = record["id"]

    candidate = candidate.strip()

    candidate_norm = normalize_match(candidate)

    gold_norm = normalize_match(
        gold_text_vi_by_query[qid]
    )

    if (
        len(candidate_norm) >= 2
        and candidate_norm in gold_norm
    ):

        confidence = "high"
        review = False
        method = "translated_exact_span"

    else:

        confidence = "medium"
        review = True
        method = "translated_non_extractive"

    answer_results[qid] = {
        "answer_vi": candidate,
        "method": method,
        "confidence": confidence,
        "needs_review": review
    }

# %% [markdown]
# ## Cell C6 — Gắn answer_vi vào records

# %%
final_queries = []

for record in query_records:

    result = answer_results[
        record["id"]
    ]

    new_record = record.copy()

    new_record.update({
        "answer_vi":
            result["answer_vi"],

        "answer_vi_method":
            result["method"],

        "answer_vi_confidence":
            result["confidence"],

        "answer_vi_needs_review":
            result["needs_review"]
    })

    final_queries.append(new_record)


print("Final queries:", len(final_queries))
# Out:
# Final queries: 1000

# %% [markdown]
# ## Cell C7 — Thống kê quality của answer_vi

# %%
print("Answer methods:")

print(
    Counter(
        x["answer_vi_method"]
        for x in final_queries
    )
)

print("\nConfidence:")

print(
    Counter(
        x["answer_vi_confidence"]
        for x in final_queries
    )
)

print("\nNeeds review:")

print(
    Counter(
        x["answer_vi_needs_review"]
        for x in final_queries
    )
)
# Out:
# Answer methods:
# Counter({'exact_span_existing': 544, 'translated_non_extractive': 216, 'translated_exact_span': 187, 'rule_yes_no': 53})
#
# Confidence:
# Counter({'high': 784, 'medium': 216})
#
# Needs review:
# Counter({False: 784, True: 216})

# %% [markdown]
# ## Phần phân loại các case cần maunal review

# %% [markdown]
# ## Cell C7.1 Load model

# %%
# !pip -q install sentence-transformers

# %%
import re
import unicodedata
import torch

from sentence_transformers import SentenceTransformer

CHECK_MODEL = "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"

check_model = SentenceTransformer(
    CHECK_MODEL,
    device="cuda" if torch.cuda.is_available() else "cpu"
)

print("Loaded:", CHECK_MODEL)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.89k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  471MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/526 [00:00<?, ?B/s]
# tokenizer.json: reconstructing file:   0%|          |  0.00B / 9.08MB
# tokenizer.json: downloading bytes:           |  0.00B
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Loaded: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2

# %% [markdown]
# ## Cell C7.2 Flexible normalization

# %%
def flexible_norm(text):
    if text is None:
        return ""

    text = unicodedata.normalize("NFKC", str(text))
    text = text.casefold()

    # 27.000 / 27,000 -> 27000
    text = re.sub(r"(?<=\d)[.,](?=\d)", "", text)

    # punctuation -> space
    text = re.sub(
        r"[^\wÀ-ỹ]+",
        " ",
        text,
        flags=re.UNICODE
    )

    text = re.sub(r"\s+", " ", text)

    return text.strip()


review_records = [
    x for x in final_queries
    if x["answer_vi_needs_review"]
]

print("Review records:", len(review_records))
# Out:
# Review records: 216

# %% [markdown]
# ## Cell C7.3. Tính semantic similarity

# %%
q_vi_list = [
    x["question_vi"]
    for x in review_records
]

q_en_list = [
    x["question_en"]
    for x in review_records
]

a_vi_list = [
    x["answer_vi"]
    for x in review_records
]

a_en_list = [
    x["answer_en"]
    for x in review_records
]


# Encode theo batch
q_vi_emb = check_model.encode(
    q_vi_list,
    batch_size=64,
    convert_to_tensor=True,
    normalize_embeddings=True
)

q_en_emb = check_model.encode(
    q_en_list,
    batch_size=64,
    convert_to_tensor=True,
    normalize_embeddings=True
)

a_vi_emb = check_model.encode(
    a_vi_list,
    batch_size=64,
    convert_to_tensor=True,
    normalize_embeddings=True
)

a_en_emb = check_model.encode(
    a_en_list,
    batch_size=64,
    convert_to_tensor=True,
    normalize_embeddings=True
)


question_sim = (
    q_vi_emb * q_en_emb
).sum(dim=1).cpu().tolist()

answer_sim = (
    a_vi_emb * a_en_emb
).sum(dim=1).cpu().tolist()


print("Encoded", len(review_records), "review cases")
# Out:
# Encoded 216 review cases

# %% [markdown]
# ## Cell C7.4. Kiểm tra answer có được gold context hỗ trợ không

# %%
def split_sentences(text):
    parts = re.split(
        r"(?<=[.!?])\s+|\n+",
        str(text)
    )

    return [
        x.strip()
        for x in parts
        if len(x.strip()) >= 10
    ]


sentence_bank = []
sentence_ranges = {}

for record in review_records:

    qid = record["id"]

    sentences = split_sentences(
        gold_text_vi_by_query[qid]
    )

    start = len(sentence_bank)

    sentence_bank.extend(sentences)

    end = len(sentence_bank)

    sentence_ranges[qid] = (start, end)


print("Gold context sentences:", len(sentence_bank))


sentence_emb = check_model.encode(
    sentence_bank,
    batch_size=128,
    convert_to_tensor=True,
    normalize_embeddings=True,
    show_progress_bar=True
)
# Out:
# Gold context sentences: 1752
# Batches:   0%|          | 0/14 [00:00<?, ?it/s]

# %%
context_sim = []
best_context_sentence = []

for i, record in enumerate(review_records):

    qid = record["id"]

    start, end = sentence_ranges[qid]

    if end <= start:

        context_sim.append(0.0)
        best_context_sentence.append("")
        continue

    candidate_emb = a_vi_emb[i]

    sims = (
        sentence_emb[start:end]
        @ candidate_emb
    )

    best_idx = int(
        torch.argmax(sims).item()
    )

    context_sim.append(
        float(sims[best_idx].item())
    )

    best_context_sentence.append(
        sentence_bank[start + best_idx]
    )

# %% [markdown]
# ## Cell C7.5 — Chia 216 câu thành A/B/C/D

# %%
triage_results = []

for i, record in enumerate(review_records):

    qid = record["id"]

    ans_vi = record["answer_vi"]

    gold_context = (
        gold_text_vi_by_query[qid]
    )

    flexible_span = (
        len(flexible_norm(ans_vi)) >= 2
        and flexible_norm(ans_vi)
        in flexible_norm(gold_context)
    )

    qs = question_sim[i]
    ans = answer_sim[i]
    ctx = context_sim[i]

    # -----------------------------------------
    # A: gần như ổn
    # -----------------------------------------
    if flexible_span:

        category = "A_flexible_span"

    # -----------------------------------------
    # C: nghi question VI dịch lệch question EN
    # -----------------------------------------
    elif qs < 0.60:

        category = "C_question_suspicious"

    # -----------------------------------------
    # B: nghi answer_vi dịch sai answer_en
    # -----------------------------------------
    elif ans < 0.50:

        category = "B_answer_translation_suspicious"

    # -----------------------------------------
    # D: answer translation có vẻ đúng
    # nhưng evidence VI không support tốt
    # -----------------------------------------
    elif ctx < 0.28:

        category = "D_context_support_suspicious"

    # -----------------------------------------
    # A: semantic đều tốt
    # -----------------------------------------
    elif (
        qs >= 0.72
        and ans >= 0.65
        and ctx >= 0.40
    ):

        category = "A_likely_ok"

    else:

        category = "E_ambiguous_review"


    triage_results.append({
        "id": qid,

        "question_vi":
            record["question_vi"],

        "question_en":
            record["question_en"],

        "answer_en":
            record["answer_en"],

        "answer_vi":
            record["answer_vi"],

        "question_similarity": qs,

        "answer_similarity": ans,

        "context_similarity": ctx,

        "best_context_sentence":
            best_context_sentence[i],

        "flexible_span":
            flexible_span,

        "category":
            category
    })

# %% [markdown]
# ## Cell 7.6 Xem kết quả phân loại

# %%
from collections import Counter

category_counts = Counter(
    x["category"]
    for x in triage_results
)

print("=" * 70)
print("REVIEW TRIAGE")
print("=" * 70)

for category, count in category_counts.items():
    print(f"{category:35s}: {count}")

print("\nTotal:", sum(category_counts.values()))
# Out:
# ======================================================================
# REVIEW TRIAGE
# ======================================================================
# A_likely_ok                        : 143
# E_ambiguous_review                 : 42
# D_context_support_suspicious       : 11
# A_flexible_span                    : 10
# B_answer_translation_suspicious    : 10
#
# Total: 216

# %% [markdown]
# Nên thêm một lớp kiểm tra trên toàn bộ 1.000 câu, không chỉ 216 câu, vì Rudolf Hess đã lọt vào nhóm A_likely_ok.
#
# ## Cell C7.7 — Tạo gold supporting context tiếng Anh
#
# Dùng đúng các supporting_facts của HotpotQA gốc.

# %%
def build_gold_en_context(qid):
    row = original_by_id[qid]

    title_to_sentences = {
        title: sentences
        for title, sentences in zip(
            row["context"]["title"],
            row["context"]["sentences"]
        )
    }

    support = []

    for title, sent_id in zip(
        row["supporting_facts"]["title"],
        row["supporting_facts"]["sent_id"]
    ):
        if (
            title in title_to_sentences
            and sent_id < len(title_to_sentences[title])
        ):
            sent = title_to_sentences[title][sent_id]
            support.append(f"{title}: {sent}")

    return " ".join(support)


gold_en_context_by_query = {
    x["id"]: build_gold_en_context(x["id"])
    for x in final_queries
}

print("Built contexts:", len(gold_en_context_by_query))
# Out:
# Built contexts: 1000

# %% [markdown]
# ## Cell C7.8 Load model kiểm tra QA consistency

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch

QA_CHECK_MODEL = "google/flan-t5-base"

qa_tokenizer = AutoTokenizer.from_pretrained(QA_CHECK_MODEL)

qa_model = AutoModelForSeq2SeqLM.from_pretrained(
    QA_CHECK_MODEL
).to(
    "cuda" if torch.cuda.is_available() else "cpu"
)

qa_device = next(qa_model.parameters()).device

print("QA checker:", QA_CHECK_MODEL)
print("Device:", qa_device)
# Out:
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model: reconstructing file:   0%|          |  0.00B /  792kB
# spiece.model: downloading bytes:           |  0.00B
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  990MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/282 [00:00<?, ?it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# QA checker: google/flan-t5-base
# Device: cuda:0

# %% [markdown]
# ## Cell C7.9 — Kiểm tra 1.000 gold answers

# %%
def make_consistency_prompt(record):

    context = gold_en_context_by_query[record["id"]]

    return f"""
Determine whether the proposed answer directly and correctly answers
the question using the context.

Important:
- The answer must answer exactly what the question asks.
- Do NOT say YES merely because the proposed answer appears in the context.
- Check question type carefully: who, what, why, when, where, which, how many, etc.
- Reply with only YES or NO.

Context:
{context}

Question:
{record["question_en"]}

Proposed answer:
{record["answer_en"]}

Correct?
""".strip()

# %%
def run_qa_consistency(records, batch_size=16):

    results = []

    for start in range(0, len(records), batch_size):

        batch_records = records[start:start + batch_size]

        prompts = [
            make_consistency_prompt(x)
            for x in batch_records
        ]

        inputs = qa_tokenizer(
            prompts,
            return_tensors="pt",
            padding=True,
            truncation=True,
            max_length=512
        ).to(qa_device)

        with torch.no_grad():
            outputs = qa_model.generate(
                **inputs,
                max_new_tokens=4
            )

        texts = qa_tokenizer.batch_decode(
            outputs,
            skip_special_tokens=True
        )

        results.extend(texts)

    return results


qa_judgments_raw = run_qa_consistency(
    final_queries
)

print("Checked:", len(qa_judgments_raw))
# Out:
# Checked: 1000

# %% [markdown]
# ## Cell C7.10 — Parse kết quả

# %%
qa_consistency = {}

for record, raw in zip(
    final_queries,
    qa_judgments_raw
):

    text = raw.strip().lower()

    if text.startswith("yes"):
        status = "pass"

    elif text.startswith("no"):
        status = "suspicious"

    else:
        status = "uncertain"

    qa_consistency[record["id"]] = {
        "status": status,
        "raw": raw
    }


from collections import Counter

print(
    Counter(
        x["status"]
        for x in qa_consistency.values()
    )
)
# Out:
# Counter({'pass': 949, 'suspicious': 50, 'uncertain': 1})

# %% [markdown]
# ## Cell C7.11 — Kiểm tra Rudolf Hess

# %%
for record in final_queries:

    if "Rudolf Hess" in record["question_vi"]:

        qid = record["id"]

        print("QUESTION EN:")
        print(record["question_en"])

        print("\nANSWER EN:")
        print(record["answer_en"])

        print("\nQA CHECK:")
        print(qa_consistency[qid])

        print("\nSUPPORT:")
        print(gold_en_context_by_query[qid])
# Out:
# QUESTION EN:
# Why did Rudolf Hess stop serving Hitler in 1941?
#
# ANSWER EN:
# report Hess's illegal May 1941 flight to Scotland
#
# QA CHECK:
# {'status': 'pass', 'raw': 'Yes'}
#
# SUPPORT:
# Karlheinz Pintsch:  It fell to him to report Hess's illegal May 1941 flight to Scotland to Hitler and his recollections and notes have been the subject of debate by historians. Rudolf Hess:  Appointed Deputy Führer to Adolf Hitler in 1933, he served in this position until 1941, when he flew solo to Scotland in an attempt to negotiate peace with the United Kingdom during World War II. Rudolf Hess:  He was taken prisoner and eventually was convicted of crimes against peace, serving a life sentence until his suicide.

# %% [markdown]
# ## Cell C7.12 — Sinh answer tham khảo cho những câu bị nghi

# %%
source_suspicious = [
    x for x in final_queries
    if qa_consistency[x["id"]]["status"] != "pass"
]

print("Source QA cases to inspect:",
      len(source_suspicious))
# Out:
# Source QA cases to inspect: 51

# %%
def make_answer_prompt(record):

    context = gold_en_context_by_query[record["id"]]

    return f"""
Answer the question using only the context.
Return only a short answer.

Context:
{context}

Question:
{record["question_en"]}

Answer:
""".strip()


def generate_reference_answers(records, batch_size=16):

    answers = []

    for start in range(0, len(records), batch_size):

        batch = records[start:start + batch_size]

        prompts = [
            make_answer_prompt(x)
            for x in batch
        ]

        inputs = qa_tokenizer(
            prompts,
            return_tensors="pt",
            padding=True,
            truncation=True,
            max_length=512
        ).to(qa_device)

        with torch.no_grad():

            outputs = qa_model.generate(
                **inputs,
                max_new_tokens=32
            )

        answers.extend(
            qa_tokenizer.batch_decode(
                outputs,
                skip_special_tokens=True
            )
        )

    return answers


reference_answers = generate_reference_answers(
    source_suspicious
)

reference_answer_by_id = {
    row["id"]: ans
    for row, ans in zip(
        source_suspicious,
        reference_answers
    )
}

# %% [markdown]
# ## Cell C8 — In những câu cần review

# %% [markdown]
# ## Cell C8.1 Xem các case nguy hiểm

# %%
priority_categories = {
    "C_question_suspicious",
    "B_answer_translation_suspicious",
    "D_context_support_suspicious",
    "E_ambiguous_review"
}

priority_ids = {
    x["id"]
    for x in triage_results
    if x["category"] in priority_categories
}

priority_review = [
    x for x in final_queries
    if x["id"] in priority_ids
]

print("Priority manual review:", len(priority_review))
# Out:
# Priority manual review: 63

# %% [markdown]
# ## Cell C8.2 Xem chi tiết

# %%
triage_by_id = {
    x["id"]: x
    for x in triage_results
}

for x in priority_review[:50]:

    qid = x["id"]

    triage = triage_by_id.get(qid, {})

    print("\n" + "=" * 100)

    print("ID:", qid)

    print(
        "Translation triage:",
        triage.get("category", "not_in_translation_review")
    )

    print(
        "Source QA:",
        qa_consistency[qid]["status"]
    )

    print("\nQUESTION VI:")
    print(x["question_vi"])

    print("\nQUESTION EN:")
    print(x["question_en"])

    print("\nORIGINAL GOLD ANSWER:")
    print(x["answer_en"])

    print("\nCURRENT ANSWER VI:")
    print(x["answer_vi"])

    if qid in reference_answer_by_id:
        print("\nMODEL REFERENCE ANSWER:")
        print(reference_answer_by_id[qid])

    print("\nGOLD SUPPORT:")
    print(gold_en_context_by_query[qid])
# Out:
# ====================================================================================================
# ID: 5ab28156554299449642c8ce
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Đội bóng đã chơi các trận đấu sân nhà tại Holman Stadium thuộc giải đấu nào?
#
# QUESTION EN:
# What league did was the team that played home games at Holman Stadium belong to?
#
# ORIGINAL GOLD ANSWER:
# Canadian-American Association of Professional Baseball
#
# CURRENT ANSWER VI:
# Hiệp hội bóng chày chuyên nghiệp Canada-America
#
# GOLD SUPPORT:
# Pittsfield Colonials: The Pittsfield Colonials were a baseball team in the independent Canadian-American Association of Professional Baseball, based in Pittsfield, Massachusetts. Nashua Pride:  They played home games at Holman Stadium from 1998 through 2008, when they were sold and renamed the American Defenders of New Hampshire.
#
# ====================================================================================================
# ID: 5ae35b035542992e3233c3ae
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# William Bromley-Davenport giữ chức vụ chính trị dưới thời thủ tướng thuộc đảng nào?
#
# QUESTION EN:
# William Bromley-Davenport held political office under the Prime Minister who was of which party?
#
# ORIGINAL GOLD ANSWER:
# Conservative
#
# CURRENT ANSWER VI:
# Tự bảo thủ
#
# GOLD SUPPORT:
# William Bromley-Davenport (British Army officer):  An MP from 1886 to 1906, he held political office under Arthur Balfour as Financial Secretary to the War Office from 1903 to 1905. Arthur Balfour: Arthur James Balfour, 1st Earl of Balfour, (usually , but traditionally /bəɫˈfʉr/ in Scottish English; 25 July 184819 March 1930) was a British Conservative politician who was the Prime Minister of the United Kingdom from July 1902 to December 1905, and later Foreign Secretary.
#
# ====================================================================================================
# ID: 5ae0b2f25542993d6555ec1c
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Nhà hàng chuỗi của một trong những đối tượng nghiên cứu của Daniel Greene chuyên về món ăn gì?
#
# QUESTION EN:
# What food does one of Daniel Greene's subjects' restaurant chain specialize in?
#
# ORIGINAL GOLD ANSWER:
# hamburgers
#
# CURRENT ANSWER VI:
# bánh mì
#
# GOLD SUPPORT:
# Daniel Greene (artist):  Some of his sitters include First Lady Eleanor Roosevelt, Ayn Rand, Astronaut Walter Schirra, William Randolph Hearst, “Wendy’s” founder Dave Thomas, Commentator Rush Limbaugh, Composer Alan Menken, Bryant Gumbel and Bob Schieffer of CBS TV. Dave Thomas (businessman):  Thomas was the founder and chief executive officer of Wendy's, a fast-food restaurant chain specializing in hamburgers.
#
# ====================================================================================================
# ID: 5ae537a855429960a22e0266
# Translation triage: D_context_support_suspicious
# Source QA: pass
#
# QUESTION VI:
# "Let's Get Ready to Rhumble" là một bài hát năm 1994 của bộ đôi nhạc sĩ từ nơi nào?
#
# QUESTION EN:
# "Let's Get Ready to Rhumble" is a 1994 song by a music duo from where?
#
# ORIGINAL GOLD ANSWER:
# Newcastle upon Tyne, England
#
# CURRENT ANSWER VI:
# Newcastle upon Tyne, Anh
#
# GOLD SUPPORT:
# Let's Get Ready to Rhumble: "Let's Get Ready to Rhumble" is a 1994 song by British duo Ant & Dec, who at the time were known as PJ & Duncan. Ant &amp; Dec: Anthony McPartlin, OBE (born 18 November 1975) and Declan Donnelly, OBE (born 25 September 1975), known collectively as Ant & Dec, are an English comedy TV presenting, television producing, acting and former music duo from Newcastle upon Tyne, England.
#
# ====================================================================================================
# ID: 5ae60d36554299546bf8303e
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Khi nào tay đua người Bỉ Stoffel Vandoorne đã thắng giải Monaco GP2 Series?
#
# QUESTION EN:
# When did Belgium racer Stoffel Vandoorne win the Monaco GP2 Series round?
#
# ORIGINAL GOLD ANSWER:
# 22 and 23 May 2015
#
# CURRENT ANSWER VI:
# 22 và 23 tháng 5 năm 2015
#
# GOLD SUPPORT:
# 2015 Monaco GP2 Series round: The 2015 Monaco GP2 Series round was a pair of motor races held on 22 and 23 May 2015 at the Circuit de Monaco, Monte Carlo, Monaco as part of the GP2 Series. 2015 Monaco GP2 Series round:  The first race, a 40-lap feature event, was won by ART Grand Prix driver Stoffel Vandoorne who started from fourth position. Stoffel Vandoorne: Stoffel Vandoorne (born 26 March 1992) is a professional racing driver from Belgium, currently competing in Formula 1.
#
# ====================================================================================================
# ID: 5ab7ece25542995dae37e9f3
# Translation triage: D_context_support_suspicious
# Source QA: pass
#
# QUESTION VI:
# 4 bộ phận nào tạo nên công ty của người giàu nhất ở Georgia?
#
# QUESTION EN:
# What 4 divisions make up the company of the wealthiest person in Georgia?
#
# ORIGINAL GOLD ANSWER:
# newspapers, television, radio, cable television
#
# CURRENT ANSWER VI:
# báo chí, truyền hình, đài phát thanh, truyền hình cáp
#
# GOLD SUPPORT:
# James C. Kennedy:  According to the Forbes billionaires list from 2017, he is the 105th richest person in the world, the thirty-seventh richest person in the United States, and the richest person in the state of Georgia, surpassing his aunt, Anne Cox Chambers, for the title. Anne Cox Chambers: Anne Beau Cox Chambers (born December 1, 1919) is an American media proprietor, who has a stake of interest in Cox Enterprises, a privately held media empire that includes newspapers, television, radio, cable television, and other businesses.
#
# ====================================================================================================
# ID: 5ae1599155429901ffe4ae7b
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Willi Forst và Brian Robbins đều là người gì?
#
# QUESTION EN:
# Willi Forst and Brian Robbins are both what?
#
# ORIGINAL GOLD ANSWER:
# actor, screenwriter, film director, film producer
#
# CURRENT ANSWER VI:
# diễn viên, biên kịch, đạo diễn phim, nhà sản xuất phim
#
# GOLD SUPPORT:
# Willi Forst: Willi Forst, born Wilhelm Anton Frohs (7 April 1903 – 11 August 1980) was an Austrian actor, screenwriter, film director, film producer and singer. Brian Robbins: Brian Levine (born November 22, 1963), best known as Brian Robbins, is an American actor, film director, film producer, television director, television producer and occasional screenwriter.
#
# ====================================================================================================
# ID: 5ab8f3235542991b5579f084
# Translation triage: E_ambiguous_review
# Source QA: suspicious
#
# QUESTION VI:
# Tổng thống thứ bao nhiêu mà Annie Caputo được đề cử vào Ủy ban Điều tiết Hạt nhân?
#
# QUESTION EN:
# What number president was Annie Caputo nominated by to become a member of the Nuclear Regulatory Commission?
#
# ORIGINAL GOLD ANSWER:
# 45th
#
# CURRENT ANSWER VI:
# 45th
#
# MODEL REFERENCE ANSWER:
# 45th
#
# GOLD SUPPORT:
# Annie Caputo: Annie Caputo is an American political advisor and government official. Annie Caputo:  Currently serving as senior policy advisor for Chairman John Barrasso (R-WY) on the United States Senate Committee on Environment and Public Works, she is President Donald Trump's nominee to become a member of the Nuclear Regulatory Commission for the remainder of a five-year term expiring on June 30, 2021. Donald Trump: Donald John Trump (born June 14, 1946) is the 45th and current President of the United States, in office since January 20, 2017.
#
# ====================================================================================================
# ID: 5a7a10755542996a35c170b1
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Loài thực vật chính cần loại phân bón kiểu ericaceous có thể tác động đến môi trường xung quanh như thế nào do cách thức hấp thụ cation của nó?
#
# QUESTION EN:
# The most principle species of plants which requires an ericaceous type of compost can have what effect on its surroundings because of the way it takes up cations?
#
# ORIGINAL GOLD ANSWER:
# Peat moss can also acidify its surroundings by taking up cations
#
# CURRENT ANSWER VI:
# Chất xám cũng có thể làm cho môi trường xung quanh của nó bị axit bằng cách hấp thụ các cation
#
# GOLD SUPPORT:
# Calcifuge:  There are many horticultural plants which are calcifuges, most of which require an 'ericaceous' compost with a low pH, composed principally of "Sphagnum" moss peat. Sphagnum:  Peat moss can also acidify its surroundings by taking up cations, such as calcium and magnesium, and releasing hydrogen ions.
#
# ====================================================================================================
# ID: 5ae32ce75542992f92d8223d
# Translation triage: D_context_support_suspicious
# Source QA: suspicious
#
# QUESTION VI:
# Tháng nào một trang web dành cho người lớn trực tuyến mà tạp chí in cuối cùng được xuất bản vào mùa hè năm 2007 đã công nhận Nikita Gross?
#
# QUESTION EN:
# What month did the an online adult website whose last print magazine was published in the summer of 2007 recognize Nikita Gross?
#
# ORIGINAL GOLD ANSWER:
# January
#
# CURRENT ANSWER VI:
# Tháng 1
#
# MODEL REFERENCE ANSWER:
# January
#
# GOLD SUPPORT:
# Nikita Gross: Nikita Gross is a Russian glamour model and former pornographic actress. Nikita Gross:  She was a "Perfect 10" girl in January 2000. Perfect 10: Perfect 10 is an online adult website – and formerly a monthly and then quarterly men's magazine – that features high resolution topless or nude photographs of 'all natural' women who have not had cosmetic surgery. Perfect 10:  The last print edition of the magazine was published in the summer of 2007 (issue 43).
#
# ====================================================================================================
# ID: 5a84c89a5542992a431d1a9c
# Translation triage: B_answer_translation_suspicious
# Source QA: pass
#
# QUESTION VI:
# Tên gọi khác của một khu rừng có làng Oakenclough ở rìa là gì?
#
# QUESTION EN:
# What is another name for a forest which has the hamlet of Oakenclough on the edge of it?
#
# ORIGINAL GOLD ANSWER:
# "Switzerland of England"
#
# CURRENT ANSWER VI:
# "Sui Tiếng Anh"
#
# GOLD SUPPORT:
# Oakenclough: Oakenclough ( ) is an English hamlet located on the edge of the Forest of Bowland in Lancashire. Forest of Bowland: The Forest of Bowland, also known as the Bowland Fells, is an area of barren gritstone fells, deep valleys and peat moorland, mostly in north-east Lancashire, England with a small part in North Yorkshire (before 1974, some of the area was in the West Riding of Yorkshire). Forest of Bowland:  It was once described as the "Switzerland of England".
#
# ====================================================================================================
# ID: 5a82ffef55429954d2e2ebf2
# Translation triage: D_context_support_suspicious
# Source QA: pass
#
# QUESTION VI:
# Maine có bao nhiêu đại diện tại Hạ viện Hoa Kỳ?
#
# QUESTION EN:
# How many United States House of Representatives does Maine's congressional districts have?
#
# ORIGINAL GOLD ANSWER:
# 2
#
# CURRENT ANSWER VI:
# 2
#
# GOLD SUPPORT:
# Maine Democratic caucuses, 2008: The Maine Democratic Presidential Caucuses took place on February 10, 2008, and had 24 delegates at stake. Maine Democratic caucuses, 2008:  The winner in each of Maine's two congressional districts received all of that district's total delegates, which totaled 16. Maine's congressional districts: Maine is divided into 2 congressional districts, each represented by an elected member of the United States House of Representatives.
#
# ====================================================================================================
# ID: 5adc985e5542990d50227cb7
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Học sinh vượt qua kỳ thi mà Le rêve de Rico phải vượt qua sẽ tiến lên lớp nào?
#
# QUESTION EN:
# Where will the student which pass the exam  for which Le Rêve de Rico has to pass progress to?
#
# ORIGINAL GOLD ANSWER:
# secondary school study
#
# CURRENT ANSWER VI:
# học trung học
#
# GOLD SUPPORT:
# Le Rêve de Rico:  Today he has to pass the CPE, the exam that, in Mauritius, will get him into High school. Certificate of Primary Education:  Students who successfully earn the qualification may then progress onto secondary school study.
#
# ====================================================================================================
# ID: 5a7f8b8c5542995d8a8ddea1
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Tên gọi "snake eyes" được dùng trong trò chơi sòng bạc đặc biệt sử dụng những quân cờ nào?
#
# QUESTION EN:
# The term snake eyes is used in a particular casino game that uses what game pieces?
#
# ORIGINAL GOLD ANSWER:
# a pair of dice
#
# CURRENT ANSWER VI:
# một cặp xúc xắc
#
# GOLD SUPPORT:
# Snake eyes: In gambling in general and the game of Craps in particular, snake eyes is the outcome of rolling the dice in a game and getting only one pip on each die. Craps: Craps is a dice game in which the players make wagers on the outcome of the roll, or a series of rolls, of a pair of dice.
#
# ====================================================================================================
# ID: 5ae1e1e55542997f29b3c15e
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Lenroy Thomas là đương kim vô địch hạng nặng Khối Thịnh Vượng Chung sau khi đả bại một võ sĩ quyền anh chuyên nghiệp người Anh với thành tích 12 trận thắng, 3 trận thua và bao nhiêu trận hòa?
#
# QUESTION EN:
# Lenroy Thomas is the current commonwealth heavyweight champion after beating a British , professional boxer who has a record of 12 wins, 3 defeats, and how many draws?
#
# ORIGINAL GOLD ANSWER:
# 1
#
# CURRENT ANSWER VI:
# 1
#
# GOLD SUPPORT:
# Lenroy Thomas:  He is the current commonwealth heavyweight champion after beating Dave Allen via a split decision victory. Dave Allen (boxer): David Allen (born 21 March 1992) is British professional boxer. Dave Allen (boxer):  He has fought 16 times and his record stands at 12 wins, 3 defeats and 1 draw.
#
# ====================================================================================================
# ID: 5ae1f3df554299234fd04364
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Khi nào thì ca sĩ rock Mỹ đã biểu diễn các bản cover qua đời?
#
# QUESTION EN:
# When did the  American rock singer  which performed  Recorded covers died
#
# ORIGINAL GOLD ANSWER:
# at age 27
#
# CURRENT ANSWER VI:
# ở tuổi 27
#
# GOLD SUPPORT:
# San Francisco Bay Blues:  Recorded covers have been performed by many artists including The Blues Band, Paul Jones, Jim Croce, The Weavers, Sammy Walker, The Brothers Four, Paul Clayton, Richie Havens, Eric Clapton, The Flatlanders, Paul McCartney, Hot Tuna, Janis Joplin, John Lennon, Peter, Paul, and Mary, Mungo Jerry, Glenn Yarbrough, George Ellias, Phoebe Snow, The Wave Pictures, The Halifax III and Eva Cassidy. Janis Joplin:  She was one of the biggest female rock stars of her era. Janis Joplin:  After releasing three albums, she died of a heroin overdose at age 27.
#
# ====================================================================================================
# ID: 5abb66c05542992ccd8e7f3e
# Translation triage: D_context_support_suspicious
# Source QA: pass
#
# QUESTION VI:
# Các tội lỗi mà người mở đầu trận đấu Khalid Latif và 5 cầu thủ cricket khác bị đình chỉ thi đấu vào tháng Hai năm 2017 là gì?
#
# QUESTION EN:
# What offence were opening batsman Khalid Latif and 5 other cricketers suspended for, in February 2017?
#
# ORIGINAL GOLD ANSWER:
# spot-fixing
#
# CURRENT ANSWER VI:
# Đặt chỗ
#
# GOLD SUPPORT:
# 2017 Pakistan Super League spot-fixing scandal:  The six cricketers suspended by the PCB are: Sharjeel Khan (on 10 February), Khalid Latif (on 10 February), Nasir Jamshed (on 13 February), Mohammad Irfan (on 14 March), Shahzaib Hasan (on 17 March) and Mohammad Nawaz (16 May). Khalid Latif (cricketer):  A right-handed opening batsman, Latif captained Pakistan in the 2004 U-19 Cricket World Cup win and the 2010 Asian Games bronze medal win. Khalid Latif (cricketer):  In 2017, the Pakistan Cricket Board banned Latif from all forms of cricket for five years, for his involvement in spot-fixing.
#
# ====================================================================================================
# ID: 5aba7cb455429901930fa7eb
# Translation triage: B_answer_translation_suspicious
# Source QA: pass
#
# QUESTION VI:
# Cả một cựu phi hành gia của NASA và người sáng lập FlightSafety International đã nhận được những vinh dự gì?
#
# QUESTION EN:
# What honor has been received by both a former NASA Astronaut and the Founder of FlightSafety International?
#
# ORIGINAL GOLD ANSWER:
# National Aviation Hall of Fame
#
# CURRENT ANSWER VI:
# Tòa nhà hàng không quốc gia
#
# GOLD SUPPORT:
# Albert Lee Ueltschi:  On July 21, 2001, he was enshrined at Dayton, Ohio, in the National Aviation Hall of Fame class of 2001, along with test pilot Joe Engle, United States Air Force flying ace Marion Carl, and USAF ace Robin Olds. Joe Engle: , is an American pilot who served in the United States Air Force, test pilot for the North American X-15 program, aeronautical engineer, and a former NASA astronaut.
#
# ====================================================================================================
# ID: 5ac3d1d9554299204fd21e8a
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Có bao nhiêu album đã được Talking Heads thu âm vào tháng 11 năm 1980?
#
# QUESTION EN:
# How many albums had been recorded by Talking Heads by November, 1980?
#
# ORIGINAL GOLD ANSWER:
# four
#
# CURRENT ANSWER VI:
# 4
#
# GOLD SUPPORT:
# The Name of This Band Is Talking Heads: The Name of This Band Is Talking Heads is a double live album by Talking Heads, originally released in 1982. Remain in Light: Remain in Light is the fourth studio album by American new wave band Talking Heads, released on October 8, 1980, on Sire Records.
#
# ====================================================================================================
# ID: 5ac0a18a5542992a796ded41
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Thể loại tác phẩm của nhà văn có tiểu thuyết được viết dựa trên "I'll Take Manhattan" là gì?
#
# QUESTION EN:
# What genre did the writer whose novel was based on "I'll Take Manhattan" writes?
#
# ORIGINAL GOLD ANSWER:
# romance genre
#
# CURRENT ANSWER VI:
# Phân loại lãng mạn
#
# GOLD SUPPORT:
# I'll Take Manhattan (miniseries): I'll Take Manhattan is a 1987 American television miniseries, adapted from Judith Krantz's novel of the same name. Judith Krantz: Judith "Judy" Krantz (née Tarcher) (born January 9, 1928) is a Jewish-American novelist who writes in the romance genre.
#
# ====================================================================================================
# ID: 5ab92f1f554299753720f77b
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Nghề nghiệp nào của 2007 Formula 3 Euro Series và Romain Grosjean có điểm chung?
#
# QUESTION EN:
# What profession does 2007 Formula 3 Euro Series and Romain Grosjeanhave in common?
#
# ORIGINAL GOLD ANSWER:
# driver
#
# CURRENT ANSWER VI:
# lái xe
#
# GOLD SUPPORT:
# 2007 Formula 3 Euro Series:  The top four drivers in the championship would go on to race in Formula 1: Sébastien Buemi, Kamui Kobayashi and champion Grosjean all debuted in F1 in 2009 and Nico Hülkenberg in 2010. Romain Grosjean: Romain Grosjean (] ; born 17 April 1986) is a racing driver, currently racing for the Haas F1 Team.
#
# ====================================================================================================
# ID: 5a8dafbd554299068b959da0
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Có bao nhiêu tập phim được làm cho loạt phim khoa học viễn tưởng với Gus Birney?
#
# QUESTION EN:
# How many episodes were made for the science fiction series with Gus Birney?
#
# ORIGINAL GOLD ANSWER:
# ten
#
# CURRENT ANSWER VI:
# mười
#
# GOLD SUPPORT:
# Gus Birney: Gus Birney is an American actress, best known for her role as Alex in "The Mist". The Mist (TV series): The Mist is an American science fiction-horror thriller television series developed by Christian Torpe for Spike. The Mist (TV series):  The first season, consisting of ten episodes, premiered on June 22, 2017. The Mist (TV series):  On September 27, 2017, Spike cancelled the series after one season.
#
# ====================================================================================================
# ID: 5abe7eb05542993f32c2a12c
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Ngày sinh của một người sáng lập Hội Cải cách Congo là khi nào?
#
# QUESTION EN:
# When was the date of birth of one of the founder of Congo Reform Association?
#
# ORIGINAL GOLD ANSWER:
# 1 September 1864
#
# CURRENT ANSWER VI:
# Ngày 1 tháng 9 năm 1864
#
# GOLD SUPPORT:
# Congo Reform Association:  The association was founded in March, 1904, by Dr. Henry Grattan Guinness (1861–1915), Edmund Dene Morel, and Roger Casement. Roger Casement: Roger David Casement (1 September 1864 – 3 August 1916), formerly known as Sir Roger Casement  between 1911 and shortly before his execution for treason, when he was stripped of his knighthood and other honours, was a British civil servant who worked for the British Foreign Office as a diplomat, and later became a humanitarian activist, Irish nationalist, and poet.
#
# ====================================================================================================
# ID: 5a86eee85542994775f60787
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Trong những năm nào đường sắt mà có một trạm dừng tại Ringling, Montana hoạt động?
#
# QUESTION EN:
#  During what years did the railroad that had a station stop in Ringling, Montana operate?
#
# ORIGINAL GOLD ANSWER:
# from 1847 until 1980
#
# CURRENT ANSWER VI:
# Từ năm 1847 đến năm 1980
#
# GOLD SUPPORT:
# Ringling, Montana:  The town was a station stop on the transcontinental main line of the Chicago, Milwaukee, St. Paul and Pacific Railroad ("the Milwaukee Road"); it was also the southern terminus of the White Sulphur Springs and Yellowstone Park Railway, which ran from Ringling to White Sulphur Springs. Chicago, Milwaukee, St. Paul and Pacific Railroad: The Chicago, Milwaukee, St. Paul and Pacific Railroad (often referred to as the Milwaukee Road) (reporting mark MILW) , was a Class I railroad that operated in the Midwest and Northwest of the United States from 1847 until 1980, when its Pacific Extension (Montana, Idaho, and Washington) was abandoned following a bankruptcy.
#
# ====================================================================================================
# ID: 5ac1c9a15542994ab5c67e1c
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Dân số của thành phố tổ chức phiên bản đầu tiên của Thế vận hội trẻ Nam Mỹ là bao nhiêu?
#
# QUESTION EN:
# What is the population of the city in which the first edition of the South American Youth Olympic Games were held?
#
# ORIGINAL GOLD ANSWER:
# more than 10 million
#
# CURRENT ANSWER VI:
# hơn 10 triệu
#
# GOLD SUPPORT:
# South American Youth Games: The South American Youth Olympic Games (Spanish: "Juegos Suramericanos de la Juventud"; Portuguese: "Jogos Sul-Americanos da Juventude") is a regional multi-sport event organized by the Organización Deportiva Suramericana (ODESUR). South American Youth Games:  The first edition was held in Lima, Perú, from 20 to 29 September 2013. Lima: Lima ( , ] , Quechua: ] , Aymara: ] ) is the capital and the largest city of Peru. Lima:  With a population of more than 10 million, Lima is the most populous metropolitan area of Peru and the third-largest city in the Americas (as defined by "city proper"), behind São Paulo and Mexico City.
#
# ====================================================================================================
# ID: 5ab7f27e5542991d322237d6
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Ga Aughton Park nằm trên một nhánh của Đường sắt Northern Line cách Liverpool bao xa?
#
# QUESTION EN:
# Aughton Park railway station is on a branch of the Northern Line how far from Liverpool?
#
# ORIGINAL GOLD ANSWER:
# 12+3/4 mi northeast of Liverpool
#
# CURRENT ANSWER VI:
# 12+3/4 mi về phía đông bắc Liverpool
#
# GOLD SUPPORT:
# Aughton Park railway station: Aughton Park railway station is a railway station in Aughton, Lancashire, England, on the Ormskirk branch of the Northern Line of the Merseyrail network 11½ miles (19 km) north east of Liverpool Central. Ormskirk railway station: Ormskirk railway station in Ormskirk, Lancashire, England, is an interchange between Merseyrail services from Liverpool Central and Northern services from Preston on the Ormskirk branch line, 12+3/4 mi northeast of Liverpool.
#
# ====================================================================================================
# ID: 5a7a5cc955429941d65f25d6
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Sinh nhật của tác giả "She Walks These Hills" là ngày mấy?
#
# QUESTION EN:
# What is the birthday of the author of "She Walks These Hills"?
#
# ORIGINAL GOLD ANSWER:
# February 26, 1948
#
# CURRENT ANSWER VI:
# 26 tháng 2 năm 1948
#
# GOLD SUPPORT:
# She Walks These Hills: She Walks These Hills is a book written by Sharyn McCrumb and published by Charles Scribner's Sons in 1994, which later went on to win the Anthony Award for Best Novel in 1995. Sharyn McCrumb: Sharyn McCrumb (born February 26, 1948) is an American writer whose books celebrate the history and folklore of Appalachia.
#
# ====================================================================================================
# ID: 5a7f89c75542994857a76775
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Các thuật ngữ của hình học đại số thay đổi đột ngột với sự ra đời của các phương pháp tổng quát, do một nhà toán học quốc tịch gì khởi xướng?
#
# QUESTION EN:
# The terminology of algebraic geometry changed drastically with the introduction of the general methods, initiated by a mathematician of what nationality?
#
# ORIGINAL GOLD ANSWER:
# German
#
# CURRENT ANSWER VI:
# Tiếng Đức
#
# GOLD SUPPORT:
# Glossary of classical algebraic geometry: The terminology of algebraic geometry changed drastically during the twentieth century, with the introduction of the general methods, initiated by David Hilbert and the Italian school of algebraic geometry in the beginning of the century, and later formalized by André Weil, Serre and Grothendieck. David Hilbert: David Hilbert (] ; 23 January 1862 – 14 February 1943) was a German mathematician.
#
# ====================================================================================================
# ID: 5abd82dc5542993062266cb6
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Vì sao CEO của đội bóng đá có trụ sở tại Denver, Colorado từ chức vào năm 2014?
#
# QUESTION EN:
# Why did the CEO of the football team based in Denver, Colorado step down in 2014?
#
# ORIGINAL GOLD ANSWER:
# due to the onset and progression of Alzheimer's disease
#
# CURRENT ANSWER VI:
# do sự xuất hiện và tiến triển của bệnh Alzheimer
#
# GOLD SUPPORT:
# Denver Broncos: The Denver Broncos are an American football team based in Denver, Colorado. Pat Bowlen:  He served as the Broncos CEO from his purchase of the club in 1984 until July 2014, when he stepped down as Broncos' CEO due to the onset and progression of Alzheimer's disease.
#
# ====================================================================================================
# ID: 5a71231a5542994082a3e5c4
# Translation triage: B_answer_translation_suspicious
# Source QA: pass
#
# QUESTION VI:
# Quả cây ăn được, mọng nước này mọc trên một loại cây rụng lá có tên là 'pesco' trong tiếng Ý
#
# QUESTION EN:
# What edible, juicy fruit is grown on a deciduous tree called 'pesco' in Italian?
#
# ORIGINAL GOLD ANSWER:
# peach
#
# CURRENT ANSWER VI:
# bơ
#
# GOLD SUPPORT:
# Pesco: Pesco is an Italian word meaning "Peach tree". Pesco:  It may refer to: Peach:  It bears an edible juicy fruit called a peach or a nectarine.
#
# ====================================================================================================
# ID: 5a77c60255429967ab105285
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Lý thuyết nào được tác giả của cuốn sách "Progress in Optics" đưa ra?
#
# QUESTION EN:
# What theory was advanced by the author of Progress in Optics?
#
# ORIGINAL GOLD ANSWER:
# theory of direct scattering and inverse scattering
#
# CURRENT ANSWER VI:
# Lý thuyết phân tán trực tiếp và phân tán ngược
#
# GOLD SUPPORT:
# Progress in Optics: Progress in Optics are a series of books edited by Emil Wolf published by Elsevier. Emil Wolf: Emil Wolf (born July 30, 1922) is a Czech born American physicist who made advancements in physical optics, including diffraction, coherence properties of optical fields, spectroscopy of partially coherent radiation, and the theory of direct scattering and inverse scattering.
#
# ====================================================================================================
# ID: 5ac2680055429963665199a8
# Translation triage: B_answer_translation_suspicious
# Source QA: pass
#
# QUESTION VI:
# Ernest Newman giữ chức vụ gì tại Cung điện và Pháo đài Hoàng Gia của Nữ hoàng?
#
# QUESTION EN:
# What position did Ernest Newman hold at Her Majesty's Royal Palace and Fortress?
#
# ORIGINAL GOLD ANSWER:
# Chaplain
#
# CURRENT ANSWER VI:
# Chư mục
#
# GOLD SUPPORT:
# Ernest Newman (priest):  After a curacy at Reading Minster he became a Chaplain to the Forces serving at the Tower of London and in Bengal, Caterham, South Africa (where he was Mentioned in despatches) and Portsmouth until his Archdeacon’s appointment. Tower of London: The Tower of London, officially Her Majesty's Royal Palace and Fortress of the Tower of London, is a historic castle located on the north bank of the River Thames in central London.
#
# ====================================================================================================
# ID: 5a88016b5542997e5c09a58a
# Translation triage: B_answer_translation_suspicious
# Source QA: pass
#
# QUESTION VI:
# Migene González-Wippler là chuyên gia hàng đầu trong một tôn giáo mà đã phát triển giữa nhóm dân tộc nào?
#
# QUESTION EN:
# Migene González-Wippler is leading expert on a religion that developed among which ethnic group ?
#
# ORIGINAL GOLD ANSWER:
# West African descendants
#
# CURRENT ANSWER VI:
# Hậu quả của việc sử dụng
#
# GOLD SUPPORT:
# Migene González-Wippler: Migene González-Wippler is a Puerto Rican new-age author and a leading expert on the Afro-Caribbean religion of Santería. Santería: Santería, also known as Regla de Ochá, La Regla de Ifá, or Lucumi, is an Afro-American religion of Caribbean origin that developed in the Spanish Empire among West African descendants.
#
# ====================================================================================================
# ID: 5a7bf3da5542996dd594b869
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Laurie Davidson là một diễn viên người Anh được biết đến với việc vào vai một phiên bản hư cấu của William Shakespeare trẻ tuổi trên một chương trình đã bị hủy bỏ vào ngày nào?
#
# QUESTION EN:
# Laurie Davidson is an English actor known for playing a fictionalized version of a young William Shakespeare on a show that was canceled on what date?
#
# ORIGINAL GOLD ANSWER:
# September 5, 2017
#
# CURRENT ANSWER VI:
# 5 tháng 9 năm 2017
#
# GOLD SUPPORT:
# Laurie Davidson (actor): Laurie Davidson is an English actor known for playing a fictionalized version of a young William Shakespeare in TNT's "Will". Will (TV series): Will is an American drama television series about the (fictional) life of William Shakespeare in his early 20s. Will (TV series):  On September 5, 2017, "Will" was canceled after one season by TNT.
#
# ====================================================================================================
# ID: 5ae4cda05542990ba0bbb148
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Tại sao Serena Williams thành công hơn Mariaan de Swardt trong sự nghiệp quần vợt của cô ấy?
#
# QUESTION EN:
# Why is Serena Williams more accomplished than Mariaan de Swardt in her tennis career?
#
# ORIGINAL GOLD ANSWER:
# the world No. 1 for the first time
#
# CURRENT ANSWER VI:
# lần đầu tiên là số 1 thế giới
#
# GOLD SUPPORT:
# Serena Williams: Serena Jameka Williams (born September 26, 1981) is an American professional tennis player. Serena Williams:  She became the world No. 1 for the first time on July 8, 2002. Mariaan de Swardt: Mariaan de Swardt (born 18 March 1971) is a former tennis player from South Africa, who played as a professional from 1988 to 2001. Mariaan de Swardt:  She twice represented her native country at the Summer Olympics, in 1992 and 1996, and was a member of the South African Fed Cup Team in 1992 and 1994–1997.
#
# ====================================================================================================
# ID: 5a7f3d9b5542992e7d278cb8
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Nghề nghiệp ban đầu của tác giả Freeway Warrior là gì?
#
# QUESTION EN:
# What was the author of Freeway Warrior's original occupation?
#
# ORIGINAL GOLD ANSWER:
# Originally a musician
#
# CURRENT ANSWER VI:
# Ban đầu là một nhạc sĩ
#
# GOLD SUPPORT:
# Freeway Warrior: Freeway Warrior is a series of 4 gamebooks, created by Joe Dever. Joe Dever:  Originally a musician, Dever became the first British winner of the "Advanced Dungeons & Dragons" Championship of America in 1982.
#
# ====================================================================================================
# ID: 5abd0b6b5542996e802b46b4
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Cuối cùng bao gồm bài hát mà đỉnh điểm ở số trên bảng xếp hạng US Hot 100
#
# QUESTION EN:
# Finally includes the song that peaked at what on the US Hot 100
#
# ORIGINAL GOLD ANSWER:
# number five
#
# CURRENT ANSWER VI:
# số 5
#
# GOLD SUPPORT:
# Finally (CeCe Peniston album):  Prior to the release of this album, Peniston released her debut single "Finally", which topped the US "Billboard" Hot Dance Music Club Play chart on October 26, 1991, peaking eventually at number five on the "Billboard" Hot 100 and at number two in the UK Singles Chart. Finally (CeCe Peniston song):  "Finally" became Peniston's first (and biggest) hit song, peaking at number five on the US Hot 100 in January 1992 and becoming her only US top-ten hit to date.
#
# ====================================================================================================
# ID: 5a8b8f5b55429949d91db5e1
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Yameen và Activision cùng chung một hình thức chơi game nào?
#
# QUESTION EN:
# What form of play does Yameen and Activision have in common?
#
# ORIGINAL GOLD ANSWER:
# video game
#
# CURRENT ANSWER VI:
# trò chơi video
#
# GOLD SUPPORT:
# Yameen:  His music can be heard weekly on the Activision videogames podcast, One of Swords where he is also occasionally a guest commentator. Activision: Activision Publishing, Inc., also known as Activision, is an American video game publisher.
#
# ====================================================================================================
# ID: 5abf30185542990832d3a13f
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Lou Cutell xuất hiện trong tập thứ ba của mùa thứ chín một sitcom CBS mà là tập số bao nhiêu?
#
# QUESTION EN:
#  Lou Cutell appeared on the third episode of the ninth season of an CBS sitcom that was what number episode overall?
#
# ORIGINAL GOLD ANSWER:
# 187th
#
# CURRENT ANSWER VI:
# 187th
#
# GOLD SUPPORT:
# Lou Cutell: Lou Cutell (born October 6, 1930) is an American movie and television actor. Lou Cutell:  In 2013, he appeared on the "How I Met Your Mother" episode "Last Time in New York". Last Time in New York: "Last Time in New York" is the third episode of the ninth season of the CBS sitcom "How I Met Your Mother", and the 187th episode overall.
#
# ====================================================================================================
# ID: 5ae55ed15542992663a4f1ea
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Ý nghĩa của tên thị trấn mà Jack Briggs sinh ra là gì?
#
# QUESTION EN:
# What is the meaning of the name of the town where Jack Briggs was born?
#
# ORIGINAL GOLD ANSWER:
# valley of the hazels
#
# CURRENT ANSWER VI:
# thung lũng của các hazels
#
# GOLD SUPPORT:
# Jack Briggs (cricketer):  He was born at Haslingden, Lancashire. Haslingden:  The name means 'valley of the hazels'.
#
# ====================================================================================================
# ID: 5adead1855429939a52fe948
# Translation triage: D_context_support_suspicious
# Source QA: pass
#
# QUESTION VI:
# Người "Planet Earth Rock and Roll Orchestra" là album solo cuối cùng của ông qua đời vào ngày nào?
#
# QUESTION EN:
# The person "Planet Earth Rock and Roll Orchestra" was the final solo album for died on what date?
#
# ORIGINAL GOLD ANSWER:
# January 28, 2016
#
# CURRENT ANSWER VI:
# Ngày 28 tháng 1 năm 2016
#
# GOLD SUPPORT:
# Planet Earth Rock and Roll Orchestra (album): Planet Earth Rock and Roll Orchestra is the final solo album by Paul Kantner and the only Kantner solo release to be solely credited to the singer-songwriter. Paul Kantner: Paul Lorin Kantner (March 17, 1941 – January 28, 2016) was an American rock musician.
#
# ====================================================================================================
# ID: 5a7369da55429901807db037
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Tác giả của Songs and Dances of Death thuộc nhóm nào?
#
# QUESTION EN:
# In what group was the writer of Songs and Dances of Death in?
#
# ORIGINAL GOLD ANSWER:
# "The Five"
#
# CURRENT ANSWER VI:
# "Những người năm"
#
# GOLD SUPPORT:
# Songs and Dances of Death: Songs and Dances of Death (Russian: Песни и пляски смерти , "Pesni i plyaski smerti") is a song cycle for voice (usually bass or bass-baritone) and piano by Modest Petrovich Mussorgsky, written in the mid-1870s, to poems by Arseny Golenishchev-Kutuzov, a relative of the composer. Modest Mussorgsky: Modest Petrovich Mussorgsky (Russian: Моде́ст Петро́вич Му́соргский ; ] ; 21 March [O.S. 9 March] 1839 – 28 March [O.S. 16 March] 1881 ) was a Russian composer, one of the group known as "The Five".
#
# ====================================================================================================
# ID: 5a8834f05542994846c1ce26
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Quốc tịch của nhà soạn nhạc tác phẩm Chaconne in F minor là gì?
#
# QUESTION EN:
# What was the nationality of the composer of Chaconne in F minor?
#
# ORIGINAL GOLD ANSWER:
# German
#
# CURRENT ANSWER VI:
# Tiếng Đức
#
# GOLD SUPPORT:
# Chaconne in F minor (Pachelbel): Chaconne in F minor (PWC 43, T. 206, PC 149, POP 16) is an organ chaconne by Johann Pachelbel. Johann Pachelbel: Johann Pachelbel (baptised 1 September 1653 – buried 9 March 1706) was a German composer, organist, and teacher who brought the south German organ tradition to its peak.
#
# ====================================================================================================
# ID: 5adf36c55542993344016c3e
# Translation triage: D_context_support_suspicious
# Source QA: pass
#
# QUESTION VI:
# Tên nhạc sỹ của "Elliot, A Soldier's Fugue" đã giành giải Tony năm 2008 ở hạng mục nào?
#
# QUESTION EN:
# In what category did the composer of "Elliot, a Soldier's Fugue" win a Tony Award in 2008?
#
# ORIGINAL GOLD ANSWER:
# for Best Musical
#
# CURRENT ANSWER VI:
# cho Best Musical
#
# GOLD SUPPORT:
# Water by the Spoonful:  Hudes had previously won the 2008 Tony Award for Best Musical for "In the Heights". Quiara Alegría Hudes:  Her play "Elliot, a Soldier's Fugue" was a finalist for the 2007 Pulitzer Prize for Drama.
#
# ====================================================================================================
# ID: 5adfb790554299603e418389
# Translation triage: B_answer_translation_suspicious
# Source QA: pass
#
# QUESTION VI:
# Eragrostis và Rhexia có điểm gì giống nhau?
#
# QUESTION EN:
# What do Eragrostis and Rhexia have in common?
#
# ORIGINAL GOLD ANSWER:
# plant genus
#
# CURRENT ANSWER VI:
# Phụ nữ
#
# GOLD SUPPORT:
# Eragrostis: Eragrostis is a large and widespread genus of plants in the grass family, found in many countries on all inhabited continents and many islands. Rhexia: Rhexia is a plant genus of Melastomataceae (ca. 4500 species in 150 genera) family.
#
# ====================================================================================================
# ID: 5a8dd5f955429917b4a5bcc7
# Translation triage: D_context_support_suspicious
# Source QA: pass
#
# QUESTION VI:
# Ngoài đua xe, môn thể thao nào người vô địch giải Toyota Grand Prix năm 1998 tập luyện?
#
# QUESTION EN:
# Other than racing, what sport does the 1998 champion of the Toyota GRand Prix practice?
#
# ORIGINAL GOLD ANSWER:
# paracyclist
#
# CURRENT ANSWER VI:
# người đạp xe dù
#
# GOLD SUPPORT:
# 1998 Toyota Grand Prix of Long Beach:  Alex Zanardi won the race, even though he was a lap down at one point. Alex Zanardi: Alessandro "Alex" Zanardi (] ; born 23 October 1966) is an Italian professional racing driver and paracyclist.
#
# ====================================================================================================
# ID: 5ae0b4c15542993d6555ec21
# Translation triage: B_answer_translation_suspicious
# Source QA: pass
#
# QUESTION VI:
# The Ready Set và Cell là gì?
#
# QUESTION EN:
# What are The Ready Set and Cell?
#
# ORIGINAL GOLD ANSWER:
# band
#
# CURRENT ANSWER VI:
# băng
#
# GOLD SUPPORT:
# The Ready Set: Jordan Mark Witzigreuter (born November 14, 1989), known professionally as The Ready Set, is an American singer-songwriter from Fort Wayne, Indiana. Cell (American band): Cell were a New York-based band often tagged with the label of Grunge given the time frame of their existence, though college rock or alternative is arguably a more apt description.
#
# ====================================================================================================
# ID: 5ae74fc45542997b22f6a6b4
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Tên đầy đủ của căn bệnh hô hấp do virus gây ra mà nghiên cứu của Yi Guan giúp ngăn chặn sự bùng phát là gì?
#
# QUESTION EN:
# What is the full name of the viral respiratory disease in which Yi Guan's research helped to prevent the outbreak of?
#
# ORIGINAL GOLD ANSWER:
# severe acute respiratory syndrome
#
# CURRENT ANSWER VI:
# hội chứng hô hấp cấp tính nghiêm trọng
#
# GOLD SUPPORT:
# Yi Guan:  His research on the viral respiratory disease SARS allowed the Chinese government to successfully avert the 2004 outbreak of this disease. Timeline of the SARS outbreak: The following is a timeline of the 2002–04 outbreak of severe acute respiratory syndrome (SARS).
#
# ====================================================================================================
# ID: 5adf4a275542993a75d26498
# Translation triage: D_context_support_suspicious
# Source QA: pass
#
# QUESTION VI:
# Người đàn ông, người mà giải thưởng mà "Summer of the Monkeys" đã giành được, là một phát ngôn nhân cho khu vực trắng của nước Mỹ?
#
# QUESTION EN:
# The man, who the award in which "Summer of the Monkeys" won, was a spokesman for white sector of America?
#
# ORIGINAL GOLD ANSWER:
# middle America
#
# CURRENT ANSWER VI:
# Trung Mỹ
#
# GOLD SUPPORT:
# Summer of the Monkeys: Summer of the Monkeys is a 1976 children's novel written by Wilson Rawls. Summer of the Monkeys:  It was published by Doubleday (later released by Yearling Books) and was the winner of the William Allen White Book Award and the California Young Reader Medal. William Allen White:  Between 1896 and his death, White became a spokesman for middle America.
#
# ====================================================================================================
# ID: 5ac2cdaa554299657fa29070
# Translation triage: E_ambiguous_review
# Source QA: pass
#
# QUESTION VI:
# Neoregelia và Aloysia được biết đến là loài cây mọc ở đâu?
#
# QUESTION EN:
# Where are Neoregelia and Aloysia known to grow
#
# ORIGINAL GOLD ANSWER:
# temperate climates,
#
# CURRENT ANSWER VI:
# khí hậu ôn hòa,
#
# GOLD SUPPORT:
# Neoregelia: Neoregelia is a genus of flowering plants in the bromeliad family Bromeliaceae, subfamily Bromelioideae, native to South American rainforests. Aloysia:  They are native to the Americas, where they are distributed in temperate climates, as well as in subtropical and desert climates.

# %% [markdown]
# ## Cell C8.3 Spot check nhóm A

# %%
import random

likely_ok = [
    x for x in triage_results
    if x["category"] in {
        "A_flexible_span",
        "A_likely_ok"
    }
]

rng = random.Random(42)

sample_ok = rng.sample(
    likely_ok,
    min(20, len(likely_ok))
)

for x in sample_ok:

    print("\n" + "=" * 100)

    print(x["category"])

    print("Q :", x["question_vi"])
    print("EN:", x["answer_en"])
    print("VI:", x["answer_vi"])

    print(
        "Support:",
        x["best_context_sentence"]
    )
# Out:
# ====================================================================================================
# A_likely_ok
# Q : Bộ tộc Bắc Mỹ nào cư trú dọc theo bờ sông Winnipesaukee và còn được biết đến với tên gọi Pawtucket?
# EN: the Pennacook people
# VI: người Pennacook
# Support: Pennacook, còn được biết đến với tên gọi Penacook và Pennacock, là những người Bắc Mỹ thuộc Liên minh Wabanaki cư trú tại lưu vực sông Merrimack ở New Hampshire và Massachusetts ngày nay cũng như một phần của miền Nam Maine.
#
# ====================================================================================================
# A_likely_ok
# Q : Nghề nghiệp chung giữa David Breashears và Richard Bass là gì?
# EN: mountaineer
# VI: người leo núi
# Support: Ông được biết đến nhiều nhất với việc dẫn dắt Richard Bass lên tới đỉnh Everest để hoàn tất việc chinh phục Bảy đỉnh cao nhất (đỉnh cao nhất trên mỗi trong bảy châu lục).
#
# ====================================================================================================
# A_likely_ok
# Q : Quốc tịch của một nhiếp ảnh gia nổi tiếng làm việc như một nhiếp ảnh gia hậu trường trong các bộ phim Hollywood là gì?
# EN: German
# VI: Tiếng Đức
# Support: Jürgen Vollmer
#
# ====================================================================================================
# A_likely_ok
# Q : Thành phố mà pháo đài Kongenstein nằm trong khu vực nào?
# EN: the Greater Accra Region
# VI: Khu vực Accra lớn
# Support: Nằm ngay gần đường cao tốc Accra-Aflao, thị trấn này tọa lạc dọc theo sông Volta.
#
# ====================================================================================================
# A_likely_ok
# Q : Trường trung học Ashland, New Hampshire hay trường trung học Plymouth Regional gần khu rừng quốc gia Scribner-Fellows hơn?
# EN: Ashland is home to Scribner-Fellows State Forest
# VI: Ashland là nơi có rừng bang Scribner-Fellows
# Support: Nằm gần trung tâm địa lý của bang, Ashland là nơi có khu rừng quốc gia Scribner-Fellows State Forest.
#
# ====================================================================================================
# A_likely_ok
# Q : Brad Elterman là một nhiếp ảnh gia chuyên nghiệp đã ghi lại phong cách sống rock 'n' roll của một ban nhạc được biết đến với điều gì?
# EN: its eclectic mix of musical styles
# VI: sự pha trộn đầy đủ của các phong cách âm nhạc
# Support: Họ cũng nổi tiếng vì sự đa dạng trong cách phối hợp âm nhạc kết hợp với disco, pop, reggae cùng với hip hop thời kỳ đầu.
#
# ====================================================================================================
# A_likely_ok
# Q : Trong hai mỏ Kemess và Colomac thì mỏ nào được khai thác bởi Royal Oak Mines trước?
# EN: The Colomac Mine
# VI: Quặng Colomac
# Support: Mỏ Colomac
#
# ====================================================================================================
# A_likely_ok
# Q : Josey Scott và Ian Watkins đều là những nhạc sĩ hứa hẹn. Trong hai người đàn ông tài năng này, ai bị bỏ tù, ảnh hưởng đến sự nghiệp của ban nhạc rock?
# EN: Lostprophets disbanded in 2013 after Watkins was charged with sexual offences in late 2012.
# VI: Lostprophets đã tan rã vào năm 2013 sau khi Watkins bị buộc tội phạm tình dục vào cuối năm 2012.
# Support: Lostprophets giải thể vào năm 2013 sau khi Watkins bị buộc tội về hành vi tình dục vào cuối năm 2012.
#
# ====================================================================================================
# A_likely_ok
# Q : Cistus và Stapelianthus là dạng hình thái của cái gì?
# EN: flowering plants
# VI: cây hoa
# Support: Stapelianthus
#
# ====================================================================================================
# A_likely_ok
# Q : Tên vai nhỏ mà nghệ sĩ vẽ truyện tranh người New Zealand này đóng trong phim "King Kong" sẽ do đạo diễn nào chỉ đạo sản xuất dựa trên tiểu thuyết của Philip Reeve?
# EN: Gondorian soldier
# VI: Một binh sĩ Gondorian
# Support: Anh cũng đóng vai cameo trong "" với vai một lính Gondorian và "King Kong" với vai một lính trên xe tải.
#
# ====================================================================================================
# A_likely_ok
# Q : Wexner Graduate Fellowships được trao cho những sinh viên thể hiện khả năng "lãnh đạo" hay dẫn dắt ai?
# EN: other individuals, teams, or entire organizations
# VI: Những cá nhân, nhóm hoặc tổ chức khác
# Support: Lãnh đạo là một lĩnh vực nghiên cứu và cũng là một kỹ năng thực tiễn bao gồm khả năng của cá nhân hoặc tổ chức để "lãnh đạo" hay hướng dẫn các cá nhân khác, đội ngũ công tác, hay toàn bộ tổ chức.
#
# ====================================================================================================
# A_likely_ok
# Q : Tại sao Rudolf Hess ngừng phục vụ Hitler vào năm 1941?
# EN: report Hess's illegal May 1941 flight to Scotland
# VI: báo cáo chuyến bay bất hợp pháp của Hess vào tháng 5 năm 1941 đến Scotland
# Support: Ông ta là người phải báo cáo chuyến bay bất hợp pháp tháng 5/1941 của Hess đến Scotland cho Hitler và những hồi tưởng cùng ghi chú của ông đã trở thành chủ đề tranh luận giữa các sử gia.
#
# ====================================================================================================
# A_likely_ok
# Q : Có bao nhiêu giải Quả Cầu Vàng mà nữ diễn viên người Anh đã nghỉ hưu, sự nghiệp của bà trải qua sáu thập niên và xuất hiện trong vở kịch hai hồi Moby Dick—Rehearsed của Orson Welles?
# EN: two Golden Globe Awards
# VI: hai giải Golden Globe
# Support: Bà cũng là một trong bốn nữ diễn viên duy nhất từng đoạt hai lần cùng lúc tại lễ trao giải Quả cầu vàng.
#
# ====================================================================================================
# A_flexible_span
# Q : Chó mà Socks đã cãi nhau màu gì?
# EN: chocolate-colored
# VI: màu sô cô la
# Support: Buddy (7 tháng 8, 1997 – ngày 2 tháng 1 năm 2002), một con chó Labrador Retriever màu sô-cô-la đực, là một trong hai thú cưng của gia đình Clinton khi Bill Clinton làm Tổng thống Hoa Kỳ.
#
# ====================================================================================================
# A_likely_ok
# Q : Ai là phi hành gia sinh trước, Jean-François Clervoy hay Ulrich Walter?
# EN: Prof. Dr. Ulrich Hans Walter
# VI: Giáo sư Ulrich Hans Walter
# Support: Ulrich Walter
#
# ====================================================================================================
# A_likely_ok
# Q : Tên gọi khác của LRA được nhắc đến trong A Brilliant Genocide là gì?
# EN: United Holy Salvation Army and Uganda Christian Army/Movement
# VI: Quân đội cứu độ thánh hiệp nhất và Quân đội/Hành động Kitô giáo Uganda
# Support: Ban đầu được biết đến với tên gọi là Quân đội Cứu rỗi Thánh hợp nhất và Quân đội/Phong trào Cơ Đốc Giáo Uganda, mục tiêu chính thức của nó bao gồm việc thành lập một nền dân chủ đa đảng, cai trị Uganda theo Mười Điều Răn và chủ nghĩa dân tộc Acholi mặc dù trong thực tế "LRA không có động cơ chính trị rõ ràng nào cả mà quân sự chiến lược và cách thức hành quân phản ánh điều này".
#
# ====================================================================================================
# A_likely_ok
# Q : Tên thám tử hư cấu xuất hiện trong "The Adventure of the Seven Clocks" là tác phẩm của ai?
# EN: Sir Arthur Conan Doyle
# VI: Sir Arthur Conan Doyle
# Support: Sherlock Holmes là một thám tử hư cấu do tác giả người Anh Arthur Conan Doyle sáng tạo ra.
#
# ====================================================================================================
# A_likely_ok
# Q : Năm 1736, một khu phức hợp được xây dựng ở trung tâm Moscow. Khu phức hợp này được biết đến với tên gọi gì?
# EN: Moscow Kremlin
# VI: Kremlin Moscow
# Support: Điện Kremlin
#
# ====================================================================================================
# A_likely_ok
# Q : Charles Burnett và Alan J. Pakula có nghề nghiệp gì chung?
# EN: film director, film producer, writer
# VI: đạo diễn phim, nhà sản xuất phim, nhà văn
# Support: Charles Burnett (đạo diễn)
#
# ====================================================================================================
# A_likely_ok
# Q : Nghề nghiệp của nhân vật do Ansel Elgort thủ vai trong phim "Baby Driver" là gì?
# EN: getaway driver
# VI: lái xe chạy trốn
# Support: Baby Driver

# %%
for x in triage_results:
    if "Rudolf Hess" in x["question_vi"]:
        print("Category:", x["category"])
        print("Question similarity:", x["question_similarity"])
        print("Answer similarity:", x["answer_similarity"])
        print("Context similarity:", x["context_similarity"])
        print("\nQUESTION VI:", x["question_vi"])
        print("\nQUESTION EN:", x["question_en"])
        print("\nANSWER EN:", x["answer_en"])
        print("\nANSWER VI:", x["answer_vi"])
        print("\nBEST SUPPORT:", x["best_context_sentence"])
# Out:
# Category: A_likely_ok
# Question similarity: 0.9847014546394348
# Answer similarity: 0.9505025148391724
# Context similarity: 0.7812156677246094
#
# QUESTION VI: Tại sao Rudolf Hess ngừng phục vụ Hitler vào năm 1941?
#
# QUESTION EN: Why did Rudolf Hess stop serving Hitler in 1941?
#
# ANSWER EN: report Hess's illegal May 1941 flight to Scotland
#
# ANSWER VI: báo cáo chuyến bay bất hợp pháp của Hess vào tháng 5 năm 1941 đến Scotland
#
# BEST SUPPORT: Ông ta là người phải báo cáo chuyến bay bất hợp pháp tháng 5/1941 của Hess đến Scotland cho Hitler và những hồi tưởng cùng ghi chú của ông đã trở thành chủ đề tranh luận giữa các sử gia.

# %% [markdown]
# # Lưu ra csv để dễ manual review

# %%
import pandas as pd

review_df = pd.DataFrame([
    {
        "id": x["id"],
        "question_vi": x["question_vi"],
        "question_en": x["question_en"],
        "answer_en": x["answer_en"],
        "answer_vi_current": x["answer_vi"],
        "answer_vi_corrected": "",   # điền thủ công
        "notes": ""
    }
    for x in priority_review
])

review_df.to_csv(
    "/content/answer_vi_manual_review.csv",
    index=False,
    encoding="utf-8-sig"
)

print("Saved:", len(review_df), "cases")
# Out:
# Saved: 63 cases

# %% [markdown]
# # Sau khi review, sửa cột answer_vi_corrected thì cập nhật lại

# %%
review_df = pd.read_csv(
    "/content/answer_vi_manual_review.csv"
)

corrections = {
    str(row["id"]): row["answer_vi_corrected"]
    for _, row in review_df.iterrows()
    if pd.notna(row["answer_vi_corrected"])
    and str(row["answer_vi_corrected"]).strip()
}

for row in final_queries:
    qid = str(row["id"])

    if qid in corrections:
        row["answer_vi"] = corrections[qid].strip()
        row["answer_vi_method"] = "manual_review"
        row["answer_vi_confidence"] = "high"
        row["answer_vi_needs_review"] = False

print("Applied corrections:", len(corrections))
# Out:
# Applied corrections: 0

# %% [markdown]
# # D. Save dataset cuối

# %% [markdown]
# ## Cell D1 — corpus.jsonl

# %%
import os
import json

OUT_DIR = "/content/hotpotqa_vi_1k"

os.makedirs(
    OUT_DIR,
    exist_ok=True
)

with open(
    f"{OUT_DIR}/corpus.jsonl",
    "w",
    encoding="utf-8"
) as f:

    for doc in final_corpus.values():

        output = {
            "id": doc["id"],
            "title": doc["title"],
            "text": doc["text"],
            "language": "vi"
        }

        f.write(
            json.dumps(
                output,
                ensure_ascii=False
            )
            + "\n"
        )

# %% [markdown]
# ## Cell D2 — queries.jsonl

# %%
with open(
    f"{OUT_DIR}/queries.jsonl",
    "w",
    encoding="utf-8"
) as f:

    for row in final_queries:

        f.write(
            json.dumps(
                row,
                ensure_ascii=False
            )
            + "\n"
        )

# %% [markdown]
# ## Cell D3 — qrels.tsv

# %%
import pandas as pd

qrels_df = pd.DataFrame(
    selected_qrels
)

qrels_df.to_csv(
    f"{OUT_DIR}/qrels.tsv",
    sep="\t",
    index=False
)

qrels_df.head()
# Out:
#                    query_id corpus_id  score
# 0  5ac113e2554299294b21909a    311164      1
# 1  5ac113e2554299294b21909a   2466925      1
# 2  5abed6905542990832d3a0ed  17116117      1
# 3  5abed6905542990832d3a0ed   6831066      1
# 4  5ac09da45542996f0d89cc1d  23676585      1
